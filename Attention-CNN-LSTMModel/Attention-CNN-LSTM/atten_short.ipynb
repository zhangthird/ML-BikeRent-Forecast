# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
from matplotlib import rcParams

# 设置 Matplotlib 使用 SimHei 字体
rcParams['font.family'] = ['SimHei']  # 指定中文字体
rcParams['axes.unicode_minus'] = False  # 正常显示负号

# %%
# 加载训练和测试数据
train_df = pd.read_csv('../dataset/train_data.csv')
test_df = pd.read_csv('../dataset/test_data.csv')

# 删除不需要的列
columns_to_drop = ['instant', 'dteday']
train_df.drop(columns=columns_to_drop, inplace=True)
test_df.drop(columns=columns_to_drop, inplace=True)

# 查看每列的缺失值数量
print("训练集缺失值:\n", train_df.isnull().sum())
print(train_df.info())

# 删除含有缺失值的行
train_df = train_df.dropna()
test_df = test_df.dropna()
# Out:
# 训练集缺失值:
#  season        3
# yr            3
# mnth          3
# hr            3
# holiday       3
# weekday       3
# workingday    3
# weathersit    3
# temp          3
# atemp         3
# hum           3
# windspeed     3
# casual        3
# registered    3
# cnt           3
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15219 entries, 0 to 15218
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      15216 non-null  float64
#  1   yr          15216 non-null  float64
#  2   mnth        15216 non-null  float64
#  3   hr          15216 non-null  float64
#  4   holiday     15216 non-null  float64
#  5   weekday     15216 non-null  float64
#  6   workingday  15216 non-null  float64
#  7   weathersit  15216 non-null  float64
#  8   temp        15216 non-null  float64
#  9   atemp       15216 non-null  float64
#  10  hum         15216 non-null  float64
#  11  windspeed   15216 non-null  float64
#  12  casual      15216 non-null  float64
#  13  registered  15216 non-null  float64
#  14  cnt         15216 non-null  float64
# dtypes: float64(15)
# memory usage: 1.7 MB
# None

# %%
numeric_features = ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered']
categorical_features = ['yr', 'season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']
target = 'cnt'

# 特征归一化
scaler_features = MinMaxScaler()
train_df[numeric_features] = scaler_features.fit_transform(train_df[numeric_features])
test_df[numeric_features] = scaler_features.transform(test_df[numeric_features])

features = numeric_features + categorical_features
# 最终检查
print("\n最终训练集信息:")
print(train_df.info())

print("\n最终测试集信息:")
print(test_df.info())
# Out:
# 最终训练集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15216 entries, 0 to 15215
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      15216 non-null  float64
#  1   yr          15216 non-null  float64
#  2   mnth        15216 non-null  float64
#  3   hr          15216 non-null  float64
#  4   holiday     15216 non-null  float64
#  5   weekday     15216 non-null  float64
#  6   workingday  15216 non-null  float64
#  7   weathersit  15216 non-null  float64
#  8   temp        15216 non-null  float64
#  9   atemp       15216 non-null  float64
#  10  hum         15216 non-null  float64
#  11  windspeed   15216 non-null  float64
#  12  casual      15216 non-null  float64
#  13  registered  15216 non-null  float64
#  14  cnt         15216 non-null  float64
# dtypes: float64(15)
# memory usage: 1.9 MB
# None
#
# 最终测试集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      2160 non-null   int64
#  1   yr          2160 non-null   int64
#  2   mnth        2160 non-null   int64
#  3   hr          2160 non-null   int64
#  4   holiday     2160 non-null   int64
#  5   weekday     2160 non-null   int64
#  6   workingday  2160 non-null   int64
#  7   weathersit  2160 non-null   int64
#  8   temp        2160 non-null   float64
#  9   atemp       2160 non-null   float64
#  10  hum         2160 non-null   float64
#  11  windspeed   2160 non-null   float64
#  12  casual      2160 non-null   float64
#  13  registered  2160 non-null   float64
#  14  cnt         2160 non-null   int64
# dtypes: float64(6), int64(9)
# memory usage: 253.2 KB
# None

# %%
def create_sequences(df, input_steps, output_steps, features, target, sw=1):
    X = []
    y = []
    num = (len(df) - input_steps - output_steps)/sw + 1
    for i in range(int(num)):
        X_seq = df[features].iloc[i:i+input_steps].values
        y_seq = df[target].iloc[i+input_steps:i+input_steps+output_steps].values
        X.append(X_seq)
        y.append(y_seq)
    return np.array(X), np.array(y)

# 定义输入和输出的时间步长
input_steps = 96
output_steps_short = 96

# 创建短期预测的训练集
X_short, y_short = create_sequences(train_df, input_steps, output_steps_short, features, target)
print(f'短期预测 - 输入形状: {X_short.shape}, 输出形状: {y_short.shape}')

# 划分比例
split_ratio = 0.8

# 短期预测
split_index_short = int(X_short.shape[0] * split_ratio)
X_train_short = X_short[:split_index_short]
y_train_short = y_short[:split_index_short]
X_val_short = X_short[split_index_short:]
y_val_short = y_short[split_index_short:]

X_test_short, y_test_short = create_sequences(test_df, input_steps, output_steps_short, features, target)

print(f'短期预测 - 训练集: {X_train_short.shape}, 验证集: {X_val_short.shape}')
print(f'短期预测 - 测试集: {X_test_short.shape}')
# Out:
# 短期预测 - 输入形状: (15025, 96, 14), 输出形状: (15025, 96)
# 短期预测 - 训练集: (12020, 96, 14), 验证集: (3005, 96, 14)
# 短期预测 - 测试集: (1969, 96, 14)

# %%
class BikeSharingDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 64

# 短期预测数据加载器
train_dataset_short = BikeSharingDataset(X_train_short, y_train_short)
val_dataset_short = BikeSharingDataset(X_val_short, y_val_short)
train_loader_short = DataLoader(train_dataset_short, batch_size=batch_size, shuffle=True)
val_loader_short = DataLoader(val_dataset_short, batch_size=batch_size, shuffle=False)
test_dataset_short = BikeSharingDataset(X_test_short, y_test_short)
test_loader_short = DataLoader(test_dataset_short, batch_size=batch_size, shuffle=False)

# %%
class AttentionBlock(nn.Module):
    def __init__(self, embed_dim):
        super(AttentionBlock, self).__init__()
        self.attention = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=8, batch_first=True)

    def forward(self, q, k, v):
        attn_out, _ = self.attention(q, k, v)
        attn_applied = torch.sum(attn_out, dim=1)
        return attn_applied


class CNNLSTMAttentionModel(nn.Module):
    def __init__(self, n_input, n_out, n_features):
        super(CNNLSTMAttentionModel, self).__init__()
        self.conv1d = nn.Conv1d(n_features, 64, kernel_size=3, padding=1)
        self.lstm = nn.LSTM(64, 128, batch_first=True, num_layers=2)
        self.dropout = nn.Dropout(0.2)
        self.conv_q = nn.Conv1d(128, 64, kernel_size=3, padding=1)
        self.conv_k = nn.Conv1d(128, 64, kernel_size=5, padding=2)
        self.conv_v = nn.Conv1d(128, 64, kernel_size=7, padding=3)
        self.attention = AttentionBlock(64)  
        self.fc1 = nn.Linear(64, 128)
        self.batch_norm = nn.BatchNorm1d(128)
        self.fc2 = nn.Linear(128, n_out)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # 转换为 (batch_size, n_features, time_steps) 以适应 Conv1D
        x = self.conv1d(x)
        x = x.permute(0, 2, 1)  # 恢复为 (batch_size, time_steps, n_features)
        lstm_out, (hn, cn) = self.lstm(x)
        lstm_out = self.dropout(lstm_out)
        q = self.conv_q(lstm_out.permute(0, 2, 1)).permute(0, 2, 1)
        k = self.conv_k(lstm_out.permute(0, 2, 1)).permute(0, 2, 1)
        v = self.conv_v(lstm_out.permute(0, 2, 1)).permute(0, 2, 1)
        attention_out = self.attention(q, k, v)
        out = self.fc1(attention_out)
        out = self.batch_norm(out)
        out = self.fc2(out)
        return out

# %%
def train_model(model, train_loader, val_loader, num_epochs, learning_rate, device, max_grad_norm=1.0):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)  # 学习率每10个epoch衰减为0.1

    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            # 前向传播
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
            optimizer.step()
            
            running_loss += loss.item() * X_batch.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)

        # 验证
        model.eval()
        val_running_loss = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val = X_val.to(device)
                y_val = y_val.to(device)
                outputs = model(X_val)
                loss = criterion(outputs, y_val)
                val_running_loss += loss.item() * X_val.size(0)
        
        val_epoch_loss = val_running_loss / len(val_loader.dataset)
        val_losses.append(val_epoch_loss)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_loss:.4f}, Val Loss: {val_epoch_loss:.4f}')

        # 更新学习率
        scheduler.step()

    return train_losses, val_losses

# %%
# 设置训练参数
num_epochs = 200
learning_rate = 0.005
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_experiments = 5

# 获取输入特征数量
input_size = len(features)

# 短期预测模型参数
hidden_size_short = 64
num_layers_short = 2
output_steps_short = 96

def init_weights(m):
    if isinstance(m, nn.LSTM):
        for name, param in m.named_parameters():
            if 'weight_ih' in name:
                nn.init.xavier_uniform_(param.data)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param.data)
            elif 'bias' in name:
                nn.init.zeros_(param.data)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

for exp in range(num_experiments):
    print(f"正在进行实验 {exp+1} ...")
    # model_short = LSTMModel(input_size, hidden_size_short, num_layers_short, output_steps_short)
    model_short = CNNLSTMAttentionModel(input_steps, output_steps_short, input_size)
    model_short = model_short.to('cuda' if torch.cuda.is_available() else 'cpu')
    model_short.apply(init_weights)
    train_losses, val_losses = train_model(
        model_short, train_loader_short, val_loader_short, num_epochs, learning_rate, device
    )
    torch.save(model_short.state_dict(), f'./short_model/model_short_{exp+1}.pth')

# 保存loss
train_losses_df = pd.DataFrame(train_losses)
val_losses_df = pd.DataFrame(val_losses)
train_losses_df.to_csv('./short_model/train_losses.csv', index=False)
val_losses_df.to_csv('./short_model/val_losses.csv', index=False)
# Out:
# 正在进行实验 1 ...
# Epoch [1/200], Train Loss: 39479.2774, Val Loss: 63151.3321
# Epoch [2/200], Train Loss: 15535.0642, Val Loss: 31539.2884
# Epoch [3/200], Train Loss: 11816.7550, Val Loss: 32406.1176
# Epoch [4/200], Train Loss: 10954.8982, Val Loss: 28912.8257
# Epoch [5/200], Train Loss: 9879.3034, Val Loss: 24855.9767
# Epoch [6/200], Train Loss: 9149.2377, Val Loss: 27819.2049
# Epoch [7/200], Train Loss: 8901.8584, Val Loss: 28892.2922
# Epoch [8/200], Train Loss: 8821.5622, Val Loss: 25156.6594
# Epoch [9/200], Train Loss: 8726.5536, Val Loss: 27382.6160
# Epoch [10/200], Train Loss: 8697.6146, Val Loss: 26046.8600
# Epoch [11/200], Train Loss: 8641.7891, Val Loss: 28952.3690
# Epoch [12/200], Train Loss: 8563.7832, Val Loss: 25870.6857
# Epoch [13/200], Train Loss: 8297.3243, Val Loss: 26167.0541
# Epoch [14/200], Train Loss: 8085.8897, Val Loss: 28418.5184
# Epoch [15/200], Train Loss: 8250.5817, Val Loss: 24554.2817
# Epoch [16/200], Train Loss: 8168.5743, Val Loss: 26347.2184
# Epoch [17/200], Train Loss: 8020.4707, Val Loss: 27217.1310
# Epoch [18/200], Train Loss: 8175.7611, Val Loss: 23035.8880
# Epoch [19/200], Train Loss: 8022.6705, Val Loss: 25068.5609
# Epoch [20/200], Train Loss: 7871.8181, Val Loss: 24659.6071
# Epoch [21/200], Train Loss: 7878.4395, Val Loss: 22256.1218
# Epoch [22/200], Train Loss: 7904.7312, Val Loss: 25594.7255
# Epoch [23/200], Train Loss: 7777.5801, Val Loss: 21229.0876
# Epoch [24/200], Train Loss: 7639.1318, Val Loss: 20515.4458
# Epoch [25/200], Train Loss: 7605.9317, Val Loss: 21149.0986
# Epoch [26/200], Train Loss: 7566.7527, Val Loss: 23541.2904
# Epoch [27/200], Train Loss: 7693.5832, Val Loss: 19831.4435
# Epoch [28/200], Train Loss: 7684.9513, Val Loss: 26028.7925
# Epoch [29/200], Train Loss: 7849.4471, Val Loss: 26960.3222
# Epoch [30/200], Train Loss: 8105.4878, Val Loss: 23241.1083
# Epoch [31/200], Train Loss: 8188.5596, Val Loss: 23799.0463
# Epoch [32/200], Train Loss: 8077.8833, Val Loss: 24900.7729
# Epoch [33/200], Train Loss: 8010.5405, Val Loss: 23973.6434
# Epoch [34/200], Train Loss: 7932.5435, Val Loss: 24897.5403
# Epoch [35/200], Train Loss: 7947.8163, Val Loss: 24418.0111
# Epoch [36/200], Train Loss: 7871.7363, Val Loss: 24968.0335
# Epoch [37/200], Train Loss: 7955.6760, Val Loss: 21454.5742
# Epoch [38/200], Train Loss: 7818.3086, Val Loss: 24066.1784
# Epoch [39/200], Train Loss: 7932.3705, Val Loss: 23927.2095
# Epoch [40/200], Train Loss: 7888.3189, Val Loss: 26774.6884
# Epoch [41/200], Train Loss: 7862.1096, Val Loss: 24035.6238
# Epoch [42/200], Train Loss: 8059.1810, Val Loss: 24899.5881
# Epoch [43/200], Train Loss: 8043.6807, Val Loss: 26193.0061
# Epoch [44/200], Train Loss: 7855.2328, Val Loss: 26869.5606
# Epoch [45/200], Train Loss: 7678.4137, Val Loss: 19654.0353
# Epoch [46/200], Train Loss: 7544.9026, Val Loss: 21482.4682
# Epoch [47/200], Train Loss: 7896.7011, Val Loss: 20133.7547
# Epoch [48/200], Train Loss: 7620.1121, Val Loss: 25150.4452
# Epoch [49/200], Train Loss: 7541.4645, Val Loss: 20346.7380
# Epoch [50/200], Train Loss: 7650.5387, Val Loss: 21057.8828
# Epoch [51/200], Train Loss: 7505.2866, Val Loss: 18672.0164
# Epoch [52/200], Train Loss: 8406.5390, Val Loss: 33685.9769
# Epoch [53/200], Train Loss: 7971.3937, Val Loss: 20182.8164
# Epoch [54/200], Train Loss: 7524.7033, Val Loss: 19434.8354
# Epoch [55/200], Train Loss: 7430.5778, Val Loss: 18735.4005
# Epoch [56/200], Train Loss: 7232.1234, Val Loss: 20438.7942
# Epoch [57/200], Train Loss: 7320.8366, Val Loss: 18076.2894
# Epoch [58/200], Train Loss: 7378.2602, Val Loss: 23611.0435
# Epoch [59/200], Train Loss: 7342.5232, Val Loss: 21297.5763
# Epoch [60/200], Train Loss: 7279.9935, Val Loss: 22700.7982
# Epoch [61/200], Train Loss: 7380.8832, Val Loss: 17566.0482
# Epoch [62/200], Train Loss: 7357.8460, Val Loss: 19589.2542
# Epoch [63/200], Train Loss: 7119.6248, Val Loss: 20181.0434
# Epoch [64/200], Train Loss: 7157.6442, Val Loss: 23025.2672
# Epoch [65/200], Train Loss: 7090.1546, Val Loss: 19927.8892
# Epoch [66/200], Train Loss: 7072.1539, Val Loss: 19111.5734
# Epoch [67/200], Train Loss: 6971.9972, Val Loss: 19227.1842
# Epoch [68/200], Train Loss: 6867.3387, Val Loss: 18844.1631
# Epoch [69/200], Train Loss: 6911.7228, Val Loss: 19448.7689
# Epoch [70/200], Train Loss: 7061.2611, Val Loss: 20627.2656
# Epoch [71/200], Train Loss: 7170.2109, Val Loss: 17312.7317
# Epoch [72/200], Train Loss: 7595.3310, Val Loss: 17714.5911
# Epoch [73/200], Train Loss: 7519.8177, Val Loss: 20851.9249
# Epoch [74/200], Train Loss: 7140.4879, Val Loss: 16071.6494
# Epoch [75/200], Train Loss: 6896.2963, Val Loss: 17546.2910
# Epoch [76/200], Train Loss: 6998.7923, Val Loss: 17228.9735
# Epoch [77/200], Train Loss: 6713.9030, Val Loss: 16517.0161
# Epoch [78/200], Train Loss: 6573.7132, Val Loss: 16353.5875
# Epoch [79/200], Train Loss: 6563.7646, Val Loss: 17928.5825
# Epoch [80/200], Train Loss: 6217.0818, Val Loss: 19023.1445
# Epoch [81/200], Train Loss: 6203.2641, Val Loss: 21096.6105
# Epoch [82/200], Train Loss: 6134.8259, Val Loss: 18027.8533
# Epoch [83/200], Train Loss: 6097.9385, Val Loss: 19543.2044
# Epoch [84/200], Train Loss: 6059.1923, Val Loss: 20252.2689
# Epoch [85/200], Train Loss: 5999.5093, Val Loss: 23330.6624
# Epoch [86/200], Train Loss: 6087.2771, Val Loss: 21929.6733
# Epoch [87/200], Train Loss: 6172.5283, Val Loss: 15259.7615
# Epoch [88/200], Train Loss: 5986.9045, Val Loss: 22153.8980
# Epoch [89/200], Train Loss: 6001.1099, Val Loss: 16811.5112
# Epoch [90/200], Train Loss: 5831.1340, Val Loss: 16830.8730
# Epoch [91/200], Train Loss: 5829.1786, Val Loss: 17108.8341
# Epoch [92/200], Train Loss: 5749.6532, Val Loss: 15891.4041
# Epoch [93/200], Train Loss: 5759.2310, Val Loss: 15418.7769
# Epoch [94/200], Train Loss: 5860.0025, Val Loss: 17411.1512
# Epoch [95/200], Train Loss: 6091.0995, Val Loss: 16636.4551
# Epoch [96/200], Train Loss: 5959.6134, Val Loss: 17862.3749
# Epoch [97/200], Train Loss: 5890.7362, Val Loss: 14122.4783
# Epoch [98/200], Train Loss: 5836.1598, Val Loss: 15856.3341
# Epoch [99/200], Train Loss: 5854.8690, Val Loss: 15865.6611
# Epoch [100/200], Train Loss: 5795.1187, Val Loss: 16952.4373
# Epoch [101/200], Train Loss: 5578.1139, Val Loss: 17649.7584
# Epoch [102/200], Train Loss: 5519.2659, Val Loss: 17561.5930
# Epoch [103/200], Train Loss: 5486.5202, Val Loss: 17466.4887
# Epoch [104/200], Train Loss: 5453.1498, Val Loss: 17373.5919
# Epoch [105/200], Train Loss: 5447.1830, Val Loss: 17755.6966
# Epoch [106/200], Train Loss: 5412.9942, Val Loss: 17335.9130
# Epoch [107/200], Train Loss: 5433.5803, Val Loss: 17239.4941
# Epoch [108/200], Train Loss: 5390.6085, Val Loss: 16590.7906
# Epoch [109/200], Train Loss: 5381.4605, Val Loss: 17009.0679
# Epoch [110/200], Train Loss: 5399.9650, Val Loss: 18035.1478
# Epoch [111/200], Train Loss: 5367.7598, Val Loss: 17255.0842
# Epoch [112/200], Train Loss: 5333.3929, Val Loss: 17512.3482
# Epoch [113/200], Train Loss: 5338.7347, Val Loss: 17257.9507
# Epoch [114/200], Train Loss: 5348.7632, Val Loss: 16898.9388
# Epoch [115/200], Train Loss: 5323.7370, Val Loss: 16626.3159
# Epoch [116/200], Train Loss: 5331.9701, Val Loss: 17037.2063
# Epoch [117/200], Train Loss: 5338.1739, Val Loss: 16923.2193
# Epoch [118/200], Train Loss: 5285.0458, Val Loss: 16964.3416
# Epoch [119/200], Train Loss: 5291.4571, Val Loss: 16943.7358
# Epoch [120/200], Train Loss: 5295.4623, Val Loss: 17268.8767
# Epoch [121/200], Train Loss: 5301.3945, Val Loss: 17376.1248
# Epoch [122/200], Train Loss: 5288.9651, Val Loss: 17267.1367
# Epoch [123/200], Train Loss: 5294.6117, Val Loss: 17512.5553
# Epoch [124/200], Train Loss: 5266.9169, Val Loss: 17105.1435
# Epoch [125/200], Train Loss: 5258.0614, Val Loss: 16693.0403
# Epoch [126/200], Train Loss: 5248.9070, Val Loss: 17315.5921
# Epoch [127/200], Train Loss: 5254.4514, Val Loss: 17439.1091
# Epoch [128/200], Train Loss: 5239.6895, Val Loss: 17214.2162
# Epoch [129/200], Train Loss: 5240.8858, Val Loss: 17232.9478
# Epoch [130/200], Train Loss: 5254.7998, Val Loss: 17168.1883
# Epoch [131/200], Train Loss: 5227.1934, Val Loss: 17606.8181
# Epoch [132/200], Train Loss: 5238.4581, Val Loss: 17533.0099
# Epoch [133/200], Train Loss: 5218.1225, Val Loss: 17637.8070
# Epoch [134/200], Train Loss: 5220.1605, Val Loss: 17173.2352
# Epoch [135/200], Train Loss: 5248.4202, Val Loss: 17775.1911
# Epoch [136/200], Train Loss: 5200.1875, Val Loss: 16914.3743
# Epoch [137/200], Train Loss: 5210.6622, Val Loss: 16993.5157
# Epoch [138/200], Train Loss: 5209.7643, Val Loss: 16947.8485
# Epoch [139/200], Train Loss: 5211.2087, Val Loss: 16995.7428
# Epoch [140/200], Train Loss: 5183.5515, Val Loss: 17481.3515
# Epoch [141/200], Train Loss: 5203.0943, Val Loss: 17416.6508
# Epoch [142/200], Train Loss: 5179.8359, Val Loss: 17483.3338
# Epoch [143/200], Train Loss: 5204.3594, Val Loss: 17272.0412
# Epoch [144/200], Train Loss: 5177.7533, Val Loss: 17283.6565
# Epoch [145/200], Train Loss: 5201.1852, Val Loss: 17319.3774
# Epoch [146/200], Train Loss: 5186.6656, Val Loss: 17455.3224
# Epoch [147/200], Train Loss: 5170.8006, Val Loss: 17412.8331
# Epoch [148/200], Train Loss: 5182.8636, Val Loss: 17338.0121
# Epoch [149/200], Train Loss: 5178.6067, Val Loss: 17247.1349
# Epoch [150/200], Train Loss: 5181.1214, Val Loss: 17176.4467
# Epoch [151/200], Train Loss: 5165.7152, Val Loss: 17222.2787
# Epoch [152/200], Train Loss: 5163.1206, Val Loss: 16726.3594
# Epoch [153/200], Train Loss: 5145.8442, Val Loss: 17618.9860
# Epoch [154/200], Train Loss: 5152.3133, Val Loss: 17422.8002
# Epoch [155/200], Train Loss: 5197.3770, Val Loss: 17472.3684
# Epoch [156/200], Train Loss: 5170.3524, Val Loss: 16962.0850
# Epoch [157/200], Train Loss: 5133.4413, Val Loss: 17157.0073
# Epoch [158/200], Train Loss: 5183.8853, Val Loss: 17055.5072
# Epoch [159/200], Train Loss: 5148.6692, Val Loss: 17153.0983
# Epoch [160/200], Train Loss: 5144.1303, Val Loss: 16756.7044
# Epoch [161/200], Train Loss: 5157.6474, Val Loss: 16859.9673
# Epoch [162/200], Train Loss: 5152.1523, Val Loss: 16479.1194
# Epoch [163/200], Train Loss: 5136.5369, Val Loss: 17464.5466
# Epoch [164/200], Train Loss: 5123.9388, Val Loss: 17448.3829
# Epoch [165/200], Train Loss: 5131.8720, Val Loss: 17117.3192
# Epoch [166/200], Train Loss: 5148.4872, Val Loss: 17441.3487
# Epoch [167/200], Train Loss: 5124.7465, Val Loss: 16970.5257
# Epoch [168/200], Train Loss: 5123.4379, Val Loss: 16797.9796
# Epoch [169/200], Train Loss: 5112.1264, Val Loss: 17070.2800
# Epoch [170/200], Train Loss: 5106.9475, Val Loss: 17064.9338
# Epoch [171/200], Train Loss: 5116.5316, Val Loss: 16746.8417
# Epoch [172/200], Train Loss: 5113.1965, Val Loss: 16687.4295
# Epoch [173/200], Train Loss: 5122.6438, Val Loss: 16205.1569
# Epoch [174/200], Train Loss: 5095.6882, Val Loss: 16622.0602
# Epoch [175/200], Train Loss: 5091.9173, Val Loss: 16728.5389
# Epoch [176/200], Train Loss: 5115.6871, Val Loss: 16789.9524
# Epoch [177/200], Train Loss: 5084.4252, Val Loss: 17262.6407
# Epoch [178/200], Train Loss: 5105.6582, Val Loss: 16158.6299
# Epoch [179/200], Train Loss: 5141.8552, Val Loss: 16898.2326
# Epoch [180/200], Train Loss: 5106.7892, Val Loss: 17307.7452
# Epoch [181/200], Train Loss: 5101.6845, Val Loss: 17114.1881
# Epoch [182/200], Train Loss: 5110.0396, Val Loss: 17463.6877
# Epoch [183/200], Train Loss: 5103.6280, Val Loss: 16666.9181
# Epoch [184/200], Train Loss: 5101.9171, Val Loss: 16327.2506
# Epoch [185/200], Train Loss: 5084.8580, Val Loss: 16832.0093
# Epoch [186/200], Train Loss: 5074.0145, Val Loss: 17135.0443
# Epoch [187/200], Train Loss: 5101.6680, Val Loss: 16879.3436
# Epoch [188/200], Train Loss: 5098.3232, Val Loss: 17041.5210
# Epoch [189/200], Train Loss: 5096.0871, Val Loss: 17501.3568
# Epoch [190/200], Train Loss: 5080.0833, Val Loss: 16741.3621
# Epoch [191/200], Train Loss: 5060.6582, Val Loss: 16594.2486
# Epoch [192/200], Train Loss: 5073.0610, Val Loss: 17434.3088
# Epoch [193/200], Train Loss: 5078.6172, Val Loss: 17236.6798
# Epoch [194/200], Train Loss: 5082.8879, Val Loss: 17099.5713
# Epoch [195/200], Train Loss: 5140.0492, Val Loss: 17006.2664
# Epoch [196/200], Train Loss: 5060.9666, Val Loss: 17196.4935
# Epoch [197/200], Train Loss: 5064.8055, Val Loss: 17195.4677
# Epoch [198/200], Train Loss: 5076.9364, Val Loss: 17549.6840
# Epoch [199/200], Train Loss: 5084.0831, Val Loss: 16658.7524
# Epoch [200/200], Train Loss: 5064.4704, Val Loss: 17190.6347
# 正在进行实验 2 ...
# Epoch [1/200], Train Loss: 41027.3091, Val Loss: 72496.7219
# Epoch [2/200], Train Loss: 22963.1305, Val Loss: 56503.6254
# Epoch [3/200], Train Loss: 20339.0105, Val Loss: 55707.1539
# Epoch [4/200], Train Loss: 20243.2510, Val Loss: 56759.4651
# Epoch [5/200], Train Loss: 20203.9472, Val Loss: 54700.6334
# Epoch [6/200], Train Loss: 20173.2602, Val Loss: 55554.8102
# Epoch [7/200], Train Loss: 20168.8557, Val Loss: 55371.7980
# Epoch [8/200], Train Loss: 20144.1282, Val Loss: 55453.9788
# Epoch [9/200], Train Loss: 20144.9131, Val Loss: 56219.1443
# Epoch [10/200], Train Loss: 20150.7954, Val Loss: 55061.9044
# Epoch [11/200], Train Loss: 20140.2627, Val Loss: 55752.4917
# Epoch [12/200], Train Loss: 19972.4072, Val Loss: 52281.6834
# Epoch [13/200], Train Loss: 17054.3106, Val Loss: 45698.0313
# Epoch [14/200], Train Loss: 16070.3185, Val Loss: 47160.4317
# Epoch [15/200], Train Loss: 15921.2838, Val Loss: 43663.1256
# Epoch [16/200], Train Loss: 15828.6433, Val Loss: 44686.7638
# Epoch [17/200], Train Loss: 15794.2064, Val Loss: 41948.3299
# Epoch [18/200], Train Loss: 14382.4714, Val Loss: 33634.8444
# Epoch [19/200], Train Loss: 11637.3294, Val Loss: 32210.7643
# Epoch [20/200], Train Loss: 11486.3043, Val Loss: 35176.6664
# Epoch [21/200], Train Loss: 11422.2357, Val Loss: 34312.4339
# Epoch [22/200], Train Loss: 11392.2151, Val Loss: 32719.2046
# Epoch [23/200], Train Loss: 11414.7068, Val Loss: 33163.1265
# Epoch [24/200], Train Loss: 11463.2409, Val Loss: 32031.7134
# Epoch [25/200], Train Loss: 11432.8882, Val Loss: 32947.9721
# Epoch [26/200], Train Loss: 11454.7274, Val Loss: 35187.4472
# Epoch [27/200], Train Loss: 11473.9530, Val Loss: 34946.8074
# Epoch [28/200], Train Loss: 11596.4707, Val Loss: 30836.9146
# Epoch [29/200], Train Loss: 11498.5443, Val Loss: 34193.7833
# Epoch [30/200], Train Loss: 11581.1330, Val Loss: 33098.2027
# Epoch [31/200], Train Loss: 11898.9815, Val Loss: 32613.9756
# Epoch [32/200], Train Loss: 11762.4268, Val Loss: 32478.4168
# Epoch [33/200], Train Loss: 11737.1189, Val Loss: 33878.3578
# Epoch [34/200], Train Loss: 11698.9816, Val Loss: 32753.1240
# Epoch [35/200], Train Loss: 11804.7187, Val Loss: 33427.5026
# Epoch [36/200], Train Loss: 12287.9608, Val Loss: 32839.7688
# Epoch [37/200], Train Loss: 12422.5837, Val Loss: 32287.0735
# Epoch [38/200], Train Loss: 12138.1894, Val Loss: 32500.9226
# Epoch [39/200], Train Loss: 12124.7386, Val Loss: 31311.1441
# Epoch [40/200], Train Loss: 12092.5254, Val Loss: 33119.8868
# Epoch [41/200], Train Loss: 11772.9445, Val Loss: 32029.4620
# Epoch [42/200], Train Loss: 11235.1809, Val Loss: 30580.4016
# Epoch [43/200], Train Loss: 11140.1294, Val Loss: 27036.0976
# Epoch [44/200], Train Loss: 11095.4285, Val Loss: 27749.6687
# Epoch [45/200], Train Loss: 11071.7513, Val Loss: 30528.3613
# Epoch [46/200], Train Loss: 11291.6683, Val Loss: 32919.9072
# Epoch [47/200], Train Loss: 11275.7871, Val Loss: 28895.6020
# Epoch [48/200], Train Loss: 10535.8932, Val Loss: 27486.2087
# Epoch [49/200], Train Loss: 10198.6578, Val Loss: 24379.7776
# Epoch [50/200], Train Loss: 10183.0535, Val Loss: 27083.9218
# Epoch [51/200], Train Loss: 9984.6665, Val Loss: 27319.0485
# Epoch [52/200], Train Loss: 9928.8216, Val Loss: 27903.2442
# Epoch [53/200], Train Loss: 9822.3960, Val Loss: 26087.4194
# Epoch [54/200], Train Loss: 9825.6763, Val Loss: 25074.4851
# Epoch [55/200], Train Loss: 9777.7604, Val Loss: 24115.2972
# Epoch [56/200], Train Loss: 9779.9796, Val Loss: 24739.7070
# Epoch [57/200], Train Loss: 9734.3823, Val Loss: 28075.7720
# Epoch [58/200], Train Loss: 9842.5268, Val Loss: 26822.2876
# Epoch [59/200], Train Loss: 9713.3224, Val Loss: 25346.1202
# Epoch [60/200], Train Loss: 9637.6886, Val Loss: 27012.8977
# Epoch [61/200], Train Loss: 9687.9500, Val Loss: 26043.0404
# Epoch [62/200], Train Loss: 9577.5097, Val Loss: 25796.3048
# Epoch [63/200], Train Loss: 9533.5321, Val Loss: 27904.1415
# Epoch [64/200], Train Loss: 9617.6321, Val Loss: 22857.6682
# Epoch [65/200], Train Loss: 9652.4705, Val Loss: 27687.7689
# Epoch [66/200], Train Loss: 9808.2383, Val Loss: 26343.1250
# Epoch [67/200], Train Loss: 9566.8114, Val Loss: 27398.6857
# Epoch [68/200], Train Loss: 9533.5601, Val Loss: 22892.7578
# Epoch [69/200], Train Loss: 9489.9194, Val Loss: 21872.5886
# Epoch [70/200], Train Loss: 9537.9251, Val Loss: 24156.5602
# Epoch [71/200], Train Loss: 9440.1886, Val Loss: 21677.9958
# Epoch [72/200], Train Loss: 9431.2108, Val Loss: 25163.8981
# Epoch [73/200], Train Loss: 9477.2694, Val Loss: 23452.8974
# Epoch [74/200], Train Loss: 9386.3155, Val Loss: 24215.7965
# Epoch [75/200], Train Loss: 9415.3440, Val Loss: 27374.2064
# Epoch [76/200], Train Loss: 9380.2819, Val Loss: 23893.7257
# Epoch [77/200], Train Loss: 9378.7117, Val Loss: 24762.8329
# Epoch [78/200], Train Loss: 9746.8123, Val Loss: 25969.7254
# Epoch [79/200], Train Loss: 9669.0258, Val Loss: 26982.2044
# Epoch [80/200], Train Loss: 9464.5160, Val Loss: 22257.7715
# Epoch [81/200], Train Loss: 9550.3267, Val Loss: 23880.8046
# Epoch [82/200], Train Loss: 9995.3005, Val Loss: 27455.3464
# Epoch [83/200], Train Loss: 9888.8581, Val Loss: 21719.9829
# Epoch [84/200], Train Loss: 9814.8819, Val Loss: 25013.5402
# Epoch [85/200], Train Loss: 9985.2985, Val Loss: 26134.8048
# Epoch [86/200], Train Loss: 9913.5384, Val Loss: 21089.5651
# Epoch [87/200], Train Loss: 9694.4918, Val Loss: 21717.9047
# Epoch [88/200], Train Loss: 9679.7127, Val Loss: 25985.3736
# Epoch [89/200], Train Loss: 9571.1204, Val Loss: 24969.1425
# Epoch [90/200], Train Loss: 9465.3131, Val Loss: 23415.9681
# Epoch [91/200], Train Loss: 9463.5671, Val Loss: 24856.2901
# Epoch [92/200], Train Loss: 9507.6474, Val Loss: 24461.3903
# Epoch [93/200], Train Loss: 9639.0288, Val Loss: 22262.5804
# Epoch [94/200], Train Loss: 9595.8369, Val Loss: 23788.3834
# Epoch [95/200], Train Loss: 9667.3882, Val Loss: 23014.5949
# Epoch [96/200], Train Loss: 9686.1261, Val Loss: 20391.5150
# Epoch [97/200], Train Loss: 9477.5132, Val Loss: 26997.6611
# Epoch [98/200], Train Loss: 9445.3113, Val Loss: 24279.0441
# Epoch [99/200], Train Loss: 9462.9091, Val Loss: 24739.2053
# Epoch [100/200], Train Loss: 9558.4747, Val Loss: 22167.5289
# Epoch [101/200], Train Loss: 9213.2620, Val Loss: 21769.0291
# Epoch [102/200], Train Loss: 9104.6249, Val Loss: 22014.7544
# Epoch [103/200], Train Loss: 9042.5449, Val Loss: 22358.7104
# Epoch [104/200], Train Loss: 8980.1473, Val Loss: 21857.3447
# Epoch [105/200], Train Loss: 8897.2721, Val Loss: 22401.7559
# Epoch [106/200], Train Loss: 8882.1532, Val Loss: 21839.7637
# Epoch [107/200], Train Loss: 8890.9894, Val Loss: 21997.2928
# Epoch [108/200], Train Loss: 8857.8341, Val Loss: 21674.2882
# Epoch [109/200], Train Loss: 8796.9446, Val Loss: 21714.9073
# Epoch [110/200], Train Loss: 8780.3422, Val Loss: 21663.5939
# Epoch [111/200], Train Loss: 8766.2177, Val Loss: 21970.5320
# Epoch [112/200], Train Loss: 8738.9566, Val Loss: 21480.6658
# Epoch [113/200], Train Loss: 8697.4138, Val Loss: 22034.6326
# Epoch [114/200], Train Loss: 8725.4715, Val Loss: 21753.9787
# Epoch [115/200], Train Loss: 8681.7705, Val Loss: 21696.7143
# Epoch [116/200], Train Loss: 8665.5667, Val Loss: 21948.7816
# Epoch [117/200], Train Loss: 8684.9224, Val Loss: 22118.8668
# Epoch [118/200], Train Loss: 8624.7039, Val Loss: 22183.2465
# Epoch [119/200], Train Loss: 8632.2254, Val Loss: 22205.1413
# Epoch [120/200], Train Loss: 8620.4657, Val Loss: 21495.6747
# Epoch [121/200], Train Loss: 8622.4148, Val Loss: 21742.7137
# Epoch [122/200], Train Loss: 8608.4463, Val Loss: 21681.2148
# Epoch [123/200], Train Loss: 8601.4186, Val Loss: 21588.1076
# Epoch [124/200], Train Loss: 8560.1158, Val Loss: 21906.4309
# Epoch [125/200], Train Loss: 8537.6565, Val Loss: 22003.6520
# Epoch [126/200], Train Loss: 8536.8135, Val Loss: 22091.2098
# Epoch [127/200], Train Loss: 8550.6008, Val Loss: 22506.2666
# Epoch [128/200], Train Loss: 8532.5341, Val Loss: 21690.9103
# Epoch [129/200], Train Loss: 8509.5796, Val Loss: 21605.3057
# Epoch [130/200], Train Loss: 8482.4891, Val Loss: 22507.0953
# Epoch [131/200], Train Loss: 8481.7656, Val Loss: 21827.8989
# Epoch [132/200], Train Loss: 8506.1342, Val Loss: 21268.4706
# Epoch [133/200], Train Loss: 8510.5521, Val Loss: 21855.9138
# Epoch [134/200], Train Loss: 8494.1883, Val Loss: 22260.9901
# Epoch [135/200], Train Loss: 8504.3699, Val Loss: 21573.2739
# Epoch [136/200], Train Loss: 8465.1882, Val Loss: 21553.7471
# Epoch [137/200], Train Loss: 8468.8803, Val Loss: 21840.6329
# Epoch [138/200], Train Loss: 8426.1555, Val Loss: 21765.5417
# Epoch [139/200], Train Loss: 8400.2974, Val Loss: 21900.6760
# Epoch [140/200], Train Loss: 8422.8474, Val Loss: 21582.1909
# Epoch [141/200], Train Loss: 8408.0102, Val Loss: 21677.3521
# Epoch [142/200], Train Loss: 8419.4123, Val Loss: 21327.3711
# Epoch [143/200], Train Loss: 8388.2078, Val Loss: 21354.1933
# Epoch [144/200], Train Loss: 8395.7323, Val Loss: 21096.9397
# Epoch [145/200], Train Loss: 8380.6861, Val Loss: 21959.9836
# Epoch [146/200], Train Loss: 8393.1309, Val Loss: 21992.0748
# Epoch [147/200], Train Loss: 8393.3407, Val Loss: 21614.7439
# Epoch [148/200], Train Loss: 8364.9201, Val Loss: 21109.8093
# Epoch [149/200], Train Loss: 8347.6140, Val Loss: 21375.4108
# Epoch [150/200], Train Loss: 8336.8125, Val Loss: 21715.5736
# Epoch [151/200], Train Loss: 8320.9086, Val Loss: 21985.4657
# Epoch [152/200], Train Loss: 8347.3841, Val Loss: 21707.6927
# Epoch [153/200], Train Loss: 8338.9830, Val Loss: 22319.9323
# Epoch [154/200], Train Loss: 8330.8812, Val Loss: 21777.6797
# Epoch [155/200], Train Loss: 8316.6954, Val Loss: 21694.2406
# Epoch [156/200], Train Loss: 8328.5589, Val Loss: 21703.0296
# Epoch [157/200], Train Loss: 8295.9553, Val Loss: 21218.3256
# Epoch [158/200], Train Loss: 8313.1956, Val Loss: 21601.9767
# Epoch [159/200], Train Loss: 8281.5513, Val Loss: 21523.7668
# Epoch [160/200], Train Loss: 8297.5809, Val Loss: 22040.5501
# Epoch [161/200], Train Loss: 8284.0148, Val Loss: 22178.3367
# Epoch [162/200], Train Loss: 8277.3794, Val Loss: 22154.5800
# Epoch [163/200], Train Loss: 8291.4970, Val Loss: 21487.8557
# Epoch [164/200], Train Loss: 8254.8569, Val Loss: 21732.0770
# Epoch [165/200], Train Loss: 8224.7027, Val Loss: 22187.4988
# Epoch [166/200], Train Loss: 8238.6177, Val Loss: 22219.7401
# Epoch [167/200], Train Loss: 8234.4985, Val Loss: 21994.9218
# Epoch [168/200], Train Loss: 8230.4022, Val Loss: 22050.3221
# Epoch [169/200], Train Loss: 8250.2501, Val Loss: 21757.8981
# Epoch [170/200], Train Loss: 8225.0883, Val Loss: 21870.5498
# Epoch [171/200], Train Loss: 8236.3048, Val Loss: 21670.2858
# Epoch [172/200], Train Loss: 8210.7596, Val Loss: 21947.1110
# Epoch [173/200], Train Loss: 8194.3547, Val Loss: 22104.9157
# Epoch [174/200], Train Loss: 8168.0510, Val Loss: 22178.1696
# Epoch [175/200], Train Loss: 8195.8454, Val Loss: 22221.2930
# Epoch [176/200], Train Loss: 8193.1497, Val Loss: 21866.9507
# Epoch [177/200], Train Loss: 8173.4173, Val Loss: 22048.0580
# Epoch [178/200], Train Loss: 8156.6504, Val Loss: 22272.1786
# Epoch [179/200], Train Loss: 8172.5183, Val Loss: 21859.8330
# Epoch [180/200], Train Loss: 8161.3623, Val Loss: 22261.1032
# Epoch [181/200], Train Loss: 8150.3452, Val Loss: 21948.1131
# Epoch [182/200], Train Loss: 8174.6259, Val Loss: 21788.6010
# Epoch [183/200], Train Loss: 8185.8296, Val Loss: 21724.3205
# Epoch [184/200], Train Loss: 8151.4947, Val Loss: 22649.7835
# Epoch [185/200], Train Loss: 8143.1105, Val Loss: 21824.2162
# Epoch [186/200], Train Loss: 8148.6051, Val Loss: 21207.8480
# Epoch [187/200], Train Loss: 8121.1683, Val Loss: 21851.5425
# Epoch [188/200], Train Loss: 8116.0741, Val Loss: 22374.7351
# Epoch [189/200], Train Loss: 8103.7983, Val Loss: 22667.1303
# Epoch [190/200], Train Loss: 8129.6757, Val Loss: 21407.5118
# Epoch [191/200], Train Loss: 8134.4537, Val Loss: 21856.2237
# Epoch [192/200], Train Loss: 8116.7788, Val Loss: 21840.8031
# Epoch [193/200], Train Loss: 8087.3621, Val Loss: 21760.4148
# Epoch [194/200], Train Loss: 8106.0746, Val Loss: 21873.5251
# Epoch [195/200], Train Loss: 8110.6730, Val Loss: 21355.3332
# Epoch [196/200], Train Loss: 8077.7429, Val Loss: 21543.6912
# Epoch [197/200], Train Loss: 8092.0563, Val Loss: 22276.0581
# Epoch [198/200], Train Loss: 8073.1123, Val Loss: 21915.0978
# Epoch [199/200], Train Loss: 8071.0355, Val Loss: 22021.5111
# Epoch [200/200], Train Loss: 8037.5642, Val Loss: 22275.1866
# 正在进行实验 3 ...
# Epoch [1/200], Train Loss: 40260.5610, Val Loss: 83554.5992
# Epoch [2/200], Train Loss: 17619.1234, Val Loss: 34629.2674
# Epoch [3/200], Train Loss: 11070.8383, Val Loss: 27483.9694
# Epoch [4/200], Train Loss: 9638.9562, Val Loss: 28244.4835
# Epoch [5/200], Train Loss: 9139.4879, Val Loss: 26519.0775
# Epoch [6/200], Train Loss: 8913.6577, Val Loss: 26226.8455
# Epoch [7/200], Train Loss: 8656.6399, Val Loss: 24606.6277
# Epoch [8/200], Train Loss: 7994.9219, Val Loss: 24609.8059
# Epoch [9/200], Train Loss: 7754.3025, Val Loss: 24031.1880
# Epoch [10/200], Train Loss: 7613.8904, Val Loss: 26359.4453
# Epoch [11/200], Train Loss: 7502.9046, Val Loss: 25069.3526
# Epoch [12/200], Train Loss: 7398.0771, Val Loss: 24138.3584
# Epoch [13/200], Train Loss: 7364.3998, Val Loss: 22598.5804
# Epoch [14/200], Train Loss: 7328.4391, Val Loss: 23976.3928
# Epoch [15/200], Train Loss: 7278.1821, Val Loss: 23255.1895
# Epoch [16/200], Train Loss: 6890.6800, Val Loss: 23836.3578
# Epoch [17/200], Train Loss: 6498.7451, Val Loss: 23221.6284
# Epoch [18/200], Train Loss: 6374.4987, Val Loss: 19854.6758
# Epoch [19/200], Train Loss: 6200.1107, Val Loss: 19946.4562
# Epoch [20/200], Train Loss: 6103.7712, Val Loss: 17596.8521
# Epoch [21/200], Train Loss: 6024.4988, Val Loss: 18830.8884
# Epoch [22/200], Train Loss: 5989.4535, Val Loss: 18245.7111
# Epoch [23/200], Train Loss: 5896.4238, Val Loss: 18003.3914
# Epoch [24/200], Train Loss: 5644.3383, Val Loss: 22620.3071
# Epoch [25/200], Train Loss: 5544.8050, Val Loss: 19020.4998
# Epoch [26/200], Train Loss: 5507.9591, Val Loss: 18008.3352
# Epoch [27/200], Train Loss: 5463.7155, Val Loss: 16744.8541
# Epoch [28/200], Train Loss: 5456.5279, Val Loss: 17579.4423
# Epoch [29/200], Train Loss: 5389.8493, Val Loss: 18109.1117
# Epoch [30/200], Train Loss: 5456.0256, Val Loss: 15541.8494
# Epoch [31/200], Train Loss: 5500.8363, Val Loss: 18948.4663
# Epoch [32/200], Train Loss: 5376.3823, Val Loss: 17972.8956
# Epoch [33/200], Train Loss: 5427.2914, Val Loss: 18454.2429
# Epoch [34/200], Train Loss: 5431.2498, Val Loss: 16993.8008
# Epoch [35/200], Train Loss: 5407.1643, Val Loss: 16434.0832
# Epoch [36/200], Train Loss: 5406.5304, Val Loss: 16018.3129
# Epoch [37/200], Train Loss: 5842.4830, Val Loss: 17830.8274
# Epoch [38/200], Train Loss: 5699.9098, Val Loss: 18161.4074
# Epoch [39/200], Train Loss: 5658.9775, Val Loss: 14274.4418
# Epoch [40/200], Train Loss: 5523.4688, Val Loss: 14150.2487
# Epoch [41/200], Train Loss: 5594.4566, Val Loss: 15412.1229
# Epoch [42/200], Train Loss: 8172.7106, Val Loss: 18465.8535
# Epoch [43/200], Train Loss: 6222.6672, Val Loss: 18785.3748
# Epoch [44/200], Train Loss: 5914.7797, Val Loss: 14244.7085
# Epoch [45/200], Train Loss: 5816.1023, Val Loss: 14070.4665
# Epoch [46/200], Train Loss: 5606.2378, Val Loss: 15753.5194
# Epoch [47/200], Train Loss: 5597.1816, Val Loss: 14839.1165
# Epoch [48/200], Train Loss: 5506.6353, Val Loss: 16314.8271
# Epoch [49/200], Train Loss: 5615.2634, Val Loss: 13405.0442
# Epoch [50/200], Train Loss: 5971.7639, Val Loss: 15003.3101
# Epoch [51/200], Train Loss: 5894.3912, Val Loss: 15536.1701
# Epoch [52/200], Train Loss: 5838.2500, Val Loss: 13966.9082
# Epoch [53/200], Train Loss: 5773.9137, Val Loss: 14363.6096
# Epoch [54/200], Train Loss: 5954.3865, Val Loss: 15045.5610
# Epoch [55/200], Train Loss: 6192.7099, Val Loss: 15078.1457
# Epoch [56/200], Train Loss: 6277.1745, Val Loss: 16408.9781
# Epoch [57/200], Train Loss: 5970.1253, Val Loss: 14857.8872
# Epoch [58/200], Train Loss: 5872.1948, Val Loss: 15103.2412
# Epoch [59/200], Train Loss: 5889.9876, Val Loss: 13952.7424
# Epoch [60/200], Train Loss: 6171.0415, Val Loss: 13910.5552
# Epoch [61/200], Train Loss: 5973.2570, Val Loss: 13727.6429
# Epoch [62/200], Train Loss: 5950.1112, Val Loss: 13645.9212
# Epoch [63/200], Train Loss: 6189.6772, Val Loss: 14111.0685
# Epoch [64/200], Train Loss: 5980.9615, Val Loss: 18948.5091
# Epoch [65/200], Train Loss: 6032.1549, Val Loss: 21712.1548
# Epoch [66/200], Train Loss: 5908.8133, Val Loss: 18178.8120
# Epoch [67/200], Train Loss: 5959.5927, Val Loss: 15167.2738
# Epoch [68/200], Train Loss: 5903.3733, Val Loss: 14565.4759
# Epoch [69/200], Train Loss: 5977.8189, Val Loss: 13436.7260
# Epoch [70/200], Train Loss: 5977.8134, Val Loss: 17022.1773
# Epoch [71/200], Train Loss: 5996.1267, Val Loss: 13705.8342
# Epoch [72/200], Train Loss: 6299.5802, Val Loss: 14107.4673
# Epoch [73/200], Train Loss: 6064.6821, Val Loss: 13340.6594
# Epoch [74/200], Train Loss: 6149.9117, Val Loss: 13125.0118
# Epoch [75/200], Train Loss: 6256.0211, Val Loss: 15050.2753
# Epoch [76/200], Train Loss: 6117.1694, Val Loss: 15065.9910
# Epoch [77/200], Train Loss: 6646.7847, Val Loss: 17097.9710
# Epoch [78/200], Train Loss: 7206.5950, Val Loss: 18756.4618
# Epoch [79/200], Train Loss: 6582.9596, Val Loss: 14678.0596
# Epoch [80/200], Train Loss: 6539.1564, Val Loss: 13856.6255
# Epoch [81/200], Train Loss: 6246.7395, Val Loss: 15304.8730
# Epoch [82/200], Train Loss: 6337.4009, Val Loss: 17416.4303
# Epoch [83/200], Train Loss: 6179.3901, Val Loss: 17019.2626
# Epoch [84/200], Train Loss: 6470.3458, Val Loss: 15971.8625
# Epoch [85/200], Train Loss: 6749.7846, Val Loss: 15847.9669
# Epoch [86/200], Train Loss: 6861.1485, Val Loss: 16179.7506
# Epoch [87/200], Train Loss: 6819.6890, Val Loss: 13613.6679
# Epoch [88/200], Train Loss: 7232.5229, Val Loss: 13792.3963
# Epoch [89/200], Train Loss: 6895.3137, Val Loss: 12833.3584
# Epoch [90/200], Train Loss: 7253.6888, Val Loss: 36587.1066
# Epoch [91/200], Train Loss: 8555.8837, Val Loss: 19744.0542
# Epoch [92/200], Train Loss: 9419.0782, Val Loss: 15897.7589
# Epoch [93/200], Train Loss: 10262.9710, Val Loss: 19154.0222
# Epoch [94/200], Train Loss: 7724.3594, Val Loss: 18886.0017
# Epoch [95/200], Train Loss: 6898.6879, Val Loss: 12139.1975
# Epoch [96/200], Train Loss: 6770.3754, Val Loss: 14306.6403
# Epoch [97/200], Train Loss: 7013.5101, Val Loss: 13830.6609
# Epoch [98/200], Train Loss: 6803.1947, Val Loss: 15068.8045
# Epoch [99/200], Train Loss: 6964.3880, Val Loss: 16516.3662
# Epoch [100/200], Train Loss: 12013.9350, Val Loss: 50961.8063
# Epoch [101/200], Train Loss: 17320.7759, Val Loss: 51337.6956
# Epoch [102/200], Train Loss: 16629.1609, Val Loss: 50493.2270
# Epoch [103/200], Train Loss: 15672.8471, Val Loss: 52242.3766
# Epoch [104/200], Train Loss: 15301.7298, Val Loss: 48399.1068
# Epoch [105/200], Train Loss: 13838.1464, Val Loss: 45114.2006
# Epoch [106/200], Train Loss: 12631.8467, Val Loss: 43466.8123
# Epoch [107/200], Train Loss: 12095.1879, Val Loss: 41564.4798
# Epoch [108/200], Train Loss: 11805.4136, Val Loss: 41354.9147
# Epoch [109/200], Train Loss: 11227.7305, Val Loss: 39035.2904
# Epoch [110/200], Train Loss: 11008.5583, Val Loss: 38377.4249
# Epoch [111/200], Train Loss: 10600.5821, Val Loss: 33897.5696
# Epoch [112/200], Train Loss: 10644.5219, Val Loss: 34815.4297
# Epoch [113/200], Train Loss: 11103.8703, Val Loss: 32967.7126
# Epoch [114/200], Train Loss: 10702.8121, Val Loss: 33293.6722
# Epoch [115/200], Train Loss: 10861.1192, Val Loss: 33985.0616
# Epoch [116/200], Train Loss: 10651.0808, Val Loss: 32103.9755
# Epoch [117/200], Train Loss: 10351.3760, Val Loss: 33377.5028
# Epoch [118/200], Train Loss: 10330.5481, Val Loss: 30807.1965
# Epoch [119/200], Train Loss: 9775.8704, Val Loss: 30072.0795
# Epoch [120/200], Train Loss: 10168.1023, Val Loss: 28106.3936
# Epoch [121/200], Train Loss: 9342.6465, Val Loss: 23906.3916
# Epoch [122/200], Train Loss: 8271.3452, Val Loss: 22532.7309
# Epoch [123/200], Train Loss: 7769.8735, Val Loss: 20295.0599
# Epoch [124/200], Train Loss: 7629.3618, Val Loss: 20018.7918
# Epoch [125/200], Train Loss: 7434.1366, Val Loss: 19975.1917
# Epoch [126/200], Train Loss: 7159.5030, Val Loss: 20674.7274
# Epoch [127/200], Train Loss: 6975.7260, Val Loss: 17668.6575
# Epoch [128/200], Train Loss: 6844.8011, Val Loss: 16974.5264
# Epoch [129/200], Train Loss: 6778.6130, Val Loss: 16891.6835
# Epoch [130/200], Train Loss: 6732.6442, Val Loss: 16346.7144
# Epoch [131/200], Train Loss: 6654.7516, Val Loss: 16438.5010
# Epoch [132/200], Train Loss: 6548.5399, Val Loss: 16076.4429
# Epoch [133/200], Train Loss: 6569.5267, Val Loss: 16300.1002
# Epoch [134/200], Train Loss: 6554.8740, Val Loss: 16648.4195
# Epoch [135/200], Train Loss: 6619.3106, Val Loss: 17622.0650
# Epoch [136/200], Train Loss: 6513.0834, Val Loss: 19290.6135
# Epoch [137/200], Train Loss: 6422.6813, Val Loss: 17323.5357
# Epoch [138/200], Train Loss: 6428.5206, Val Loss: 17629.7126
# Epoch [139/200], Train Loss: 6478.6231, Val Loss: 16887.0150
# Epoch [140/200], Train Loss: 6384.3046, Val Loss: 15380.4204
# Epoch [141/200], Train Loss: 6281.9015, Val Loss: 15997.5691
# Epoch [142/200], Train Loss: 6249.3851, Val Loss: 14908.1923
# Epoch [143/200], Train Loss: 6125.7877, Val Loss: 15524.1852
# Epoch [144/200], Train Loss: 6063.9287, Val Loss: 15052.6021
# Epoch [145/200], Train Loss: 5965.1178, Val Loss: 15932.1058
# Epoch [146/200], Train Loss: 6048.9881, Val Loss: 15526.9243
# Epoch [147/200], Train Loss: 6012.3640, Val Loss: 15341.9965
# Epoch [148/200], Train Loss: 5978.5227, Val Loss: 14993.2527
# Epoch [149/200], Train Loss: 5948.1382, Val Loss: 14978.9539
# Epoch [150/200], Train Loss: 5908.3994, Val Loss: 15321.3695
# Epoch [151/200], Train Loss: 5869.4516, Val Loss: 14808.1051
# Epoch [152/200], Train Loss: 5847.7925, Val Loss: 14991.5404
# Epoch [153/200], Train Loss: 5836.7624, Val Loss: 14067.7476
# Epoch [154/200], Train Loss: 5912.3673, Val Loss: 14392.9395
# Epoch [155/200], Train Loss: 5876.1430, Val Loss: 15416.7970
# Epoch [156/200], Train Loss: 6061.4171, Val Loss: 14786.8733
# Epoch [157/200], Train Loss: 5968.4275, Val Loss: 14770.5165
# Epoch [158/200], Train Loss: 6063.3043, Val Loss: 14637.2236
# Epoch [159/200], Train Loss: 6054.0504, Val Loss: 14684.8882
# Epoch [160/200], Train Loss: 5909.2128, Val Loss: 14474.0940
# Epoch [161/200], Train Loss: 5785.7775, Val Loss: 14776.1665
# Epoch [162/200], Train Loss: 5775.9047, Val Loss: 14412.0690
# Epoch [163/200], Train Loss: 5713.6647, Val Loss: 14401.9767
# Epoch [164/200], Train Loss: 5723.4989, Val Loss: 14299.9565
# Epoch [165/200], Train Loss: 5706.3990, Val Loss: 14330.9645
# Epoch [166/200], Train Loss: 5647.9670, Val Loss: 14296.7150
# Epoch [167/200], Train Loss: 5690.8262, Val Loss: 14386.5742
# Epoch [168/200], Train Loss: 5678.7900, Val Loss: 14484.6734
# Epoch [169/200], Train Loss: 5601.0275, Val Loss: 14103.9330
# Epoch [170/200], Train Loss: 5564.4399, Val Loss: 14374.4216
# Epoch [171/200], Train Loss: 5560.1218, Val Loss: 15068.7286
# Epoch [172/200], Train Loss: 5565.7057, Val Loss: 14732.3419
# Epoch [173/200], Train Loss: 5546.1280, Val Loss: 14703.8584
# Epoch [174/200], Train Loss: 5552.0144, Val Loss: 14307.8297
# Epoch [175/200], Train Loss: 5520.7273, Val Loss: 14445.3215
# Epoch [176/200], Train Loss: 5517.9473, Val Loss: 14784.4051
# Epoch [177/200], Train Loss: 5462.3242, Val Loss: 14625.5969
# Epoch [178/200], Train Loss: 5469.0460, Val Loss: 15411.5654
# Epoch [179/200], Train Loss: 5464.8467, Val Loss: 15249.0132
# Epoch [180/200], Train Loss: 5423.1570, Val Loss: 14647.9627
# Epoch [181/200], Train Loss: 5407.3005, Val Loss: 15013.7281
# Epoch [182/200], Train Loss: 5421.9312, Val Loss: 15693.5647
# Epoch [183/200], Train Loss: 5416.1839, Val Loss: 15006.1578
# Epoch [184/200], Train Loss: 5396.9734, Val Loss: 13975.1378
# Epoch [185/200], Train Loss: 5354.3520, Val Loss: 15029.2359
# Epoch [186/200], Train Loss: 5385.7197, Val Loss: 14945.2022
# Epoch [187/200], Train Loss: 5337.2251, Val Loss: 14857.9365
# Epoch [188/200], Train Loss: 5334.2240, Val Loss: 14594.1672
# Epoch [189/200], Train Loss: 5333.9316, Val Loss: 15575.2039
# Epoch [190/200], Train Loss: 5376.9674, Val Loss: 14435.0366
# Epoch [191/200], Train Loss: 5364.5805, Val Loss: 14750.8563
# Epoch [192/200], Train Loss: 5339.8525, Val Loss: 15016.6921
# Epoch [193/200], Train Loss: 5409.3083, Val Loss: 14315.5901
# Epoch [194/200], Train Loss: 5320.4272, Val Loss: 14522.5009
# Epoch [195/200], Train Loss: 5320.4928, Val Loss: 15160.3536
# Epoch [196/200], Train Loss: 5300.5627, Val Loss: 15265.4598
# Epoch [197/200], Train Loss: 5284.7790, Val Loss: 14399.1953
# Epoch [198/200], Train Loss: 5273.9622, Val Loss: 14712.6447
# Epoch [199/200], Train Loss: 5291.0806, Val Loss: 15182.3535
# Epoch [200/200], Train Loss: 5259.3849, Val Loss: 15246.4297
# 正在进行实验 4 ...
# Epoch [1/200], Train Loss: 40126.2320, Val Loss: 60092.8845
# Epoch [2/200], Train Loss: 19762.6799, Val Loss: 40513.2902
# Epoch [3/200], Train Loss: 13102.3183, Val Loss: 36530.3806
# Epoch [4/200], Train Loss: 12047.9268, Val Loss: 30123.7677
# Epoch [5/200], Train Loss: 11777.5594, Val Loss: 31570.1675
# Epoch [6/200], Train Loss: 11541.6587, Val Loss: 32323.4737
# Epoch [7/200], Train Loss: 11317.4692, Val Loss: 31857.1424
# Epoch [8/200], Train Loss: 11179.7251, Val Loss: 30919.5004
# Epoch [9/200], Train Loss: 10273.8032, Val Loss: 27029.5763
# Epoch [10/200], Train Loss: 8965.0112, Val Loss: 23306.9123
# Epoch [11/200], Train Loss: 8659.3600, Val Loss: 24169.4696
# Epoch [12/200], Train Loss: 8506.3754, Val Loss: 24966.5013
# Epoch [13/200], Train Loss: 8420.8976, Val Loss: 23738.0557
# Epoch [14/200], Train Loss: 8361.4172, Val Loss: 23493.7836
# Epoch [15/200], Train Loss: 8038.0547, Val Loss: 20928.3432
# Epoch [16/200], Train Loss: 7510.6718, Val Loss: 23564.9093
# Epoch [17/200], Train Loss: 7447.0999, Val Loss: 20794.8758
# Epoch [18/200], Train Loss: 7391.9876, Val Loss: 21979.2582
# Epoch [19/200], Train Loss: 7323.0563, Val Loss: 22473.3693
# Epoch [20/200], Train Loss: 7317.3104, Val Loss: 22018.8977
# Epoch [21/200], Train Loss: 7266.1628, Val Loss: 23051.2635
# Epoch [22/200], Train Loss: 7246.6745, Val Loss: 23104.5235
# Epoch [23/200], Train Loss: 7062.7812, Val Loss: 20977.2521
# Epoch [24/200], Train Loss: 6545.3949, Val Loss: 20133.7780
# Epoch [25/200], Train Loss: 6478.9196, Val Loss: 17906.5409
# Epoch [26/200], Train Loss: 6370.8146, Val Loss: 19540.2181
# Epoch [27/200], Train Loss: 6224.9860, Val Loss: 18722.4367
# Epoch [28/200], Train Loss: 5960.1485, Val Loss: 17222.6875
# Epoch [29/200], Train Loss: 5681.8931, Val Loss: 18667.0031
# Epoch [30/200], Train Loss: 5501.1812, Val Loss: 16049.3755
# Epoch [31/200], Train Loss: 5410.2407, Val Loss: 15478.0810
# Epoch [32/200], Train Loss: 5332.9728, Val Loss: 17402.7609
# Epoch [33/200], Train Loss: 5266.3786, Val Loss: 16738.3343
# Epoch [34/200], Train Loss: 5203.9653, Val Loss: 17115.3987
# Epoch [35/200], Train Loss: 5127.2321, Val Loss: 17747.8969
# Epoch [36/200], Train Loss: 5075.8446, Val Loss: 13689.9092
# Epoch [37/200], Train Loss: 5001.2724, Val Loss: 16026.1666
# Epoch [38/200], Train Loss: 4981.6175, Val Loss: 15793.1504
# Epoch [39/200], Train Loss: 4892.5647, Val Loss: 14075.3979
# Epoch [40/200], Train Loss: 4900.1328, Val Loss: 16928.4397
# Epoch [41/200], Train Loss: 4844.1751, Val Loss: 17485.3805
# Epoch [42/200], Train Loss: 4881.4577, Val Loss: 17190.4270
# Epoch [43/200], Train Loss: 4886.3942, Val Loss: 17656.0197
# Epoch [44/200], Train Loss: 4878.1461, Val Loss: 14750.0253
# Epoch [45/200], Train Loss: 4879.5960, Val Loss: 15485.9927
# Epoch [46/200], Train Loss: 4834.2950, Val Loss: 14968.8668
# Epoch [47/200], Train Loss: 4791.1147, Val Loss: 18776.5588
# Epoch [48/200], Train Loss: 4745.8094, Val Loss: 15697.4996
# Epoch [49/200], Train Loss: 4738.2877, Val Loss: 17383.0367
# Epoch [50/200], Train Loss: 4672.6856, Val Loss: 14458.9327
# Epoch [51/200], Train Loss: 4697.4693, Val Loss: 16059.6195
# Epoch [52/200], Train Loss: 4671.7438, Val Loss: 16365.7956
# Epoch [53/200], Train Loss: 4625.6638, Val Loss: 16939.7147
# Epoch [54/200], Train Loss: 4616.6786, Val Loss: 17146.2860
# Epoch [55/200], Train Loss: 4676.2629, Val Loss: 18887.3522
# Epoch [56/200], Train Loss: 4687.3543, Val Loss: 15850.2483
# Epoch [57/200], Train Loss: 4659.5792, Val Loss: 14400.3133
# Epoch [58/200], Train Loss: 4602.5139, Val Loss: 17954.0131
# Epoch [59/200], Train Loss: 4636.8455, Val Loss: 15768.1477
# Epoch [60/200], Train Loss: 4633.0878, Val Loss: 14812.6197
# Epoch [61/200], Train Loss: 4626.1410, Val Loss: 14312.2320
# Epoch [62/200], Train Loss: 4617.0404, Val Loss: 19597.6694
# Epoch [63/200], Train Loss: 4606.0852, Val Loss: 15635.1047
# Epoch [64/200], Train Loss: 4706.4679, Val Loss: 18456.1190
# Epoch [65/200], Train Loss: 4579.0681, Val Loss: 20942.7141
# Epoch [66/200], Train Loss: 4703.4353, Val Loss: 17478.2173
# Epoch [67/200], Train Loss: 4647.6246, Val Loss: 17334.0409
# Epoch [68/200], Train Loss: 4721.7135, Val Loss: 14760.9400
# Epoch [69/200], Train Loss: 4709.1550, Val Loss: 14602.1456
# Epoch [70/200], Train Loss: 4717.5481, Val Loss: 13930.2342
# Epoch [71/200], Train Loss: 4689.5951, Val Loss: 14469.2477
# Epoch [72/200], Train Loss: 4653.9994, Val Loss: 17723.5616
# Epoch [73/200], Train Loss: 4886.8691, Val Loss: 18138.3028
# Epoch [74/200], Train Loss: 4727.9631, Val Loss: 20582.9543
# Epoch [75/200], Train Loss: 4788.9009, Val Loss: 17172.7098
# Epoch [76/200], Train Loss: 4756.8988, Val Loss: 15339.4021
# Epoch [77/200], Train Loss: 4702.1420, Val Loss: 17178.6925
# Epoch [78/200], Train Loss: 4682.5697, Val Loss: 17014.5940
# Epoch [79/200], Train Loss: 4762.9647, Val Loss: 19090.7290
# Epoch [80/200], Train Loss: 4862.4434, Val Loss: 15573.0258
# Epoch [81/200], Train Loss: 4729.6038, Val Loss: 15230.6465
# Epoch [82/200], Train Loss: 4827.2580, Val Loss: 14895.9096
# Epoch [83/200], Train Loss: 4729.3418, Val Loss: 16156.5082
# Epoch [84/200], Train Loss: 4805.3000, Val Loss: 14917.9915
# Epoch [85/200], Train Loss: 4847.0273, Val Loss: 13089.4938
# Epoch [86/200], Train Loss: 4887.1058, Val Loss: 12817.7862
# Epoch [87/200], Train Loss: 4936.6454, Val Loss: 12934.8422
# Epoch [88/200], Train Loss: 4863.9630, Val Loss: 16161.1439
# Epoch [89/200], Train Loss: 4960.0857, Val Loss: 16525.4306
# Epoch [90/200], Train Loss: 4998.9480, Val Loss: 17155.2779
# Epoch [91/200], Train Loss: 4910.3402, Val Loss: 17841.6139
# Epoch [92/200], Train Loss: 4952.8276, Val Loss: 12827.9828
# Epoch [93/200], Train Loss: 4916.2465, Val Loss: 16290.5140
# Epoch [94/200], Train Loss: 5227.1119, Val Loss: 13143.4387
# Epoch [95/200], Train Loss: 5016.9565, Val Loss: 17193.4982
# Epoch [96/200], Train Loss: 4996.7907, Val Loss: 16672.1214
# Epoch [97/200], Train Loss: 5179.0868, Val Loss: 15254.3108
# Epoch [98/200], Train Loss: 5302.1249, Val Loss: 15332.2186
# Epoch [99/200], Train Loss: 5279.2431, Val Loss: 16174.6800
# Epoch [100/200], Train Loss: 5183.9718, Val Loss: 19499.4253
# Epoch [101/200], Train Loss: 4915.1487, Val Loss: 16703.9186
# Epoch [102/200], Train Loss: 4583.6452, Val Loss: 15532.8296
# Epoch [103/200], Train Loss: 4494.5694, Val Loss: 15629.6865
# Epoch [104/200], Train Loss: 4441.9533, Val Loss: 14984.7117
# Epoch [105/200], Train Loss: 4385.6907, Val Loss: 15017.0725
# Epoch [106/200], Train Loss: 4338.6327, Val Loss: 15158.5719
# Epoch [107/200], Train Loss: 4277.4561, Val Loss: 14835.6320
# Epoch [108/200], Train Loss: 4258.1060, Val Loss: 15587.7549
# Epoch [109/200], Train Loss: 4278.7474, Val Loss: 16026.0138
# Epoch [110/200], Train Loss: 4201.4766, Val Loss: 14982.4121
# Epoch [111/200], Train Loss: 4186.6264, Val Loss: 14722.7908
# Epoch [112/200], Train Loss: 4187.7956, Val Loss: 14913.0516
# Epoch [113/200], Train Loss: 4142.0059, Val Loss: 15281.7664
# Epoch [114/200], Train Loss: 4093.4108, Val Loss: 15144.6275
# Epoch [115/200], Train Loss: 4123.0703, Val Loss: 15451.5690
# Epoch [116/200], Train Loss: 4063.0975, Val Loss: 15779.2834
# Epoch [117/200], Train Loss: 4089.4090, Val Loss: 15455.2754
# Epoch [118/200], Train Loss: 4055.8134, Val Loss: 15618.5253
# Epoch [119/200], Train Loss: 4031.4103, Val Loss: 15672.9118
# Epoch [120/200], Train Loss: 4022.8903, Val Loss: 15601.6092
# Epoch [121/200], Train Loss: 4027.1445, Val Loss: 15444.1253
# Epoch [122/200], Train Loss: 4019.0672, Val Loss: 15190.7922
# Epoch [123/200], Train Loss: 3982.1705, Val Loss: 15232.9083
# Epoch [124/200], Train Loss: 3966.0051, Val Loss: 15541.1199
# Epoch [125/200], Train Loss: 3950.0383, Val Loss: 15061.0398
# Epoch [126/200], Train Loss: 3921.5151, Val Loss: 15935.3728
# Epoch [127/200], Train Loss: 3911.3225, Val Loss: 15634.0149
# Epoch [128/200], Train Loss: 3922.5430, Val Loss: 16024.8093
# Epoch [129/200], Train Loss: 3911.2175, Val Loss: 15969.1874
# Epoch [130/200], Train Loss: 3894.6831, Val Loss: 15314.2154
# Epoch [131/200], Train Loss: 3900.5237, Val Loss: 15565.3063
# Epoch [132/200], Train Loss: 3875.0244, Val Loss: 15926.0112
# Epoch [133/200], Train Loss: 3896.9404, Val Loss: 14886.8145
# Epoch [134/200], Train Loss: 3909.5121, Val Loss: 14751.5636
# Epoch [135/200], Train Loss: 3889.2443, Val Loss: 14802.2795
# Epoch [136/200], Train Loss: 3846.7580, Val Loss: 15216.3587
# Epoch [137/200], Train Loss: 3848.7163, Val Loss: 15563.7964
# Epoch [138/200], Train Loss: 3840.6488, Val Loss: 14716.3721
# Epoch [139/200], Train Loss: 3809.8168, Val Loss: 14787.1444
# Epoch [140/200], Train Loss: 3815.7392, Val Loss: 14701.4358
# Epoch [141/200], Train Loss: 3800.4072, Val Loss: 15031.3268
# Epoch [142/200], Train Loss: 3816.5210, Val Loss: 14522.6252
# Epoch [143/200], Train Loss: 3795.2685, Val Loss: 15255.6814
# Epoch [144/200], Train Loss: 3802.1242, Val Loss: 15015.9096
# Epoch [145/200], Train Loss: 3805.0289, Val Loss: 15283.8592
# Epoch [146/200], Train Loss: 3784.0722, Val Loss: 15249.2424
# Epoch [147/200], Train Loss: 3760.4335, Val Loss: 15461.4621
# Epoch [148/200], Train Loss: 3758.2686, Val Loss: 15061.3976
# Epoch [149/200], Train Loss: 3723.4923, Val Loss: 15456.3184
# Epoch [150/200], Train Loss: 3719.9510, Val Loss: 15292.7406
# Epoch [151/200], Train Loss: 3746.1316, Val Loss: 14756.8677
# Epoch [152/200], Train Loss: 3717.4901, Val Loss: 15112.2052
# Epoch [153/200], Train Loss: 3757.4405, Val Loss: 14860.2126
# Epoch [154/200], Train Loss: 3697.7109, Val Loss: 15280.3079
# Epoch [155/200], Train Loss: 3693.4143, Val Loss: 15221.6668
# Epoch [156/200], Train Loss: 3731.0743, Val Loss: 15114.2017
# Epoch [157/200], Train Loss: 3705.6762, Val Loss: 14938.2177
# Epoch [158/200], Train Loss: 3673.3805, Val Loss: 14695.5872
# Epoch [159/200], Train Loss: 3710.3022, Val Loss: 15148.8712
# Epoch [160/200], Train Loss: 3675.3007, Val Loss: 15681.8767
# Epoch [161/200], Train Loss: 3708.6714, Val Loss: 15431.7708
# Epoch [162/200], Train Loss: 3667.9571, Val Loss: 14940.4073
# Epoch [163/200], Train Loss: 3656.0912, Val Loss: 14951.7737
# Epoch [164/200], Train Loss: 3672.1742, Val Loss: 15481.3546
# Epoch [165/200], Train Loss: 3695.4587, Val Loss: 15260.0109
# Epoch [166/200], Train Loss: 3653.7610, Val Loss: 15263.0453
# Epoch [167/200], Train Loss: 3656.2134, Val Loss: 15248.7719
# Epoch [168/200], Train Loss: 3660.1210, Val Loss: 15507.7233
# Epoch [169/200], Train Loss: 3656.5200, Val Loss: 15120.2372
# Epoch [170/200], Train Loss: 3630.1096, Val Loss: 15212.8782
# Epoch [171/200], Train Loss: 3599.9178, Val Loss: 14724.8142
# Epoch [172/200], Train Loss: 3611.1819, Val Loss: 14763.6676
# Epoch [173/200], Train Loss: 3632.5423, Val Loss: 15753.6534
# Epoch [174/200], Train Loss: 3583.5660, Val Loss: 15125.7142
# Epoch [175/200], Train Loss: 3578.4861, Val Loss: 14551.7198
# Epoch [176/200], Train Loss: 3614.6801, Val Loss: 14867.1647
# Epoch [177/200], Train Loss: 3587.7814, Val Loss: 15438.9864
# Epoch [178/200], Train Loss: 3581.6702, Val Loss: 15382.0963
# Epoch [179/200], Train Loss: 3588.0166, Val Loss: 14605.5673
# Epoch [180/200], Train Loss: 3573.1506, Val Loss: 14653.4948
# Epoch [181/200], Train Loss: 3579.1528, Val Loss: 15274.5896
# Epoch [182/200], Train Loss: 3575.8649, Val Loss: 14912.8541
# Epoch [183/200], Train Loss: 3560.8664, Val Loss: 15157.5630
# Epoch [184/200], Train Loss: 3556.2107, Val Loss: 14205.2322
# Epoch [185/200], Train Loss: 3539.1257, Val Loss: 14870.5056
# Epoch [186/200], Train Loss: 3555.1722, Val Loss: 14910.0868
# Epoch [187/200], Train Loss: 3581.9971, Val Loss: 14655.9927
# Epoch [188/200], Train Loss: 3579.5977, Val Loss: 15102.6710
# Epoch [189/200], Train Loss: 3523.8921, Val Loss: 15298.5739
# Epoch [190/200], Train Loss: 3564.9047, Val Loss: 14793.8140
# Epoch [191/200], Train Loss: 3534.6229, Val Loss: 15188.7578
# Epoch [192/200], Train Loss: 3534.8755, Val Loss: 14385.6371
# Epoch [193/200], Train Loss: 3529.0392, Val Loss: 14716.3056
# Epoch [194/200], Train Loss: 3544.8568, Val Loss: 15141.0574
# Epoch [195/200], Train Loss: 3536.2942, Val Loss: 14844.0495
# Epoch [196/200], Train Loss: 3503.7300, Val Loss: 15578.2296
# Epoch [197/200], Train Loss: 3520.1086, Val Loss: 14974.3577
# Epoch [198/200], Train Loss: 3510.5713, Val Loss: 15173.2172
# Epoch [199/200], Train Loss: 3491.4344, Val Loss: 15008.6060
# Epoch [200/200], Train Loss: 3491.3264, Val Loss: 14909.5960
# 正在进行实验 5 ...
# Epoch [1/200], Train Loss: 39877.5433, Val Loss: 67538.9284
# Epoch [2/200], Train Loss: 18050.8707, Val Loss: 34014.8832
# Epoch [3/200], Train Loss: 11673.6620, Val Loss: 31491.8214
# Epoch [4/200], Train Loss: 10433.4225, Val Loss: 30642.0156
# Epoch [5/200], Train Loss: 9465.9879, Val Loss: 27694.1585
# Epoch [6/200], Train Loss: 8957.2755, Val Loss: 27478.0246
# Epoch [7/200], Train Loss: 8623.9064, Val Loss: 26795.5151
# Epoch [8/200], Train Loss: 8144.4791, Val Loss: 25344.7921
# Epoch [9/200], Train Loss: 7925.1735, Val Loss: 27231.7939
# Epoch [10/200], Train Loss: 7770.4644, Val Loss: 25002.9104
# Epoch [11/200], Train Loss: 7639.7077, Val Loss: 24448.1302
# Epoch [12/200], Train Loss: 7548.4781, Val Loss: 22943.5394
# Epoch [13/200], Train Loss: 7328.2931, Val Loss: 23392.8444
# Epoch [14/200], Train Loss: 7029.4657, Val Loss: 23956.6103
# Epoch [15/200], Train Loss: 6761.1002, Val Loss: 21589.7616
# Epoch [16/200], Train Loss: 6570.4264, Val Loss: 21534.8296
# Epoch [17/200], Train Loss: 6455.7733, Val Loss: 23680.2683
# Epoch [18/200], Train Loss: 6307.7299, Val Loss: 19977.7261
# Epoch [19/200], Train Loss: 6221.9494, Val Loss: 22898.8317
# Epoch [20/200], Train Loss: 6102.1416, Val Loss: 20487.8854
# Epoch [21/200], Train Loss: 5826.4627, Val Loss: 19063.0824
# Epoch [22/200], Train Loss: 5697.9003, Val Loss: 21127.0786
# Epoch [23/200], Train Loss: 5552.1502, Val Loss: 18235.8355
# Epoch [24/200], Train Loss: 5657.9980, Val Loss: 20128.6056
# Epoch [25/200], Train Loss: 5497.3173, Val Loss: 21309.0770
# Epoch [26/200], Train Loss: 5384.9501, Val Loss: 18288.8215
# Epoch [27/200], Train Loss: 5466.7136, Val Loss: 18154.1564
# Epoch [28/200], Train Loss: 5409.1675, Val Loss: 17466.7149
# Epoch [29/200], Train Loss: 5289.6468, Val Loss: 19034.7479
# Epoch [30/200], Train Loss: 5338.8211, Val Loss: 20121.3899
# Epoch [31/200], Train Loss: 5102.5666, Val Loss: 20924.6177
# Epoch [32/200], Train Loss: 5344.3943, Val Loss: 19250.8824
# Epoch [33/200], Train Loss: 5146.7047, Val Loss: 16807.8173
# Epoch [34/200], Train Loss: 5268.8125, Val Loss: 15401.5284
# Epoch [35/200], Train Loss: 5169.4254, Val Loss: 15929.8458
# Epoch [36/200], Train Loss: 5181.1850, Val Loss: 18598.7116
# Epoch [37/200], Train Loss: 5254.6987, Val Loss: 20316.9078
# Epoch [38/200], Train Loss: 5304.1177, Val Loss: 18201.7821
# Epoch [39/200], Train Loss: 5227.3593, Val Loss: 16759.2485
# Epoch [40/200], Train Loss: 5190.0739, Val Loss: 16793.0908
# Epoch [41/200], Train Loss: 5083.3405, Val Loss: 16759.9980
# Epoch [42/200], Train Loss: 5132.9339, Val Loss: 17564.0244
# Epoch [43/200], Train Loss: 5097.1412, Val Loss: 14852.1299
# Epoch [44/200], Train Loss: 5142.9655, Val Loss: 16436.3096
# Epoch [45/200], Train Loss: 5255.9702, Val Loss: 14713.2484
# Epoch [46/200], Train Loss: 5143.0881, Val Loss: 14632.0914
# Epoch [47/200], Train Loss: 5081.5578, Val Loss: 17573.0124
# Epoch [48/200], Train Loss: 5001.7608, Val Loss: 16384.3128
# Epoch [49/200], Train Loss: 5009.4967, Val Loss: 15317.3269
# Epoch [50/200], Train Loss: 5054.2392, Val Loss: 17338.8182
# Epoch [51/200], Train Loss: 5106.6114, Val Loss: 15532.9120
# Epoch [52/200], Train Loss: 5191.6585, Val Loss: 19408.0032
# Epoch [53/200], Train Loss: 5392.7004, Val Loss: 15485.3095
# Epoch [54/200], Train Loss: 5409.6223, Val Loss: 14522.3944
# Epoch [55/200], Train Loss: 5225.0694, Val Loss: 13151.4447
# Epoch [56/200], Train Loss: 5271.4562, Val Loss: 14811.0191
# Epoch [57/200], Train Loss: 5247.6145, Val Loss: 16100.3210
# Epoch [58/200], Train Loss: 5532.7992, Val Loss: 12331.1319
# Epoch [59/200], Train Loss: 5598.6339, Val Loss: 16840.6504
# Epoch [60/200], Train Loss: 5473.1222, Val Loss: 14696.0179
# Epoch [61/200], Train Loss: 5414.5090, Val Loss: 17549.4343
# Epoch [62/200], Train Loss: 5536.2475, Val Loss: 14789.8049
# Epoch [63/200], Train Loss: 5642.4002, Val Loss: 14430.1641
# Epoch [64/200], Train Loss: 5778.8569, Val Loss: 14594.2613
# Epoch [65/200], Train Loss: 5621.4689, Val Loss: 18858.7374
# Epoch [66/200], Train Loss: 6106.0837, Val Loss: 16542.8469
# Epoch [67/200], Train Loss: 6081.8824, Val Loss: 15006.5869
# Epoch [68/200], Train Loss: 6148.4895, Val Loss: 16136.0446
# Epoch [69/200], Train Loss: 5759.9171, Val Loss: 13580.6472
# Epoch [70/200], Train Loss: 5920.9417, Val Loss: 14526.8117
# Epoch [71/200], Train Loss: 5909.9248, Val Loss: 21620.0399
# Epoch [72/200], Train Loss: 6113.9727, Val Loss: 16133.8192
# Epoch [73/200], Train Loss: 6080.2569, Val Loss: 18606.7439
# Epoch [74/200], Train Loss: 6398.4476, Val Loss: 14334.8792
# Epoch [75/200], Train Loss: 6319.3833, Val Loss: 13929.3715
# Epoch [76/200], Train Loss: 5908.8949, Val Loss: 13344.4037
# Epoch [77/200], Train Loss: 5868.2107, Val Loss: 11254.9321
# Epoch [78/200], Train Loss: 6192.1896, Val Loss: 15373.7292
# Epoch [79/200], Train Loss: 6405.8385, Val Loss: 18261.7151
# Epoch [80/200], Train Loss: 6305.2742, Val Loss: 19451.3747
# Epoch [81/200], Train Loss: 6271.9417, Val Loss: 17671.1155
# Epoch [82/200], Train Loss: 6283.0278, Val Loss: 17694.3062
# Epoch [83/200], Train Loss: 6494.6832, Val Loss: 16087.3255
# Epoch [84/200], Train Loss: 6448.3391, Val Loss: 18436.0788
# Epoch [85/200], Train Loss: 6379.2234, Val Loss: 18553.8508
# Epoch [86/200], Train Loss: 6331.9498, Val Loss: 16091.6015
# Epoch [87/200], Train Loss: 6724.4221, Val Loss: 15412.3851
# Epoch [88/200], Train Loss: 6321.4761, Val Loss: 16715.1853
# Epoch [89/200], Train Loss: 6372.6406, Val Loss: 18723.9722
# Epoch [90/200], Train Loss: 6604.8294, Val Loss: 32751.9971
# Epoch [91/200], Train Loss: 8593.0557, Val Loss: 21336.1906
# Epoch [92/200], Train Loss: 7235.2224, Val Loss: 17094.1365
# Epoch [93/200], Train Loss: 6467.2238, Val Loss: 14730.5988
# Epoch [94/200], Train Loss: 6483.9391, Val Loss: 15404.0325
# Epoch [95/200], Train Loss: 6395.2862, Val Loss: 14228.7776
# Epoch [96/200], Train Loss: 6583.6910, Val Loss: 17539.2414
# Epoch [97/200], Train Loss: 6452.8449, Val Loss: 14608.5188
# Epoch [98/200], Train Loss: 6276.3431, Val Loss: 14085.9912
# Epoch [99/200], Train Loss: 6369.4238, Val Loss: 16583.0811
# Epoch [100/200], Train Loss: 6591.1654, Val Loss: 15780.5191
# Epoch [101/200], Train Loss: 6225.9916, Val Loss: 14619.8732
# Epoch [102/200], Train Loss: 5943.5831, Val Loss: 15150.5894
# Epoch [103/200], Train Loss: 5848.4165, Val Loss: 14187.5382
# Epoch [104/200], Train Loss: 5778.5304, Val Loss: 13487.6280
# Epoch [105/200], Train Loss: 5710.1732, Val Loss: 13280.2744
# Epoch [106/200], Train Loss: 5661.9801, Val Loss: 13550.3973
# Epoch [107/200], Train Loss: 5632.4199, Val Loss: 13237.5296
# Epoch [108/200], Train Loss: 5548.4791, Val Loss: 13337.4290
# Epoch [109/200], Train Loss: 5554.4389, Val Loss: 12823.9899
# Epoch [110/200], Train Loss: 5508.8207, Val Loss: 13295.7809
# Epoch [111/200], Train Loss: 5494.7606, Val Loss: 12816.2385
# Epoch [112/200], Train Loss: 5474.4537, Val Loss: 12939.4709
# Epoch [113/200], Train Loss: 5442.5951, Val Loss: 12341.8606
# Epoch [114/200], Train Loss: 5380.6887, Val Loss: 12562.8352
# Epoch [115/200], Train Loss: 5313.8232, Val Loss: 12443.1640
# Epoch [116/200], Train Loss: 5330.8721, Val Loss: 12406.1208
# Epoch [117/200], Train Loss: 5331.8721, Val Loss: 12473.2293
# Epoch [118/200], Train Loss: 5328.3319, Val Loss: 12152.5935
# Epoch [119/200], Train Loss: 5285.6114, Val Loss: 12334.8740
# Epoch [120/200], Train Loss: 5236.4598, Val Loss: 12655.2857
# Epoch [121/200], Train Loss: 5272.0590, Val Loss: 11956.3958
# Epoch [122/200], Train Loss: 5249.9964, Val Loss: 12337.7361
# Epoch [123/200], Train Loss: 5241.0165, Val Loss: 12445.8309
# Epoch [124/200], Train Loss: 5184.6348, Val Loss: 11898.1609
# Epoch [125/200], Train Loss: 5204.5778, Val Loss: 12371.6985
# Epoch [126/200], Train Loss: 5147.5709, Val Loss: 12154.6038
# Epoch [127/200], Train Loss: 5126.4339, Val Loss: 11943.4359
# Epoch [128/200], Train Loss: 5119.1284, Val Loss: 12570.4860
# Epoch [129/200], Train Loss: 5108.2895, Val Loss: 11885.6635
# Epoch [130/200], Train Loss: 5088.0341, Val Loss: 11777.1708
# Epoch [131/200], Train Loss: 5063.0044, Val Loss: 12935.7604
# Epoch [132/200], Train Loss: 5076.9747, Val Loss: 12380.2961
# Epoch [133/200], Train Loss: 5043.5752, Val Loss: 12177.4233
# Epoch [134/200], Train Loss: 5025.1711, Val Loss: 11998.3550
# Epoch [135/200], Train Loss: 5017.2715, Val Loss: 11722.7108
# Epoch [136/200], Train Loss: 4983.1620, Val Loss: 12712.7306
# Epoch [137/200], Train Loss: 4967.5337, Val Loss: 12253.5106
# Epoch [138/200], Train Loss: 4968.9059, Val Loss: 12039.6247
# Epoch [139/200], Train Loss: 4974.6820, Val Loss: 12610.4804
# Epoch [140/200], Train Loss: 4980.0216, Val Loss: 12404.2854
# Epoch [141/200], Train Loss: 4942.0188, Val Loss: 12333.8363
# Epoch [142/200], Train Loss: 4935.2405, Val Loss: 12940.4595
# Epoch [143/200], Train Loss: 4943.1861, Val Loss: 12634.8924
# Epoch [144/200], Train Loss: 4917.1690, Val Loss: 12040.7816
# Epoch [145/200], Train Loss: 4917.9547, Val Loss: 12402.1194
# Epoch [146/200], Train Loss: 4967.7360, Val Loss: 12998.2631
# Epoch [147/200], Train Loss: 4912.8982, Val Loss: 12555.1222
# Epoch [148/200], Train Loss: 4883.4526, Val Loss: 12388.4495
# Epoch [149/200], Train Loss: 4935.0945, Val Loss: 12703.8155
# Epoch [150/200], Train Loss: 4881.9867, Val Loss: 12776.9097
# Epoch [151/200], Train Loss: 4899.6400, Val Loss: 12874.9775
# Epoch [152/200], Train Loss: 4832.1389, Val Loss: 12393.5384
# Epoch [153/200], Train Loss: 4829.2518, Val Loss: 12590.8614
# Epoch [154/200], Train Loss: 4808.0601, Val Loss: 12576.1513
# Epoch [155/200], Train Loss: 4813.0448, Val Loss: 12248.5461
# Epoch [156/200], Train Loss: 4792.2140, Val Loss: 12352.5760
# Epoch [157/200], Train Loss: 4758.8072, Val Loss: 12467.2932
# Epoch [158/200], Train Loss: 4801.7748, Val Loss: 12848.6783
# Epoch [159/200], Train Loss: 4788.1141, Val Loss: 12920.5795
# Epoch [160/200], Train Loss: 4762.2995, Val Loss: 12514.0557
# Epoch [161/200], Train Loss: 4758.3896, Val Loss: 12665.3669
# Epoch [162/200], Train Loss: 4747.0931, Val Loss: 12486.7199
# Epoch [163/200], Train Loss: 4717.2912, Val Loss: 13078.0996
# Epoch [164/200], Train Loss: 4700.0266, Val Loss: 12498.9963
# Epoch [165/200], Train Loss: 4697.9922, Val Loss: 12190.2120
# Epoch [166/200], Train Loss: 4726.5403, Val Loss: 12463.7522
# Epoch [167/200], Train Loss: 4723.5075, Val Loss: 13116.2509
# Epoch [168/200], Train Loss: 4670.9034, Val Loss: 12595.6302
# Epoch [169/200], Train Loss: 4705.8084, Val Loss: 12540.7332
# Epoch [170/200], Train Loss: 4689.9197, Val Loss: 12373.2647
# Epoch [171/200], Train Loss: 4665.4932, Val Loss: 12181.2034
# Epoch [172/200], Train Loss: 4650.6151, Val Loss: 12307.9952
# Epoch [173/200], Train Loss: 4646.1136, Val Loss: 12593.1558
# Epoch [174/200], Train Loss: 4637.3988, Val Loss: 12556.0172
# Epoch [175/200], Train Loss: 4696.7297, Val Loss: 12741.9272
# Epoch [176/200], Train Loss: 4671.4638, Val Loss: 12755.4012
# Epoch [177/200], Train Loss: 4613.1603, Val Loss: 13075.8710
# Epoch [178/200], Train Loss: 4609.7205, Val Loss: 12689.0362
# Epoch [179/200], Train Loss: 4588.5599, Val Loss: 12862.3972
# Epoch [180/200], Train Loss: 4663.6483, Val Loss: 12464.8236
# Epoch [181/200], Train Loss: 4609.1262, Val Loss: 12915.5671
# Epoch [182/200], Train Loss: 4590.7414, Val Loss: 12804.3932
# Epoch [183/200], Train Loss: 4571.8545, Val Loss: 12584.5828
# Epoch [184/200], Train Loss: 4618.0058, Val Loss: 12854.8917
# Epoch [185/200], Train Loss: 4584.1987, Val Loss: 12703.2032
# Epoch [186/200], Train Loss: 4550.4611, Val Loss: 12577.3177
# Epoch [187/200], Train Loss: 4595.6329, Val Loss: 12530.7319
# Epoch [188/200], Train Loss: 4601.5737, Val Loss: 12068.0916
# Epoch [189/200], Train Loss: 4581.6047, Val Loss: 12781.7055
# Epoch [190/200], Train Loss: 4555.8201, Val Loss: 12737.2469
# Epoch [191/200], Train Loss: 4530.3452, Val Loss: 11927.0943
# Epoch [192/200], Train Loss: 4519.3227, Val Loss: 12296.0206
# Epoch [193/200], Train Loss: 4540.1865, Val Loss: 12896.4863
# Epoch [194/200], Train Loss: 4536.4273, Val Loss: 12657.7016
# Epoch [195/200], Train Loss: 4501.2644, Val Loss: 12455.5896
# Epoch [196/200], Train Loss: 4531.1020, Val Loss: 12624.6523
# Epoch [197/200], Train Loss: 4552.6710, Val Loss: 12786.7277
# Epoch [198/200], Train Loss: 4526.4375, Val Loss: 12847.4306
# Epoch [199/200], Train Loss: 4572.3695, Val Loss: 12559.5012
# Epoch [200/200], Train Loss: 4533.9537, Val Loss: 12668.8284

# %%
def plot_losses(train_losses, val_losses, title):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='训练损失')
    plt.plot(val_losses, label='验证损失')
    plt.title(f'{title} 损失曲线')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.show()

# 读取损失
train_losses = pd.read_csv('./short_model/train_losses.csv').values
val_losses = pd.read_csv('./short_model/val_losses.csv').values
# 绘制短期预测模型的损失曲线
plot_losses(train_losses, val_losses, '短期预测模型')

# %%
def evaluate_model(model, val_loader, device):
    model.eval()
    predictions = []
    actuals = []
    inputs = []  # 用于存储输入序列
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val = X_val.to(device)
            y_val = y_val.to(device)
            outputs = model(X_val)
            predictions.append(outputs.cpu().numpy())
            actuals.append(y_val.cpu().numpy())
            inputs.append(X_val.cpu().numpy())  # 收集输入序列
    
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)
    inputs = np.concatenate(inputs, axis=0)  # 合并所有输入序列
    
    mse = mean_squared_error(actuals, predictions)
    mae = mean_absolute_error(actuals, predictions)
    
    return mse, mae, inputs, actuals, predictions

mse_list = []
mae_list = []

for exp in range(num_experiments):
    model_short = CNNLSTMAttentionModel(input_steps, output_steps_short, input_size)
    model_short = model_short.to('cuda' if torch.cuda.is_available() else 'cpu')
    model_short.load_state_dict(torch.load(f'./short_model/model_short_{exp+1}.pth', weights_only=False))
    mse, mae, inputs_short, actuals_short, predictions_short = evaluate_model(model_short, test_loader_short, device)
    mse_list.append(mse)
    mae_list.append(mae)

std_mse = np.std(mse_list)
std_mae = np.std(mae_list)
print(f'短期预测模型 - 平均 MSE: {np.mean(mse_list):.4f}, 平均 MAE: {np.mean(mae_list):.4f}')
print(f'短期预测模型 - MSE 标准差: {std_mse:.4f}, MAE 标准差: {std_mae:.4f}')

# 最佳模型
best_model_idx = np.argmin(mse_list)
model_short = CNNLSTMAttentionModel(input_steps, output_steps_short, input_size)
model_short = model_short.to('cuda' if torch.cuda.is_available() else 'cpu')
model_short.load_state_dict(torch.load(f'./short_model/model_short_{best_model_idx+1}.pth', weights_only=False))
mse, mae, inputs_short, actuals_short, predictions_short = evaluate_model(model_short, test_loader_short, device)

def plot_predictions_with_input(inputs, actual, predicted, sample_idx, title):
    plt.figure(figsize=(15, 5))
    
    input_steps = inputs.shape[1]
    output_steps = actual.shape[1]
    total_steps = input_steps + output_steps
    
    # 提取特定样本的输入、实际和预测数据
    actual_seq = actual[sample_idx]
    predicted_seq = predicted[sample_idx]
    
    last_input_cnt = list(actual[sample_idx - 1][-input_steps:])
    last_input_cnt.append(actual[sample_idx][0])
    
    # 绘制输入序列
    plt.plot(range(input_steps+1), last_input_cnt, label='Input (前一个时间步 cnt)', color='gray')
    
    # 绘制实际值
    plt.plot(range(input_steps, total_steps), actual_seq, label='True', color='blue')
    
    # 绘制预测值
    plt.plot(range(input_steps, total_steps), predicted_seq, label='Predicted', color='red')
    
    plt.title(f'{title} - 预测结果')
    plt.xlabel('时间步')
    plt.ylabel('租赁数量')
    plt.legend()
    plt.show()

plot_predictions_with_input(inputs_short, actuals_short, predictions_short, 1, '短期预测')
# Out:
# 短期预测模型 - 平均 MSE: 18908.1830, 平均 MAE: 94.2525
# 短期预测模型 - MSE 标准差: 3310.0490, MAE 标准差: 7.3086
