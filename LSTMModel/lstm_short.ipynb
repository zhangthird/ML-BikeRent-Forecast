# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
from matplotlib import rcParams

# 设置 Matplotlib 使用 SimHei 字体
rcParams['font.family'] = ['SimHei']  # 指定中文字体
rcParams['axes.unicode_minus'] = False  # 正常显示负号

# %%
# 加载训练和测试数据
train_df = pd.read_csv('../dataset/train_data.csv')
test_df = pd.read_csv('../dataset/test_data.csv')

# 删除不需要的列
columns_to_drop = ['instant', 'dteday']
train_df.drop(columns=columns_to_drop, inplace=True)
test_df.drop(columns=columns_to_drop, inplace=True)

# 查看每列的缺失值数量
print("训练集缺失值:\n", train_df.isnull().sum())
print(train_df.info())

# 删除含有缺失值的行
train_df = train_df.dropna()
test_df = test_df.dropna()
# Out:
# 训练集缺失值:
#  season        3
# yr            3
# mnth          3
# hr            3
# holiday       3
# weekday       3
# workingday    3
# weathersit    3
# temp          3
# atemp         3
# hum           3
# windspeed     3
# casual        3
# registered    3
# cnt           3
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15219 entries, 0 to 15218
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      15216 non-null  float64
#  1   yr          15216 non-null  float64
#  2   mnth        15216 non-null  float64
#  3   hr          15216 non-null  float64
#  4   holiday     15216 non-null  float64
#  5   weekday     15216 non-null  float64
#  6   workingday  15216 non-null  float64
#  7   weathersit  15216 non-null  float64
#  8   temp        15216 non-null  float64
#  9   atemp       15216 non-null  float64
#  10  hum         15216 non-null  float64
#  11  windspeed   15216 non-null  float64
#  12  casual      15216 non-null  float64
#  13  registered  15216 non-null  float64
#  14  cnt         15216 non-null  float64
# dtypes: float64(15)
# memory usage: 1.7 MB
# None

# %%
numeric_features = ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered']
categorical_features = ['yr', 'season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit']
target = 'cnt'

# 特征归一化
scaler_features = MinMaxScaler()
train_df[numeric_features] = scaler_features.fit_transform(train_df[numeric_features])
test_df[numeric_features] = scaler_features.transform(test_df[numeric_features])

features = numeric_features + categorical_features
# 最终检查
print("\n最终训练集信息:")
print(train_df.info())

print("\n最终测试集信息:")
print(test_df.info())
# Out:
# 最终训练集信息:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15216 entries, 0 to 15215
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      15216 non-null  float64
#  1   yr          15216 non-null  float64
#  2   mnth        15216 non-null  float64
#  3   hr          15216 non-null  float64
#  4   holiday     15216 non-null  float64
#  5   weekday     15216 non-null  float64
#  6   workingday  15216 non-null  float64
#  7   weathersit  15216 non-null  float64
#  8   temp        15216 non-null  float64
#  9   atemp       15216 non-null  float64
#  10  hum         15216 non-null  float64
#  11  windspeed   15216 non-null  float64
#  12  casual      15216 non-null  float64
#  13  registered  15216 non-null  float64
#  14  cnt         15216 non-null  float64
# dtypes: float64(15)
# memory usage: 1.9 MB
# None
#
# 最终测试集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      2160 non-null   int64
#  1   yr          2160 non-null   int64
#  2   mnth        2160 non-null   int64
#  3   hr          2160 non-null   int64
#  4   holiday     2160 non-null   int64
#  5   weekday     2160 non-null   int64
#  6   workingday  2160 non-null   int64
#  7   weathersit  2160 non-null   int64
#  8   temp        2160 non-null   float64
#  9   atemp       2160 non-null   float64
#  10  hum         2160 non-null   float64
#  11  windspeed   2160 non-null   float64
#  12  casual      2160 non-null   float64
#  13  registered  2160 non-null   float64
#  14  cnt         2160 non-null   int64
# dtypes: float64(6), int64(9)
# memory usage: 253.2 KB
# None

# %%
def create_sequences(df, input_steps, output_steps, features, target, sw=1):
    X = []
    y = []
    num = (len(df) - input_steps - output_steps)/sw + 1
    for i in range(int(num)):
        X_seq = df[features].iloc[i:i+input_steps].values
        y_seq = df[target].iloc[i+input_steps:i+input_steps+output_steps].values
        X.append(X_seq)
        y.append(y_seq)
    return np.array(X), np.array(y)

# 定义输入和输出的时间步长
input_steps = 96
output_steps_short = 96

# 创建短期预测的训练集
X_short, y_short = create_sequences(train_df, input_steps, output_steps_short, features, target)
print(f'短期预测 - 输入形状: {X_short.shape}, 输出形状: {y_short.shape}')

# 划分比例
split_ratio = 0.8

# 短期预测
split_index_short = int(X_short.shape[0] * split_ratio)
X_train_short = X_short[:split_index_short]
y_train_short = y_short[:split_index_short]
X_val_short = X_short[split_index_short:]
y_val_short = y_short[split_index_short:]

X_test_short, y_test_short = create_sequences(test_df, input_steps, output_steps_short, features, target)

print(f'短期预测 - 训练集: {X_train_short.shape}, 验证集: {X_val_short.shape}')
print(f'短期预测 - 测试集: {X_test_short.shape}')
# Out:
# 短期预测 - 输入形状: (15025, 96, 14), 输出形状: (15025, 96)
# 短期预测 - 训练集: (12020, 96, 14), 验证集: (3005, 96, 14)
# 短期预测 - 测试集: (1969, 96, 14)

# %%
class BikeSharingDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

batch_size = 64

# 短期预测数据加载器
train_dataset_short = BikeSharingDataset(X_train_short, y_train_short)
val_dataset_short = BikeSharingDataset(X_val_short, y_val_short)
train_loader_short = DataLoader(train_dataset_short, batch_size=batch_size, shuffle=True)
val_loader_short = DataLoader(val_dataset_short, batch_size=batch_size, shuffle=False)
test_dataset_short = BikeSharingDataset(X_test_short, y_test_short)
test_loader_short = DataLoader(test_dataset_short, batch_size=batch_size, shuffle=False)

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_steps, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.output_steps = output_steps
        
        # 堆叠多个LSTM层
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        
        # Dropout层
        self.dropout = nn.Dropout(dropout)
        
        # 全连接层
        self.fc1 = nn.Linear(hidden_size, 128)
        self.batch_norm = nn.BatchNorm1d(128)
        self.fc2 = nn.Linear(128, 64)
        self.batch_norm2 = nn.BatchNorm1d(64)
        self.fc3 = nn.Linear(64, output_steps)
    
    def forward(self, x):
        # 初始化隐藏状态和细胞状态
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        # 前向传播LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: (batch_size, seq_length, hidden_size)
        
        # 取最后一个时间步的输出
        out = out[:, -1, :]  # (batch_size, hidden_size)
        
        # Dropout
        out = self.dropout(out)
        
        # 全连接层
        out = self.fc1(out)
        out = self.batch_norm(out)
        out = self.fc2(out)
        out = self.batch_norm2(out)
        out = self.fc3(out)
        
        return out

# %%
def train_model(model, train_loader, val_loader, num_epochs, learning_rate, device, max_grad_norm=1.0):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    # scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)  # 每 10 个 epoch 学习率衰减为原来的 0.1
    
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            # 前向传播
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            
            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
            optimizer.step()
            
            running_loss += loss.item() * X_batch.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)
        
        # 验证
        model.eval()
        val_running_loss = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val = X_val.to(device)
                y_val = y_val.to(device)
                outputs = model(X_val)
                loss = criterion(outputs, y_val)
                val_running_loss += loss.item() * X_val.size(0)
        
        val_epoch_loss = val_running_loss / len(val_loader.dataset)
        val_losses.append(val_epoch_loss)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_loss:.4f}, Val Loss: {val_epoch_loss:.4f}')
        
        # 每个 epoch 后更新学习率
        # scheduler.step()

    return train_losses, val_losses

# %%
# 设置训练参数
num_epochs = 400
learning_rate = 0.005
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_experiments = 5

# 获取输入特征数量
input_size = len(features)

# 短期预测模型参数
hidden_size_short = 64
num_layers_short = 3
output_steps_short = 96

def init_weights(m):
    if isinstance(m, nn.LSTM):
        for name, param in m.named_parameters():
            if 'weight_ih' in name:
                nn.init.xavier_uniform_(param.data)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param.data)
            elif 'bias' in name:
                nn.init.zeros_(param.data)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

for exp in range(num_experiments):
    print(f"正在进行实验 {exp+1} ...")
    model_short = LSTMModel(input_size, hidden_size_short, num_layers_short, output_steps_short)
    model_short = model_short.to('cuda' if torch.cuda.is_available() else 'cpu')
    model_short.apply(init_weights)
    train_losses, val_losses = train_model(
        model_short, train_loader_short, val_loader_short, num_epochs, learning_rate, device
    )
    torch.save(model_short.state_dict(), f'./short_model/model_short_{exp+1}.pth')

# 保存loss
train_losses_df = pd.DataFrame(train_losses)
val_losses_df = pd.DataFrame(val_losses)
train_losses_df.to_csv('./short_model/train_losses.csv', index=False)
val_losses_df.to_csv('./short_model/val_losses.csv', index=False)
# Out:
# 正在进行实验 1 ...
# Epoch [1/400], Train Loss: 45082.3295, Val Loss: 97799.2666
# Epoch [2/400], Train Loss: 28161.0175, Val Loss: 55243.5681
# Epoch [3/400], Train Loss: 14918.0983, Val Loss: 36248.3317
# Epoch [4/400], Train Loss: 11156.0376, Val Loss: 31143.9048
# Epoch [5/400], Train Loss: 9817.3603, Val Loss: 26768.0179
# Epoch [6/400], Train Loss: 9437.6307, Val Loss: 23627.9154
# Epoch [7/400], Train Loss: 9041.4492, Val Loss: 20975.3075
# Epoch [8/400], Train Loss: 8640.9992, Val Loss: 29153.4086
# Epoch [9/400], Train Loss: 8481.5523, Val Loss: 25793.7050
# Epoch [10/400], Train Loss: 8316.5358, Val Loss: 24145.8898
# Epoch [11/400], Train Loss: 8184.0178, Val Loss: 25007.4790
# Epoch [12/400], Train Loss: 8089.6168, Val Loss: 23112.9655
# Epoch [13/400], Train Loss: 7975.7250, Val Loss: 22878.2734
# Epoch [14/400], Train Loss: 7801.1468, Val Loss: 24188.7446
# Epoch [15/400], Train Loss: 7601.3277, Val Loss: 26633.6289
# Epoch [16/400], Train Loss: 7310.0870, Val Loss: 20493.4726
# Epoch [17/400], Train Loss: 7049.5422, Val Loss: 24074.2495
# Epoch [18/400], Train Loss: 6878.7084, Val Loss: 25144.4559
# Epoch [19/400], Train Loss: 6748.9849, Val Loss: 22363.0533
# Epoch [20/400], Train Loss: 6697.2559, Val Loss: 21604.9466
# Epoch [21/400], Train Loss: 6632.2370, Val Loss: 21610.2350
# Epoch [22/400], Train Loss: 6644.5564, Val Loss: 22061.3040
# Epoch [23/400], Train Loss: 6570.0917, Val Loss: 18745.8871
# Epoch [24/400], Train Loss: 6544.7787, Val Loss: 22260.0065
# Epoch [25/400], Train Loss: 6385.1867, Val Loss: 20444.3599
# Epoch [26/400], Train Loss: 6207.3685, Val Loss: 19620.2077
# Epoch [27/400], Train Loss: 5996.3559, Val Loss: 19759.0700
# Epoch [28/400], Train Loss: 5908.4705, Val Loss: 19226.8821
# Epoch [29/400], Train Loss: 5779.2628, Val Loss: 19652.8500
# Epoch [30/400], Train Loss: 5672.4926, Val Loss: 20910.7298
# Epoch [31/400], Train Loss: 5641.9170, Val Loss: 18921.7702
# Epoch [32/400], Train Loss: 5647.4632, Val Loss: 19719.7815
# Epoch [33/400], Train Loss: 5580.8792, Val Loss: 18223.6573
# Epoch [34/400], Train Loss: 5637.2307, Val Loss: 18819.1344
# Epoch [35/400], Train Loss: 5593.8379, Val Loss: 19970.6228
# Epoch [36/400], Train Loss: 5530.0732, Val Loss: 19234.8334
# Epoch [37/400], Train Loss: 5460.8013, Val Loss: 20116.2178
# Epoch [38/400], Train Loss: 5385.5420, Val Loss: 18551.3236
# Epoch [39/400], Train Loss: 5299.5984, Val Loss: 18871.3505
# Epoch [40/400], Train Loss: 5262.5723, Val Loss: 17464.3148
# Epoch [41/400], Train Loss: 5210.7550, Val Loss: 16696.1177
# Epoch [42/400], Train Loss: 5189.7175, Val Loss: 17430.8908
# Epoch [43/400], Train Loss: 5145.2696, Val Loss: 18791.3480
# Epoch [44/400], Train Loss: 5150.7404, Val Loss: 17439.7560
# Epoch [45/400], Train Loss: 5137.2009, Val Loss: 18165.5674
# Epoch [46/400], Train Loss: 5092.0393, Val Loss: 17454.7949
# Epoch [47/400], Train Loss: 5108.0751, Val Loss: 19087.0253
# Epoch [48/400], Train Loss: 5056.8060, Val Loss: 17824.7231
# Epoch [49/400], Train Loss: 5039.7979, Val Loss: 18655.5603
# Epoch [50/400], Train Loss: 5055.2311, Val Loss: 17341.5961
# Epoch [51/400], Train Loss: 4990.9852, Val Loss: 18073.5906
# Epoch [52/400], Train Loss: 4967.8241, Val Loss: 17556.2683
# Epoch [53/400], Train Loss: 4956.7786, Val Loss: 17697.4411
# Epoch [54/400], Train Loss: 4870.4147, Val Loss: 17401.4395
# Epoch [55/400], Train Loss: 4857.1288, Val Loss: 17725.5805
# Epoch [56/400], Train Loss: 4790.7221, Val Loss: 16356.1100
# Epoch [57/400], Train Loss: 4748.8313, Val Loss: 17476.2411
# Epoch [58/400], Train Loss: 4681.9990, Val Loss: 17312.6355
# Epoch [59/400], Train Loss: 4635.4495, Val Loss: 18077.4547
# Epoch [60/400], Train Loss: 4625.2064, Val Loss: 17676.2304
# Epoch [61/400], Train Loss: 4582.0027, Val Loss: 18391.7661
# Epoch [62/400], Train Loss: 4554.7620, Val Loss: 17389.8493
# Epoch [63/400], Train Loss: 4521.3920, Val Loss: 17101.4330
# Epoch [64/400], Train Loss: 4548.9744, Val Loss: 17341.7219
# Epoch [65/400], Train Loss: 4491.9445, Val Loss: 17734.5821
# Epoch [66/400], Train Loss: 4508.7474, Val Loss: 19388.5325
# Epoch [67/400], Train Loss: 4471.9691, Val Loss: 17646.9083
# Epoch [68/400], Train Loss: 4461.1996, Val Loss: 17637.8604
# Epoch [69/400], Train Loss: 4465.5320, Val Loss: 18351.3667
# Epoch [70/400], Train Loss: 4440.4962, Val Loss: 17952.0090
# Epoch [71/400], Train Loss: 4441.9404, Val Loss: 16972.5974
# Epoch [72/400], Train Loss: 4406.7849, Val Loss: 18931.1215
# Epoch [73/400], Train Loss: 4376.2977, Val Loss: 16828.3633
# Epoch [74/400], Train Loss: 4415.0044, Val Loss: 17436.3876
# Epoch [75/400], Train Loss: 4375.7010, Val Loss: 18147.4623
# Epoch [76/400], Train Loss: 4358.9831, Val Loss: 18247.8858
# Epoch [77/400], Train Loss: 4310.6038, Val Loss: 17970.1201
# Epoch [78/400], Train Loss: 4287.9394, Val Loss: 17671.9511
# Epoch [79/400], Train Loss: 4262.2894, Val Loss: 17227.5625
# Epoch [80/400], Train Loss: 4256.5823, Val Loss: 17061.3943
# Epoch [81/400], Train Loss: 4264.2787, Val Loss: 17468.5696
# Epoch [82/400], Train Loss: 4231.4802, Val Loss: 16832.3133
# Epoch [83/400], Train Loss: 4248.5531, Val Loss: 17956.0880
# Epoch [84/400], Train Loss: 4278.8595, Val Loss: 17031.7082
# Epoch [85/400], Train Loss: 4256.7669, Val Loss: 18375.3284
# Epoch [86/400], Train Loss: 4219.5124, Val Loss: 16048.5012
# Epoch [87/400], Train Loss: 4218.2718, Val Loss: 16429.5374
# Epoch [88/400], Train Loss: 4210.8171, Val Loss: 17926.4916
# Epoch [89/400], Train Loss: 4191.2970, Val Loss: 16974.4357
# Epoch [90/400], Train Loss: 4187.5452, Val Loss: 17984.3580
# Epoch [91/400], Train Loss: 4169.9063, Val Loss: 16886.4031
# Epoch [92/400], Train Loss: 4195.8186, Val Loss: 16961.3628
# Epoch [93/400], Train Loss: 4163.9627, Val Loss: 18577.2524
# Epoch [94/400], Train Loss: 4171.4060, Val Loss: 17607.8616
# Epoch [95/400], Train Loss: 4150.4204, Val Loss: 17872.5646
# Epoch [96/400], Train Loss: 4154.6107, Val Loss: 17849.4618
# Epoch [97/400], Train Loss: 4131.1697, Val Loss: 17669.2423
# Epoch [98/400], Train Loss: 4100.0940, Val Loss: 17029.2898
# Epoch [99/400], Train Loss: 4115.5091, Val Loss: 16326.3748
# Epoch [100/400], Train Loss: 4114.6389, Val Loss: 16955.2344
# Epoch [101/400], Train Loss: 4106.8667, Val Loss: 17348.6132
# Epoch [102/400], Train Loss: 4067.7642, Val Loss: 15995.8944
# Epoch [103/400], Train Loss: 4034.7050, Val Loss: 16786.7822
# Epoch [104/400], Train Loss: 4069.8667, Val Loss: 17697.3494
# Epoch [105/400], Train Loss: 4056.0982, Val Loss: 18265.9683
# Epoch [106/400], Train Loss: 3989.2895, Val Loss: 16104.6838
# Epoch [107/400], Train Loss: 4002.2018, Val Loss: 17199.0371
# Epoch [108/400], Train Loss: 3960.8538, Val Loss: 17709.2992
# Epoch [109/400], Train Loss: 3982.1194, Val Loss: 16748.1849
# Epoch [110/400], Train Loss: 3963.9453, Val Loss: 17606.5222
# Epoch [111/400], Train Loss: 3950.9606, Val Loss: 16323.8140
# Epoch [112/400], Train Loss: 3978.2153, Val Loss: 17139.1735
# Epoch [113/400], Train Loss: 3957.9369, Val Loss: 17396.2574
# Epoch [114/400], Train Loss: 3939.0575, Val Loss: 18093.3057
# Epoch [115/400], Train Loss: 3929.7820, Val Loss: 17733.3135
# Epoch [116/400], Train Loss: 3903.3687, Val Loss: 17051.6415
# Epoch [117/400], Train Loss: 3905.3849, Val Loss: 16475.2240
# Epoch [118/400], Train Loss: 3907.4207, Val Loss: 17660.1783
# Epoch [119/400], Train Loss: 3886.0505, Val Loss: 17111.0905
# Epoch [120/400], Train Loss: 3885.1833, Val Loss: 17038.6742
# Epoch [121/400], Train Loss: 3875.4588, Val Loss: 15537.4979
# Epoch [122/400], Train Loss: 3878.4412, Val Loss: 17782.3485
# Epoch [123/400], Train Loss: 3912.7751, Val Loss: 17960.4942
# Epoch [124/400], Train Loss: 3878.3650, Val Loss: 16961.5397
# Epoch [125/400], Train Loss: 3881.3962, Val Loss: 15931.0007
# Epoch [126/400], Train Loss: 3826.4003, Val Loss: 16956.2977
# Epoch [127/400], Train Loss: 3871.0685, Val Loss: 16557.9799
# Epoch [128/400], Train Loss: 3845.4772, Val Loss: 16283.7099
# Epoch [129/400], Train Loss: 3828.5487, Val Loss: 17200.5416
# Epoch [130/400], Train Loss: 3815.6336, Val Loss: 16507.2268
# Epoch [131/400], Train Loss: 3797.7818, Val Loss: 16251.0765
# Epoch [132/400], Train Loss: 3788.1917, Val Loss: 17358.0287
# Epoch [133/400], Train Loss: 3784.1731, Val Loss: 16790.3249
# Epoch [134/400], Train Loss: 3748.7493, Val Loss: 16964.5748
# Epoch [135/400], Train Loss: 3748.9167, Val Loss: 17433.5838
# Epoch [136/400], Train Loss: 3752.4108, Val Loss: 17489.0736
# Epoch [137/400], Train Loss: 3747.5839, Val Loss: 19085.0539
# Epoch [138/400], Train Loss: 3751.8256, Val Loss: 16916.0204
# Epoch [139/400], Train Loss: 3779.4600, Val Loss: 18302.3401
# Epoch [140/400], Train Loss: 3714.0441, Val Loss: 16943.1043
# Epoch [141/400], Train Loss: 3750.7023, Val Loss: 18763.3564
# Epoch [142/400], Train Loss: 3728.9445, Val Loss: 17025.5294
# Epoch [143/400], Train Loss: 3747.9687, Val Loss: 17869.0039
# Epoch [144/400], Train Loss: 3693.5893, Val Loss: 18602.9999
# Epoch [145/400], Train Loss: 3698.6207, Val Loss: 19128.0750
# Epoch [146/400], Train Loss: 3709.6972, Val Loss: 16962.6459
# Epoch [147/400], Train Loss: 3689.6781, Val Loss: 17966.4686
# Epoch [148/400], Train Loss: 3672.5225, Val Loss: 18662.9157
# Epoch [149/400], Train Loss: 3713.2401, Val Loss: 19231.8490
# Epoch [150/400], Train Loss: 3692.2103, Val Loss: 17465.9516
# Epoch [151/400], Train Loss: 3684.2787, Val Loss: 16926.6976
# Epoch [152/400], Train Loss: 3664.8047, Val Loss: 18294.8250
# Epoch [153/400], Train Loss: 3664.4314, Val Loss: 16480.9558
# Epoch [154/400], Train Loss: 3642.0936, Val Loss: 17163.0047
# Epoch [155/400], Train Loss: 3660.6373, Val Loss: 17322.5536
# Epoch [156/400], Train Loss: 3668.3092, Val Loss: 17312.4085
# Epoch [157/400], Train Loss: 3654.2900, Val Loss: 16868.0071
# Epoch [158/400], Train Loss: 3671.2303, Val Loss: 18577.6752
# Epoch [159/400], Train Loss: 3640.9375, Val Loss: 18319.4610
# Epoch [160/400], Train Loss: 3641.9916, Val Loss: 18110.1732
# Epoch [161/400], Train Loss: 3618.7061, Val Loss: 18848.4005
# Epoch [162/400], Train Loss: 3612.4072, Val Loss: 18013.3345
# Epoch [163/400], Train Loss: 3617.8948, Val Loss: 17311.6534
# Epoch [164/400], Train Loss: 3645.8282, Val Loss: 18411.3347
# Epoch [165/400], Train Loss: 3633.3634, Val Loss: 16593.5650
# Epoch [166/400], Train Loss: 3617.3711, Val Loss: 18031.5554
# Epoch [167/400], Train Loss: 3627.4374, Val Loss: 16941.9391
# Epoch [168/400], Train Loss: 3626.8617, Val Loss: 18330.4159
# Epoch [169/400], Train Loss: 3602.7489, Val Loss: 18950.8733
# Epoch [170/400], Train Loss: 3622.8875, Val Loss: 17343.6419
# Epoch [171/400], Train Loss: 3621.0101, Val Loss: 16649.5745
# Epoch [172/400], Train Loss: 3575.4092, Val Loss: 16736.7542
# Epoch [173/400], Train Loss: 3571.9961, Val Loss: 16680.7864
# Epoch [174/400], Train Loss: 3599.4941, Val Loss: 17865.0501
# Epoch [175/400], Train Loss: 3596.3208, Val Loss: 18016.8328
# Epoch [176/400], Train Loss: 3602.7091, Val Loss: 16550.2383
# Epoch [177/400], Train Loss: 3578.8526, Val Loss: 18357.2788
# Epoch [178/400], Train Loss: 3599.7513, Val Loss: 18289.2113
# Epoch [179/400], Train Loss: 3575.4257, Val Loss: 20028.4375
# Epoch [180/400], Train Loss: 3559.6970, Val Loss: 17206.4951
# Epoch [181/400], Train Loss: 3530.4181, Val Loss: 17570.2488
# Epoch [182/400], Train Loss: 3543.0895, Val Loss: 17585.6859
# Epoch [183/400], Train Loss: 3523.5627, Val Loss: 17533.5627
# Epoch [184/400], Train Loss: 3490.3189, Val Loss: 17251.6455
# Epoch [185/400], Train Loss: 3493.4753, Val Loss: 17183.4794
# Epoch [186/400], Train Loss: 3473.1087, Val Loss: 16286.6957
# Epoch [187/400], Train Loss: 3475.6442, Val Loss: 17073.0419
# Epoch [188/400], Train Loss: 3451.2714, Val Loss: 16520.1816
# Epoch [189/400], Train Loss: 3475.1947, Val Loss: 17082.9551
# Epoch [190/400], Train Loss: 3458.1391, Val Loss: 16505.9893
# Epoch [191/400], Train Loss: 3461.9824, Val Loss: 17552.4588
# Epoch [192/400], Train Loss: 3460.3387, Val Loss: 18665.7573
# Epoch [193/400], Train Loss: 3494.7241, Val Loss: 17288.7858
# Epoch [194/400], Train Loss: 3458.6225, Val Loss: 17577.3403
# Epoch [195/400], Train Loss: 3460.5758, Val Loss: 17053.8554
# Epoch [196/400], Train Loss: 3446.4327, Val Loss: 16881.7061
# Epoch [197/400], Train Loss: 3480.0552, Val Loss: 18156.4335
# Epoch [198/400], Train Loss: 3428.1296, Val Loss: 17991.7487
# Epoch [199/400], Train Loss: 3425.7375, Val Loss: 15926.6224
# Epoch [200/400], Train Loss: 3470.8347, Val Loss: 18600.6674
# Epoch [201/400], Train Loss: 3417.2287, Val Loss: 16008.7590
# Epoch [202/400], Train Loss: 3418.8331, Val Loss: 18172.3738
# Epoch [203/400], Train Loss: 3446.7054, Val Loss: 17820.2358
# Epoch [204/400], Train Loss: 3441.3721, Val Loss: 17007.1831
# Epoch [205/400], Train Loss: 3421.8049, Val Loss: 16753.9211
# Epoch [206/400], Train Loss: 3476.3266, Val Loss: 18065.3324
# Epoch [207/400], Train Loss: 3446.4134, Val Loss: 18201.1126
# Epoch [208/400], Train Loss: 3409.2095, Val Loss: 18331.2355
# Epoch [209/400], Train Loss: 3437.9592, Val Loss: 17742.0442
# Epoch [210/400], Train Loss: 3407.7833, Val Loss: 18884.7969
# Epoch [211/400], Train Loss: 3397.2496, Val Loss: 16325.7632
# Epoch [212/400], Train Loss: 3434.2390, Val Loss: 19197.0758
# Epoch [213/400], Train Loss: 3394.8953, Val Loss: 18945.0941
# Epoch [214/400], Train Loss: 3412.5064, Val Loss: 17514.8645
# Epoch [215/400], Train Loss: 3445.4643, Val Loss: 18252.4369
# Epoch [216/400], Train Loss: 3410.7881, Val Loss: 18047.7053
# Epoch [217/400], Train Loss: 3447.8971, Val Loss: 19487.6780
# Epoch [218/400], Train Loss: 3414.9122, Val Loss: 17071.5988
# Epoch [219/400], Train Loss: 3412.2742, Val Loss: 16862.1841
# Epoch [220/400], Train Loss: 3439.2712, Val Loss: 16502.9716
# Epoch [221/400], Train Loss: 3389.3344, Val Loss: 17301.1124
# Epoch [222/400], Train Loss: 3414.5952, Val Loss: 16368.4821
# Epoch [223/400], Train Loss: 3369.0000, Val Loss: 18068.7868
# Epoch [224/400], Train Loss: 3395.4570, Val Loss: 18092.3848
# Epoch [225/400], Train Loss: 3413.8759, Val Loss: 18317.1592
# Epoch [226/400], Train Loss: 3418.0450, Val Loss: 18415.0349
# Epoch [227/400], Train Loss: 3367.2174, Val Loss: 18189.0533
# Epoch [228/400], Train Loss: 3399.0749, Val Loss: 15421.9682
# Epoch [229/400], Train Loss: 3337.3706, Val Loss: 18079.9479
# Epoch [230/400], Train Loss: 3443.7763, Val Loss: 18857.7962
# Epoch [231/400], Train Loss: 3404.3680, Val Loss: 17936.6908
# Epoch [232/400], Train Loss: 3409.2757, Val Loss: 17319.7848
# Epoch [233/400], Train Loss: 3420.3577, Val Loss: 17469.0177
# Epoch [234/400], Train Loss: 3409.6357, Val Loss: 17005.8063
# Epoch [235/400], Train Loss: 3401.5831, Val Loss: 18409.9835
# Epoch [236/400], Train Loss: 3421.9316, Val Loss: 16908.3241
# Epoch [237/400], Train Loss: 3381.1423, Val Loss: 17288.0735
# Epoch [238/400], Train Loss: 3426.0019, Val Loss: 18698.1488
# Epoch [239/400], Train Loss: 3364.3002, Val Loss: 17506.4342
# Epoch [240/400], Train Loss: 3354.6564, Val Loss: 17884.5658
# Epoch [241/400], Train Loss: 3400.9520, Val Loss: 19890.2398
# Epoch [242/400], Train Loss: 3394.8495, Val Loss: 18147.1676
# Epoch [243/400], Train Loss: 3374.0710, Val Loss: 17784.6675
# Epoch [244/400], Train Loss: 3398.6095, Val Loss: 17848.8312
# Epoch [245/400], Train Loss: 3359.7027, Val Loss: 19352.1021
# Epoch [246/400], Train Loss: 3360.9091, Val Loss: 19262.9676
# Epoch [247/400], Train Loss: 3355.1998, Val Loss: 17863.7825
# Epoch [248/400], Train Loss: 3372.5678, Val Loss: 18575.6495
# Epoch [249/400], Train Loss: 3374.0534, Val Loss: 17857.4467
# Epoch [250/400], Train Loss: 3364.1094, Val Loss: 18129.0242
# Epoch [251/400], Train Loss: 3342.9368, Val Loss: 20265.6669
# Epoch [252/400], Train Loss: 3362.5396, Val Loss: 20316.9112
# Epoch [253/400], Train Loss: 3391.6168, Val Loss: 19066.4832
# Epoch [254/400], Train Loss: 3387.7812, Val Loss: 19255.7093
# Epoch [255/400], Train Loss: 3334.8177, Val Loss: 18777.4850
# Epoch [256/400], Train Loss: 3376.0204, Val Loss: 18690.2463
# Epoch [257/400], Train Loss: 3372.7232, Val Loss: 18213.8704
# Epoch [258/400], Train Loss: 3357.5044, Val Loss: 19526.5161
# Epoch [259/400], Train Loss: 3340.5134, Val Loss: 19413.7116
# Epoch [260/400], Train Loss: 3350.8148, Val Loss: 17639.1655
# Epoch [261/400], Train Loss: 3368.4674, Val Loss: 18620.8521
# Epoch [262/400], Train Loss: 3360.2934, Val Loss: 17020.5581
# Epoch [263/400], Train Loss: 3338.4641, Val Loss: 18233.5916
# Epoch [264/400], Train Loss: 3351.0351, Val Loss: 17415.1317
# Epoch [265/400], Train Loss: 3377.4901, Val Loss: 17673.4589
# Epoch [266/400], Train Loss: 3353.9780, Val Loss: 19784.7330
# Epoch [267/400], Train Loss: 3351.4937, Val Loss: 19936.2242
# Epoch [268/400], Train Loss: 3340.6966, Val Loss: 19328.1296
# Epoch [269/400], Train Loss: 3347.9637, Val Loss: 17635.1262
# Epoch [270/400], Train Loss: 3343.3073, Val Loss: 18370.8695
# Epoch [271/400], Train Loss: 3384.7410, Val Loss: 18054.0466
# Epoch [272/400], Train Loss: 3367.0914, Val Loss: 19053.7068
# Epoch [273/400], Train Loss: 3357.9980, Val Loss: 17527.4672
# Epoch [274/400], Train Loss: 3332.2089, Val Loss: 18147.6451
# Epoch [275/400], Train Loss: 3339.9504, Val Loss: 17309.0370
# Epoch [276/400], Train Loss: 3324.1075, Val Loss: 17701.7835
# Epoch [277/400], Train Loss: 3366.2978, Val Loss: 17632.3497
# Epoch [278/400], Train Loss: 3348.0680, Val Loss: 19284.9277
# Epoch [279/400], Train Loss: 3351.6902, Val Loss: 18628.2465
# Epoch [280/400], Train Loss: 3356.4018, Val Loss: 17809.1264
# Epoch [281/400], Train Loss: 3338.5156, Val Loss: 19315.5537
# Epoch [282/400], Train Loss: 3348.5742, Val Loss: 19652.2270
# Epoch [283/400], Train Loss: 3329.4758, Val Loss: 19200.8327
# Epoch [284/400], Train Loss: 3334.7900, Val Loss: 19059.1654
# Epoch [285/400], Train Loss: 3319.7926, Val Loss: 17436.7362
# Epoch [286/400], Train Loss: 3345.1333, Val Loss: 17524.4885
# Epoch [287/400], Train Loss: 3335.9581, Val Loss: 18523.7109
# Epoch [288/400], Train Loss: 3318.6060, Val Loss: 17992.5328
# Epoch [289/400], Train Loss: 3327.8971, Val Loss: 18182.6812
# Epoch [290/400], Train Loss: 3354.7262, Val Loss: 20539.1145
# Epoch [291/400], Train Loss: 3310.1923, Val Loss: 20383.8240
# Epoch [292/400], Train Loss: 3348.1525, Val Loss: 19950.3368
# Epoch [293/400], Train Loss: 3343.2702, Val Loss: 16915.9132
# Epoch [294/400], Train Loss: 3343.2872, Val Loss: 18370.7637
# Epoch [295/400], Train Loss: 3322.8357, Val Loss: 18380.0775
# Epoch [296/400], Train Loss: 3303.5408, Val Loss: 17485.6451
# Epoch [297/400], Train Loss: 3289.7554, Val Loss: 19591.1033
# Epoch [298/400], Train Loss: 3306.9347, Val Loss: 18413.1556
# Epoch [299/400], Train Loss: 3324.5451, Val Loss: 17403.5615
# Epoch [300/400], Train Loss: 3316.3364, Val Loss: 18485.7053
# Epoch [301/400], Train Loss: 3335.4153, Val Loss: 18254.8346
# Epoch [302/400], Train Loss: 3329.4957, Val Loss: 19118.0222
# Epoch [303/400], Train Loss: 3355.7817, Val Loss: 19081.8303
# Epoch [304/400], Train Loss: 3319.4775, Val Loss: 18952.9736
# Epoch [305/400], Train Loss: 3320.4697, Val Loss: 18785.4912
# Epoch [306/400], Train Loss: 3341.7086, Val Loss: 17814.0389
# Epoch [307/400], Train Loss: 3289.5799, Val Loss: 19597.3196
# Epoch [308/400], Train Loss: 3284.2156, Val Loss: 18420.5016
# Epoch [309/400], Train Loss: 3275.5303, Val Loss: 19255.1710
# Epoch [310/400], Train Loss: 3315.7781, Val Loss: 19698.7048
# Epoch [311/400], Train Loss: 3331.5901, Val Loss: 18539.9717
# Epoch [312/400], Train Loss: 3302.0676, Val Loss: 19432.7022
# Epoch [313/400], Train Loss: 3362.1646, Val Loss: 17300.3828
# Epoch [314/400], Train Loss: 3316.4705, Val Loss: 18426.8164
# Epoch [315/400], Train Loss: 3328.0747, Val Loss: 17188.7036
# Epoch [316/400], Train Loss: 3310.7570, Val Loss: 17826.8535
# Epoch [317/400], Train Loss: 3327.4587, Val Loss: 18443.4511
# Epoch [318/400], Train Loss: 3295.6403, Val Loss: 18454.2221
# Epoch [319/400], Train Loss: 3326.1404, Val Loss: 17933.3538
# Epoch [320/400], Train Loss: 3315.5652, Val Loss: 18699.7700
# Epoch [321/400], Train Loss: 3309.4821, Val Loss: 19989.3028
# Epoch [322/400], Train Loss: 3306.8286, Val Loss: 18062.6446
# Epoch [323/400], Train Loss: 3296.9479, Val Loss: 18229.5464
# Epoch [324/400], Train Loss: 3326.5432, Val Loss: 18118.9070
# Epoch [325/400], Train Loss: 3300.3054, Val Loss: 17595.6947
# Epoch [326/400], Train Loss: 3344.7381, Val Loss: 19176.6759
# Epoch [327/400], Train Loss: 3298.6366, Val Loss: 17302.2592
# Epoch [328/400], Train Loss: 3287.3743, Val Loss: 19413.8071
# Epoch [329/400], Train Loss: 3783.6374, Val Loss: 20024.7030
# Epoch [330/400], Train Loss: 4704.0899, Val Loss: 17579.3160
# Epoch [331/400], Train Loss: 3718.1655, Val Loss: 18254.0801
# Epoch [332/400], Train Loss: 3378.8218, Val Loss: 17529.0885
# Epoch [333/400], Train Loss: 3295.1039, Val Loss: 17536.3182
# Epoch [334/400], Train Loss: 3330.3859, Val Loss: 16729.2653
# Epoch [335/400], Train Loss: 3312.8578, Val Loss: 16731.5241
# Epoch [336/400], Train Loss: 3308.4792, Val Loss: 16738.3327
# Epoch [337/400], Train Loss: 3296.0997, Val Loss: 18241.0286
# Epoch [338/400], Train Loss: 3291.4748, Val Loss: 17370.5111
# Epoch [339/400], Train Loss: 3352.9981, Val Loss: 18937.0220
# Epoch [340/400], Train Loss: 3280.8598, Val Loss: 18084.0352
# Epoch [341/400], Train Loss: 3314.6132, Val Loss: 18329.5601
# Epoch [342/400], Train Loss: 3275.8078, Val Loss: 17971.6243
# Epoch [343/400], Train Loss: 3303.1519, Val Loss: 18859.7546
# Epoch [344/400], Train Loss: 3440.9755, Val Loss: 17077.0232
# Epoch [345/400], Train Loss: 3326.1810, Val Loss: 18064.8562
# Epoch [346/400], Train Loss: 3271.6330, Val Loss: 19556.1009
# Epoch [347/400], Train Loss: 3322.2069, Val Loss: 17833.0902
# Epoch [348/400], Train Loss: 3312.9133, Val Loss: 17791.8221
# Epoch [349/400], Train Loss: 3285.7858, Val Loss: 17548.9610
# Epoch [350/400], Train Loss: 3258.0118, Val Loss: 17270.9009
# Epoch [351/400], Train Loss: 3302.6594, Val Loss: 19268.6884
# Epoch [352/400], Train Loss: 3288.9357, Val Loss: 17836.1395
# Epoch [353/400], Train Loss: 3266.1178, Val Loss: 16985.1864
# Epoch [354/400], Train Loss: 3281.3973, Val Loss: 17597.5668
# Epoch [355/400], Train Loss: 3268.7029, Val Loss: 18661.5160
# Epoch [356/400], Train Loss: 3267.5422, Val Loss: 17627.1234
# Epoch [357/400], Train Loss: 3292.8403, Val Loss: 18897.8701
# Epoch [358/400], Train Loss: 3315.7171, Val Loss: 19007.8246
# Epoch [359/400], Train Loss: 3258.0978, Val Loss: 17028.0133
# Epoch [360/400], Train Loss: 3302.9604, Val Loss: 17491.9784
# Epoch [361/400], Train Loss: 3298.7313, Val Loss: 16211.3686
# Epoch [362/400], Train Loss: 3264.0741, Val Loss: 17624.1288
# Epoch [363/400], Train Loss: 3278.8111, Val Loss: 16691.5577
# Epoch [364/400], Train Loss: 3277.5763, Val Loss: 17037.2888
# Epoch [365/400], Train Loss: 3270.9108, Val Loss: 17057.3882
# Epoch [366/400], Train Loss: 3290.1341, Val Loss: 17204.8185
# Epoch [367/400], Train Loss: 3265.2445, Val Loss: 17215.9444
# Epoch [368/400], Train Loss: 3294.0102, Val Loss: 20040.0877
# Epoch [369/400], Train Loss: 3267.7581, Val Loss: 18640.7068
# Epoch [370/400], Train Loss: 3264.0464, Val Loss: 17487.0637
# Epoch [371/400], Train Loss: 3261.4793, Val Loss: 18177.4982
# Epoch [372/400], Train Loss: 3267.6230, Val Loss: 16940.9828
# Epoch [373/400], Train Loss: 3263.3868, Val Loss: 18772.4903
# Epoch [374/400], Train Loss: 3276.4499, Val Loss: 17258.0862
# Epoch [375/400], Train Loss: 3258.6308, Val Loss: 17661.5826
# Epoch [376/400], Train Loss: 3274.2290, Val Loss: 18439.4760
# Epoch [377/400], Train Loss: 3248.8390, Val Loss: 17523.9160
# Epoch [378/400], Train Loss: 3259.2816, Val Loss: 17923.5577
# Epoch [379/400], Train Loss: 3248.3519, Val Loss: 18595.5831
# Epoch [380/400], Train Loss: 3261.2964, Val Loss: 18554.0599
# Epoch [381/400], Train Loss: 3263.8997, Val Loss: 18400.6377
# Epoch [382/400], Train Loss: 3248.5388, Val Loss: 17273.1451
# Epoch [383/400], Train Loss: 3212.7058, Val Loss: 18790.6454
# Epoch [384/400], Train Loss: 3254.7616, Val Loss: 19931.3590
# Epoch [385/400], Train Loss: 3220.6078, Val Loss: 18481.9731
# Epoch [386/400], Train Loss: 3226.4216, Val Loss: 19213.2356
# Epoch [387/400], Train Loss: 3241.5506, Val Loss: 18802.7211
# Epoch [388/400], Train Loss: 3232.1797, Val Loss: 18074.2757
# Epoch [389/400], Train Loss: 3212.7773, Val Loss: 16797.2566
# Epoch [390/400], Train Loss: 3217.7005, Val Loss: 18102.0170
# Epoch [391/400], Train Loss: 3203.8465, Val Loss: 19798.5277
# Epoch [392/400], Train Loss: 3192.7352, Val Loss: 17301.1686
# Epoch [393/400], Train Loss: 3217.3961, Val Loss: 17847.6463
# Epoch [394/400], Train Loss: 3217.6071, Val Loss: 17688.1533
# Epoch [395/400], Train Loss: 3249.2750, Val Loss: 17419.3902
# Epoch [396/400], Train Loss: 3209.1574, Val Loss: 17873.9826
# Epoch [397/400], Train Loss: 3176.5043, Val Loss: 17657.2986
# Epoch [398/400], Train Loss: 3199.1572, Val Loss: 16725.0228
# Epoch [399/400], Train Loss: 3177.6369, Val Loss: 16621.0813
# Epoch [400/400], Train Loss: 3251.8396, Val Loss: 17857.6579
# 正在进行实验 2 ...
# Epoch [1/400], Train Loss: 44816.4563, Val Loss: 99603.3069
# Epoch [2/400], Train Loss: 28782.6332, Val Loss: 52426.3098
# Epoch [3/400], Train Loss: 15054.5339, Val Loss: 33567.7300
# Epoch [4/400], Train Loss: 11219.1486, Val Loss: 27518.9306
# Epoch [5/400], Train Loss: 9875.2716, Val Loss: 26188.0425
# Epoch [6/400], Train Loss: 9508.5628, Val Loss: 23017.8527
# Epoch [7/400], Train Loss: 9199.5169, Val Loss: 25178.4344
# Epoch [8/400], Train Loss: 8732.8190, Val Loss: 22677.5468
# Epoch [9/400], Train Loss: 8420.2755, Val Loss: 21090.0969
# Epoch [10/400], Train Loss: 8285.6545, Val Loss: 20466.8520
# Epoch [11/400], Train Loss: 8147.4438, Val Loss: 21298.9507
# Epoch [12/400], Train Loss: 8062.5817, Val Loss: 22333.8236
# Epoch [13/400], Train Loss: 7922.6473, Val Loss: 21748.6648
# Epoch [14/400], Train Loss: 7588.3083, Val Loss: 21099.3068
# Epoch [15/400], Train Loss: 7307.5808, Val Loss: 19367.8792
# Epoch [16/400], Train Loss: 7119.7133, Val Loss: 19318.2863
# Epoch [17/400], Train Loss: 6938.4973, Val Loss: 19150.1152
# Epoch [18/400], Train Loss: 6839.5789, Val Loss: 17015.3925
# Epoch [19/400], Train Loss: 6748.3666, Val Loss: 18408.7979
# Epoch [20/400], Train Loss: 6718.2719, Val Loss: 18758.7795
# Epoch [21/400], Train Loss: 6680.9174, Val Loss: 18557.0896
# Epoch [22/400], Train Loss: 6625.1008, Val Loss: 18332.7062
# Epoch [23/400], Train Loss: 6614.6353, Val Loss: 19957.9460
# Epoch [24/400], Train Loss: 6564.6115, Val Loss: 19416.5575
# Epoch [25/400], Train Loss: 6520.7276, Val Loss: 19597.4172
# Epoch [26/400], Train Loss: 6432.0012, Val Loss: 19331.6037
# Epoch [27/400], Train Loss: 6236.9049, Val Loss: 17259.3856
# Epoch [28/400], Train Loss: 6066.3804, Val Loss: 18815.2168
# Epoch [29/400], Train Loss: 5934.4697, Val Loss: 16432.3972
# Epoch [30/400], Train Loss: 5868.9524, Val Loss: 19168.6741
# Epoch [31/400], Train Loss: 5798.9718, Val Loss: 19985.0722
# Epoch [32/400], Train Loss: 5673.8947, Val Loss: 16323.4995
# Epoch [33/400], Train Loss: 5643.1021, Val Loss: 15023.2378
# Epoch [34/400], Train Loss: 5581.6799, Val Loss: 16993.3037
# Epoch [35/400], Train Loss: 5604.2442, Val Loss: 16202.2602
# Epoch [36/400], Train Loss: 5586.1340, Val Loss: 17582.2878
# Epoch [37/400], Train Loss: 5574.5734, Val Loss: 17476.3226
# Epoch [38/400], Train Loss: 5515.3338, Val Loss: 17556.9260
# Epoch [39/400], Train Loss: 5519.5833, Val Loss: 17417.0557
# Epoch [40/400], Train Loss: 5502.9689, Val Loss: 16285.8600
# Epoch [41/400], Train Loss: 5474.1124, Val Loss: 16720.4888
# Epoch [42/400], Train Loss: 5454.4364, Val Loss: 17303.4964
# Epoch [43/400], Train Loss: 5433.1454, Val Loss: 17108.4820
# Epoch [44/400], Train Loss: 5427.2800, Val Loss: 16926.9288
# Epoch [45/400], Train Loss: 5378.5078, Val Loss: 15706.3105
# Epoch [46/400], Train Loss: 5341.1947, Val Loss: 15646.9585
# Epoch [47/400], Train Loss: 5302.2210, Val Loss: 16278.4545
# Epoch [48/400], Train Loss: 5279.4745, Val Loss: 17363.2706
# Epoch [49/400], Train Loss: 5213.3090, Val Loss: 15756.9003
# Epoch [50/400], Train Loss: 5150.9416, Val Loss: 15438.3827
# Epoch [51/400], Train Loss: 5102.7158, Val Loss: 15718.6171
# Epoch [52/400], Train Loss: 5035.3207, Val Loss: 17879.7071
# Epoch [53/400], Train Loss: 5006.3341, Val Loss: 17598.9880
# Epoch [54/400], Train Loss: 4926.8212, Val Loss: 16266.2525
# Epoch [55/400], Train Loss: 4890.4000, Val Loss: 16265.7952
# Epoch [56/400], Train Loss: 4906.2859, Val Loss: 16441.6865
# Epoch [57/400], Train Loss: 4801.5864, Val Loss: 16272.8219
# Epoch [58/400], Train Loss: 4759.7140, Val Loss: 17195.7368
# Epoch [59/400], Train Loss: 4725.8735, Val Loss: 16079.1137
# Epoch [60/400], Train Loss: 4697.3096, Val Loss: 17604.4616
# Epoch [61/400], Train Loss: 4657.9232, Val Loss: 15960.3681
# Epoch [62/400], Train Loss: 4642.8196, Val Loss: 14256.7923
# Epoch [63/400], Train Loss: 4618.6328, Val Loss: 15871.2914
# Epoch [64/400], Train Loss: 4573.2727, Val Loss: 15359.9716
# Epoch [65/400], Train Loss: 4544.6614, Val Loss: 15870.7588
# Epoch [66/400], Train Loss: 4549.3068, Val Loss: 14712.3622
# Epoch [67/400], Train Loss: 4522.5771, Val Loss: 18933.0884
# Epoch [68/400], Train Loss: 4499.8981, Val Loss: 14726.6816
# Epoch [69/400], Train Loss: 4498.5008, Val Loss: 16761.6784
# Epoch [70/400], Train Loss: 4506.4551, Val Loss: 16049.8746
# Epoch [71/400], Train Loss: 4472.3842, Val Loss: 15962.7512
# Epoch [72/400], Train Loss: 4477.2474, Val Loss: 15359.3637
# Epoch [73/400], Train Loss: 4444.5663, Val Loss: 16506.6537
# Epoch [74/400], Train Loss: 4460.3224, Val Loss: 15726.1325
# Epoch [75/400], Train Loss: 4424.3824, Val Loss: 17093.2619
# Epoch [76/400], Train Loss: 4420.7930, Val Loss: 16668.3171
# Epoch [77/400], Train Loss: 4393.3869, Val Loss: 17502.0865
# Epoch [78/400], Train Loss: 4354.2599, Val Loss: 15904.2835
# Epoch [79/400], Train Loss: 4375.9726, Val Loss: 15491.8398
# Epoch [80/400], Train Loss: 4305.6979, Val Loss: 15974.3179
# Epoch [81/400], Train Loss: 4257.9073, Val Loss: 15477.6080
# Epoch [82/400], Train Loss: 4303.4979, Val Loss: 16187.9070
# Epoch [83/400], Train Loss: 4253.2966, Val Loss: 15972.4086
# Epoch [84/400], Train Loss: 4287.9670, Val Loss: 15691.4570
# Epoch [85/400], Train Loss: 4266.5944, Val Loss: 15926.8831
# Epoch [86/400], Train Loss: 4269.3920, Val Loss: 15236.7313
# Epoch [87/400], Train Loss: 4248.4302, Val Loss: 16572.0310
# Epoch [88/400], Train Loss: 4209.6108, Val Loss: 18086.7372
# Epoch [89/400], Train Loss: 4226.1455, Val Loss: 15887.3445
# Epoch [90/400], Train Loss: 4249.1515, Val Loss: 16671.7313
# Epoch [91/400], Train Loss: 4208.1366, Val Loss: 17332.3452
# Epoch [92/400], Train Loss: 4207.8410, Val Loss: 14973.2930
# Epoch [93/400], Train Loss: 4180.6388, Val Loss: 17291.4938
# Epoch [94/400], Train Loss: 4177.8357, Val Loss: 15836.9976
# Epoch [95/400], Train Loss: 4167.6428, Val Loss: 17087.0907
# Epoch [96/400], Train Loss: 4134.4021, Val Loss: 16105.8227
# Epoch [97/400], Train Loss: 4116.7708, Val Loss: 16033.6644
# Epoch [98/400], Train Loss: 4145.5805, Val Loss: 16041.5611
# Epoch [99/400], Train Loss: 4131.2089, Val Loss: 15333.3260
# Epoch [100/400], Train Loss: 4139.6343, Val Loss: 15910.6966
# Epoch [101/400], Train Loss: 4109.8611, Val Loss: 16138.0626
# Epoch [102/400], Train Loss: 4079.1555, Val Loss: 15803.5439
# Epoch [103/400], Train Loss: 4109.3701, Val Loss: 17138.6139
# Epoch [104/400], Train Loss: 4100.8712, Val Loss: 16732.2954
# Epoch [105/400], Train Loss: 4071.1204, Val Loss: 17014.5137
# Epoch [106/400], Train Loss: 4049.4916, Val Loss: 16256.3419
# Epoch [107/400], Train Loss: 4069.0314, Val Loss: 15368.1013
# Epoch [108/400], Train Loss: 4061.7896, Val Loss: 15177.4543
# Epoch [109/400], Train Loss: 4067.0799, Val Loss: 15363.1057
# Epoch [110/400], Train Loss: 4045.8757, Val Loss: 14888.0383
# Epoch [111/400], Train Loss: 4060.4754, Val Loss: 16870.6064
# Epoch [112/400], Train Loss: 3999.3358, Val Loss: 15948.8289
# Epoch [113/400], Train Loss: 4007.7849, Val Loss: 15915.9338
# Epoch [114/400], Train Loss: 4011.3203, Val Loss: 15749.8136
# Epoch [115/400], Train Loss: 4030.8508, Val Loss: 15462.8920
# Epoch [116/400], Train Loss: 3982.6381, Val Loss: 16356.1660
# Epoch [117/400], Train Loss: 3986.9094, Val Loss: 15665.1455
# Epoch [118/400], Train Loss: 3957.6575, Val Loss: 17754.0939
# Epoch [119/400], Train Loss: 3943.2923, Val Loss: 16381.8568
# Epoch [120/400], Train Loss: 3926.9511, Val Loss: 15760.7058
# Epoch [121/400], Train Loss: 3924.8087, Val Loss: 17542.0156
# Epoch [122/400], Train Loss: 3929.3345, Val Loss: 14590.7956
# Epoch [123/400], Train Loss: 3907.0398, Val Loss: 15351.7567
# Epoch [124/400], Train Loss: 3918.1279, Val Loss: 16445.0421
# Epoch [125/400], Train Loss: 3880.3217, Val Loss: 15704.3277
# Epoch [126/400], Train Loss: 3854.3003, Val Loss: 16606.0541
# Epoch [127/400], Train Loss: 3875.7633, Val Loss: 14195.1456
# Epoch [128/400], Train Loss: 3886.3267, Val Loss: 16301.1315
# Epoch [129/400], Train Loss: 3873.7840, Val Loss: 17062.9615
# Epoch [130/400], Train Loss: 3860.6202, Val Loss: 16821.5887
# Epoch [131/400], Train Loss: 3867.8655, Val Loss: 15691.6694
# Epoch [132/400], Train Loss: 3866.1660, Val Loss: 15433.3901
# Epoch [133/400], Train Loss: 3865.8271, Val Loss: 16150.5387
# Epoch [134/400], Train Loss: 3834.7171, Val Loss: 15886.5463
# Epoch [135/400], Train Loss: 3823.1348, Val Loss: 16150.6520
# Epoch [136/400], Train Loss: 3812.6669, Val Loss: 15730.2329
# Epoch [137/400], Train Loss: 3791.7821, Val Loss: 15875.9754
# Epoch [138/400], Train Loss: 3790.7394, Val Loss: 14924.9360
# Epoch [139/400], Train Loss: 3772.6970, Val Loss: 14784.5520
# Epoch [140/400], Train Loss: 3775.7661, Val Loss: 16194.4652
# Epoch [141/400], Train Loss: 3733.6864, Val Loss: 16152.1178
# Epoch [142/400], Train Loss: 3727.5974, Val Loss: 15265.2076
# Epoch [143/400], Train Loss: 3750.8993, Val Loss: 15339.9148
# Epoch [144/400], Train Loss: 3761.8143, Val Loss: 15170.8212
# Epoch [145/400], Train Loss: 3753.9782, Val Loss: 14765.9485
# Epoch [146/400], Train Loss: 3723.6080, Val Loss: 14226.4003
# Epoch [147/400], Train Loss: 3748.1153, Val Loss: 14532.5532
# Epoch [148/400], Train Loss: 3713.4256, Val Loss: 14910.5218
# Epoch [149/400], Train Loss: 3704.4131, Val Loss: 15031.9276
# Epoch [150/400], Train Loss: 3707.0424, Val Loss: 15520.9073
# Epoch [151/400], Train Loss: 3729.9022, Val Loss: 15929.3791
# Epoch [152/400], Train Loss: 3691.0017, Val Loss: 15279.0893
# Epoch [153/400], Train Loss: 3707.3286, Val Loss: 15264.5279
# Epoch [154/400], Train Loss: 3663.4329, Val Loss: 15793.2704
# Epoch [155/400], Train Loss: 3692.1324, Val Loss: 15404.6663
# Epoch [156/400], Train Loss: 3694.1607, Val Loss: 16133.0887
# Epoch [157/400], Train Loss: 3696.3292, Val Loss: 16258.5671
# Epoch [158/400], Train Loss: 3677.2950, Val Loss: 16333.0627
# Epoch [159/400], Train Loss: 3636.1444, Val Loss: 15817.9098
# Epoch [160/400], Train Loss: 3655.3215, Val Loss: 15763.4211
# Epoch [161/400], Train Loss: 3644.0960, Val Loss: 15291.8249
# Epoch [162/400], Train Loss: 3694.3585, Val Loss: 14823.7178
# Epoch [163/400], Train Loss: 3653.7200, Val Loss: 17107.3847
# Epoch [164/400], Train Loss: 3668.6178, Val Loss: 16355.8425
# Epoch [165/400], Train Loss: 3685.0328, Val Loss: 15813.3429
# Epoch [166/400], Train Loss: 3666.0890, Val Loss: 15578.2489
# Epoch [167/400], Train Loss: 3662.8617, Val Loss: 15294.6183
# Epoch [168/400], Train Loss: 3656.5719, Val Loss: 14852.9748
# Epoch [169/400], Train Loss: 3684.1478, Val Loss: 15820.5356
# Epoch [170/400], Train Loss: 3658.8053, Val Loss: 14786.0167
# Epoch [171/400], Train Loss: 3634.2089, Val Loss: 15544.4382
# Epoch [172/400], Train Loss: 3655.6839, Val Loss: 14920.0219
# Epoch [173/400], Train Loss: 3612.6448, Val Loss: 14622.7788
# Epoch [174/400], Train Loss: 3650.1794, Val Loss: 16327.8563
# Epoch [175/400], Train Loss: 3648.5383, Val Loss: 15225.3673
# Epoch [176/400], Train Loss: 3630.4548, Val Loss: 14867.2415
# Epoch [177/400], Train Loss: 3648.9059, Val Loss: 16300.4457
# Epoch [178/400], Train Loss: 3652.4423, Val Loss: 17971.0224
# Epoch [179/400], Train Loss: 3631.3840, Val Loss: 17436.5302
# Epoch [180/400], Train Loss: 3618.7140, Val Loss: 16947.7691
# Epoch [181/400], Train Loss: 3624.9943, Val Loss: 16918.5122
# Epoch [182/400], Train Loss: 3619.0166, Val Loss: 16560.9830
# Epoch [183/400], Train Loss: 3611.7739, Val Loss: 16018.9923
# Epoch [184/400], Train Loss: 3602.3571, Val Loss: 16424.6891
# Epoch [185/400], Train Loss: 3600.1232, Val Loss: 16261.9210
# Epoch [186/400], Train Loss: 3611.5998, Val Loss: 14888.5852
# Epoch [187/400], Train Loss: 3604.9996, Val Loss: 15207.7601
# Epoch [188/400], Train Loss: 3578.3387, Val Loss: 16534.5154
# Epoch [189/400], Train Loss: 3588.5010, Val Loss: 16301.8312
# Epoch [190/400], Train Loss: 3576.1243, Val Loss: 17683.5639
# Epoch [191/400], Train Loss: 3582.1074, Val Loss: 15979.9173
# Epoch [192/400], Train Loss: 3600.8721, Val Loss: 14944.0890
# Epoch [193/400], Train Loss: 3547.9832, Val Loss: 15168.2134
# Epoch [194/400], Train Loss: 3573.1825, Val Loss: 15668.4461
# Epoch [195/400], Train Loss: 3568.0196, Val Loss: 13970.3106
# Epoch [196/400], Train Loss: 3551.4968, Val Loss: 15293.8976
# Epoch [197/400], Train Loss: 3558.9414, Val Loss: 15363.8767
# Epoch [198/400], Train Loss: 3528.2199, Val Loss: 16006.5756
# Epoch [199/400], Train Loss: 3544.5596, Val Loss: 17070.4103
# Epoch [200/400], Train Loss: 3543.0071, Val Loss: 15677.1579
# Epoch [201/400], Train Loss: 3558.0041, Val Loss: 15620.5918
# Epoch [202/400], Train Loss: 3537.8169, Val Loss: 17370.8258
# Epoch [203/400], Train Loss: 3533.5501, Val Loss: 18142.2809
# Epoch [204/400], Train Loss: 3489.7310, Val Loss: 16266.0493
# Epoch [205/400], Train Loss: 3481.0882, Val Loss: 16743.7359
# Epoch [206/400], Train Loss: 3494.8850, Val Loss: 15520.3285
# Epoch [207/400], Train Loss: 3467.6490, Val Loss: 16457.5070
# Epoch [208/400], Train Loss: 3476.1494, Val Loss: 17152.1863
# Epoch [209/400], Train Loss: 3449.1762, Val Loss: 16229.5689
# Epoch [210/400], Train Loss: 3431.0644, Val Loss: 15447.9288
# Epoch [211/400], Train Loss: 3422.4385, Val Loss: 16424.6745
# Epoch [212/400], Train Loss: 3435.2739, Val Loss: 17464.5798
# Epoch [213/400], Train Loss: 3471.5660, Val Loss: 15430.4382
# Epoch [214/400], Train Loss: 3446.0938, Val Loss: 14497.9164
# Epoch [215/400], Train Loss: 3434.4399, Val Loss: 15112.3801
# Epoch [216/400], Train Loss: 3443.8227, Val Loss: 14830.1826
# Epoch [217/400], Train Loss: 3434.7524, Val Loss: 16487.5684
# Epoch [218/400], Train Loss: 3458.8881, Val Loss: 16653.3478
# Epoch [219/400], Train Loss: 3432.1081, Val Loss: 14823.3286
# Epoch [220/400], Train Loss: 3433.8552, Val Loss: 16717.1540
# Epoch [221/400], Train Loss: 3448.8615, Val Loss: 16693.8851
# Epoch [222/400], Train Loss: 3426.0877, Val Loss: 16132.1705
# Epoch [223/400], Train Loss: 3419.0218, Val Loss: 17131.3203
# Epoch [224/400], Train Loss: 3431.2530, Val Loss: 17758.5724
# Epoch [225/400], Train Loss: 3409.2696, Val Loss: 16659.4691
# Epoch [226/400], Train Loss: 3417.3761, Val Loss: 16417.6728
# Epoch [227/400], Train Loss: 3434.1814, Val Loss: 16226.6656
# Epoch [228/400], Train Loss: 3419.3568, Val Loss: 16634.5656
# Epoch [229/400], Train Loss: 3404.1181, Val Loss: 16643.5683
# Epoch [230/400], Train Loss: 3416.4592, Val Loss: 16654.8264
# Epoch [231/400], Train Loss: 3436.8167, Val Loss: 17375.4883
# Epoch [232/400], Train Loss: 3406.9732, Val Loss: 17590.0632
# Epoch [233/400], Train Loss: 3413.7953, Val Loss: 14719.3944
# Epoch [234/400], Train Loss: 3411.6641, Val Loss: 15435.1482
# Epoch [235/400], Train Loss: 3394.5533, Val Loss: 17564.6957
# Epoch [236/400], Train Loss: 3423.6371, Val Loss: 17908.9098
# Epoch [237/400], Train Loss: 3414.2441, Val Loss: 14887.2635
# Epoch [238/400], Train Loss: 3409.7526, Val Loss: 16486.4839
# Epoch [239/400], Train Loss: 3422.4282, Val Loss: 15862.4547
# Epoch [240/400], Train Loss: 3409.3717, Val Loss: 16320.7403
# Epoch [241/400], Train Loss: 3416.5142, Val Loss: 16996.7419
# Epoch [242/400], Train Loss: 3388.6360, Val Loss: 16436.2382
# Epoch [243/400], Train Loss: 3423.8482, Val Loss: 15539.2549
# Epoch [244/400], Train Loss: 3371.3870, Val Loss: 16554.0821
# Epoch [245/400], Train Loss: 3390.1103, Val Loss: 15421.6546
# Epoch [246/400], Train Loss: 3394.2666, Val Loss: 17778.6273
# Epoch [247/400], Train Loss: 3401.6935, Val Loss: 17796.4832
# Epoch [248/400], Train Loss: 3422.8941, Val Loss: 15011.6643
# Epoch [249/400], Train Loss: 3376.2223, Val Loss: 16204.5203
# Epoch [250/400], Train Loss: 3416.6045, Val Loss: 16491.4933
# Epoch [251/400], Train Loss: 3366.7318, Val Loss: 16087.8050
# Epoch [252/400], Train Loss: 3381.5296, Val Loss: 16072.7082
# Epoch [253/400], Train Loss: 3381.1747, Val Loss: 16601.1798
# Epoch [254/400], Train Loss: 3412.9578, Val Loss: 16051.1212
# Epoch [255/400], Train Loss: 3368.7978, Val Loss: 15115.6807
# Epoch [256/400], Train Loss: 3363.9515, Val Loss: 15766.0917
# Epoch [257/400], Train Loss: 3396.2068, Val Loss: 15279.0733
# Epoch [258/400], Train Loss: 3363.6212, Val Loss: 17478.2408
# Epoch [259/400], Train Loss: 3354.6196, Val Loss: 15982.7916
# Epoch [260/400], Train Loss: 3380.3577, Val Loss: 17252.1407
# Epoch [261/400], Train Loss: 3376.9369, Val Loss: 16490.1459
# Epoch [262/400], Train Loss: 3366.2784, Val Loss: 15631.8654
# Epoch [263/400], Train Loss: 3400.8788, Val Loss: 14212.9327
# Epoch [264/400], Train Loss: 3385.2940, Val Loss: 17038.5531
# Epoch [265/400], Train Loss: 3385.7642, Val Loss: 15027.0531
# Epoch [266/400], Train Loss: 3356.0909, Val Loss: 15881.7872
# Epoch [267/400], Train Loss: 3415.8866, Val Loss: 15879.7239
# Epoch [268/400], Train Loss: 3383.0540, Val Loss: 14215.7580
# Epoch [269/400], Train Loss: 3360.2489, Val Loss: 15849.0861
# Epoch [270/400], Train Loss: 3397.4784, Val Loss: 15491.2636
# Epoch [271/400], Train Loss: 3386.7823, Val Loss: 15564.1762
# Epoch [272/400], Train Loss: 3351.2859, Val Loss: 14860.6903
# Epoch [273/400], Train Loss: 3356.4018, Val Loss: 16397.1553
# Epoch [274/400], Train Loss: 3357.0013, Val Loss: 15434.4324
# Epoch [275/400], Train Loss: 3372.5151, Val Loss: 14376.9294
# Epoch [276/400], Train Loss: 3411.9341, Val Loss: 15484.3339
# Epoch [277/400], Train Loss: 3396.8176, Val Loss: 15895.7821
# Epoch [278/400], Train Loss: 3345.0252, Val Loss: 17101.4583
# Epoch [279/400], Train Loss: 3356.9482, Val Loss: 17221.0599
# Epoch [280/400], Train Loss: 3412.9997, Val Loss: 16301.1291
# Epoch [281/400], Train Loss: 3350.3787, Val Loss: 15341.7111
# Epoch [282/400], Train Loss: 3370.9105, Val Loss: 15930.8364
# Epoch [283/400], Train Loss: 3399.5178, Val Loss: 16118.8507
# Epoch [284/400], Train Loss: 3372.6482, Val Loss: 15632.0629
# Epoch [285/400], Train Loss: 3356.8665, Val Loss: 14417.7473
# Epoch [286/400], Train Loss: 3402.7312, Val Loss: 15386.5314
# Epoch [287/400], Train Loss: 3367.8953, Val Loss: 14729.1125
# Epoch [288/400], Train Loss: 3369.4976, Val Loss: 15985.8592
# Epoch [289/400], Train Loss: 3353.9892, Val Loss: 14376.1039
# Epoch [290/400], Train Loss: 3340.4609, Val Loss: 17298.8814
# Epoch [291/400], Train Loss: 3340.4693, Val Loss: 15082.6044
# Epoch [292/400], Train Loss: 3368.0924, Val Loss: 14699.2229
# Epoch [293/400], Train Loss: 3360.8052, Val Loss: 14330.3977
# Epoch [294/400], Train Loss: 3321.6188, Val Loss: 13556.9058
# Epoch [295/400], Train Loss: 3360.8219, Val Loss: 14447.9416
# Epoch [296/400], Train Loss: 3360.2041, Val Loss: 15167.2598
# Epoch [297/400], Train Loss: 3343.7295, Val Loss: 14682.1002
# Epoch [298/400], Train Loss: 3366.7840, Val Loss: 13954.5224
# Epoch [299/400], Train Loss: 3336.3899, Val Loss: 16630.2933
# Epoch [300/400], Train Loss: 3327.7927, Val Loss: 15025.8214
# Epoch [301/400], Train Loss: 3325.4304, Val Loss: 14571.6701
# Epoch [302/400], Train Loss: 3336.2560, Val Loss: 14373.4196
# Epoch [303/400], Train Loss: 3345.1777, Val Loss: 13976.0533
# Epoch [304/400], Train Loss: 3344.8014, Val Loss: 16144.7779
# Epoch [305/400], Train Loss: 3332.8925, Val Loss: 14169.5553
# Epoch [306/400], Train Loss: 3348.3333, Val Loss: 14885.5224
# Epoch [307/400], Train Loss: 3359.5941, Val Loss: 14123.6089
# Epoch [308/400], Train Loss: 3384.6392, Val Loss: 14883.3096
# Epoch [309/400], Train Loss: 3316.6807, Val Loss: 14854.1378
# Epoch [310/400], Train Loss: 3357.3759, Val Loss: 13667.5959
# Epoch [311/400], Train Loss: 3353.8428, Val Loss: 14783.9746
# Epoch [312/400], Train Loss: 3320.9074, Val Loss: 14340.5700
# Epoch [313/400], Train Loss: 3326.2172, Val Loss: 13290.8544
# Epoch [314/400], Train Loss: 3340.9074, Val Loss: 13956.8255
# Epoch [315/400], Train Loss: 3345.1836, Val Loss: 14630.5262
# Epoch [316/400], Train Loss: 3355.1832, Val Loss: 15086.5057
# Epoch [317/400], Train Loss: 3345.9045, Val Loss: 14439.6075
# Epoch [318/400], Train Loss: 3364.6444, Val Loss: 14219.1389
# Epoch [319/400], Train Loss: 3344.5539, Val Loss: 16647.5885
# Epoch [320/400], Train Loss: 3350.6477, Val Loss: 13721.1784
# Epoch [321/400], Train Loss: 3334.5322, Val Loss: 15446.8775
# Epoch [322/400], Train Loss: 3355.7692, Val Loss: 15293.2326
# Epoch [323/400], Train Loss: 3331.1568, Val Loss: 14114.7357
# Epoch [324/400], Train Loss: 3329.2081, Val Loss: 15078.8637
# Epoch [325/400], Train Loss: 3317.2820, Val Loss: 14369.3713
# Epoch [326/400], Train Loss: 3351.6036, Val Loss: 15995.3701
# Epoch [327/400], Train Loss: 3355.3861, Val Loss: 15571.6485
# Epoch [328/400], Train Loss: 3315.2852, Val Loss: 15744.6759
# Epoch [329/400], Train Loss: 3331.4879, Val Loss: 14648.9202
# Epoch [330/400], Train Loss: 3324.4916, Val Loss: 13820.5998
# Epoch [331/400], Train Loss: 3354.9186, Val Loss: 13887.0919
# Epoch [332/400], Train Loss: 3314.2316, Val Loss: 15443.5252
# Epoch [333/400], Train Loss: 3334.0583, Val Loss: 13723.6991
# Epoch [334/400], Train Loss: 3290.9646, Val Loss: 11837.6583
# Epoch [335/400], Train Loss: 3320.4670, Val Loss: 12272.9933
# Epoch [336/400], Train Loss: 3352.6137, Val Loss: 13875.1318
# Epoch [337/400], Train Loss: 3306.7026, Val Loss: 13851.8716
# Epoch [338/400], Train Loss: 3316.6558, Val Loss: 14058.3396
# Epoch [339/400], Train Loss: 3316.9959, Val Loss: 14278.7144
# Epoch [340/400], Train Loss: 3341.6707, Val Loss: 12962.5060
# Epoch [341/400], Train Loss: 3297.0954, Val Loss: 13106.9438
# Epoch [342/400], Train Loss: 3305.1082, Val Loss: 16406.0583
# Epoch [343/400], Train Loss: 3310.1565, Val Loss: 14357.7864
# Epoch [344/400], Train Loss: 3290.7376, Val Loss: 13996.6529
# Epoch [345/400], Train Loss: 3316.4453, Val Loss: 13169.8607
# Epoch [346/400], Train Loss: 3327.4017, Val Loss: 12795.3793
# Epoch [347/400], Train Loss: 3306.0324, Val Loss: 16088.6697
# Epoch [348/400], Train Loss: 3311.5536, Val Loss: 15138.7139
# Epoch [349/400], Train Loss: 3312.2737, Val Loss: 15894.8543
# Epoch [350/400], Train Loss: 3290.0108, Val Loss: 13620.0101
# Epoch [351/400], Train Loss: 3289.7133, Val Loss: 14073.6918
# Epoch [352/400], Train Loss: 3283.8708, Val Loss: 14031.9177
# Epoch [353/400], Train Loss: 3303.1667, Val Loss: 15235.7822
# Epoch [354/400], Train Loss: 3306.7972, Val Loss: 14695.1078
# Epoch [355/400], Train Loss: 3248.5220, Val Loss: 14792.6128
# Epoch [356/400], Train Loss: 3299.3708, Val Loss: 13737.0532
# Epoch [357/400], Train Loss: 3282.6209, Val Loss: 14503.1752
# Epoch [358/400], Train Loss: 3271.9169, Val Loss: 14157.4279
# Epoch [359/400], Train Loss: 3263.2972, Val Loss: 13933.3091
# Epoch [360/400], Train Loss: 3264.9269, Val Loss: 14804.3904
# Epoch [361/400], Train Loss: 3270.3496, Val Loss: 15279.5530
# Epoch [362/400], Train Loss: 3250.2937, Val Loss: 15281.6183
# Epoch [363/400], Train Loss: 3264.9425, Val Loss: 14207.0895
# Epoch [364/400], Train Loss: 3276.8133, Val Loss: 14252.2673
# Epoch [365/400], Train Loss: 3256.1394, Val Loss: 15302.4458
# Epoch [366/400], Train Loss: 3250.6141, Val Loss: 14656.0742
# Epoch [367/400], Train Loss: 3264.4884, Val Loss: 16413.7710
# Epoch [368/400], Train Loss: 3272.0593, Val Loss: 13927.5939
# Epoch [369/400], Train Loss: 3246.4074, Val Loss: 13930.1905
# Epoch [370/400], Train Loss: 3254.0134, Val Loss: 13554.0713
# Epoch [371/400], Train Loss: 3223.0763, Val Loss: 14582.9620
# Epoch [372/400], Train Loss: 3258.2076, Val Loss: 15147.9989
# Epoch [373/400], Train Loss: 3220.1733, Val Loss: 13978.3930
# Epoch [374/400], Train Loss: 3241.4584, Val Loss: 13513.7399
# Epoch [375/400], Train Loss: 3271.5192, Val Loss: 14439.2661
# Epoch [376/400], Train Loss: 3232.8972, Val Loss: 13512.7003
# Epoch [377/400], Train Loss: 3258.3279, Val Loss: 16706.1052
# Epoch [378/400], Train Loss: 3243.2592, Val Loss: 13543.1916
# Epoch [379/400], Train Loss: 3267.9469, Val Loss: 13754.5614
# Epoch [380/400], Train Loss: 3257.4258, Val Loss: 14106.6106
# Epoch [381/400], Train Loss: 3208.1943, Val Loss: 13464.0602
# Epoch [382/400], Train Loss: 3242.9239, Val Loss: 14926.7995
# Epoch [383/400], Train Loss: 3256.3734, Val Loss: 13652.5123
# Epoch [384/400], Train Loss: 3223.4061, Val Loss: 16658.1153
# Epoch [385/400], Train Loss: 3228.2959, Val Loss: 14389.9741
# Epoch [386/400], Train Loss: 3188.7276, Val Loss: 15131.2585
# Epoch [387/400], Train Loss: 3243.3193, Val Loss: 15631.1836
# Epoch [388/400], Train Loss: 3215.2184, Val Loss: 13047.7598
# Epoch [389/400], Train Loss: 3200.8472, Val Loss: 13326.0114
# ...
# Epoch [139/400], Train Loss: 3847.7581, Val Loss: 17112.7062
# Epoch [140/400], Train Loss: 3825.5211, Val Loss: 16529.5305
# Epoch [141/400], Train Loss: 3844.0107, Val Loss: 16052.6631
# Epoch [142/400], Train Loss: 3836.1683, Val Loss: 16600.9869
# Epoch [143/400], Train Loss: 3792.7702, Val Loss: 15653.5122
# Epoch [144/400], Train Loss: 3842.0979, Val Loss: 16523.7970
# Epoch [145/400], Train Loss: 3808.1282, Val Loss: 17435.9895
# Epoch [146/400], Train Loss: 3805.7140, Val Loss: 17158.0037
# Epoch [147/400], Train Loss: 3816.5055, Val Loss: 15517.1439
# Epoch [148/400], Train Loss: 3799.1923, Val Loss: 15988.3023
# Epoch [149/400], Train Loss: 3788.7255, Val Loss: 15617.5459
# Epoch [150/400], Train Loss: 3794.5112, Val Loss: 16881.3645
# Epoch [151/400], Train Loss: 3834.9505, Val Loss: 15915.2330
# Epoch [152/400], Train Loss: 3791.6020, Val Loss: 16542.9221
# Epoch [153/400], Train Loss: 3769.9792, Val Loss: 17333.7547
# Epoch [154/400], Train Loss: 3793.5619, Val Loss: 17034.3096
# Epoch [155/400], Train Loss: 3798.3572, Val Loss: 15821.6362
# Epoch [156/400], Train Loss: 3781.1132, Val Loss: 16475.4889
# Epoch [157/400], Train Loss: 3748.8210, Val Loss: 17348.0936
# Epoch [158/400], Train Loss: 3747.9176, Val Loss: 16245.6286
# Epoch [159/400], Train Loss: 3728.5630, Val Loss: 16177.9576
# Epoch [160/400], Train Loss: 3751.7799, Val Loss: 17051.6607
# Epoch [161/400], Train Loss: 3703.8563, Val Loss: 15057.7928
# Epoch [162/400], Train Loss: 3730.1529, Val Loss: 15890.4747
# Epoch [163/400], Train Loss: 3704.5971, Val Loss: 15328.3987
# Epoch [164/400], Train Loss: 3732.9984, Val Loss: 15413.9749
# Epoch [165/400], Train Loss: 3731.3086, Val Loss: 17026.5976
# Epoch [166/400], Train Loss: 3725.3294, Val Loss: 15831.2064
# Epoch [167/400], Train Loss: 3715.8298, Val Loss: 17170.2877
# Epoch [168/400], Train Loss: 3733.1570, Val Loss: 16458.5592
# Epoch [169/400], Train Loss: 3700.6979, Val Loss: 15639.2709
# Epoch [170/400], Train Loss: 3693.8437, Val Loss: 15590.5261
# Epoch [171/400], Train Loss: 3690.6865, Val Loss: 15572.8026
# Epoch [172/400], Train Loss: 3707.9674, Val Loss: 16555.7723
# Epoch [173/400], Train Loss: 3677.0443, Val Loss: 15397.9828
# Epoch [174/400], Train Loss: 3689.8141, Val Loss: 16229.9925
# Epoch [175/400], Train Loss: 3717.3925, Val Loss: 16015.9811
# Epoch [176/400], Train Loss: 3682.4350, Val Loss: 17048.3766
# Epoch [177/400], Train Loss: 3671.4648, Val Loss: 16043.2923
# Epoch [178/400], Train Loss: 3676.4666, Val Loss: 16355.7841
# Epoch [179/400], Train Loss: 3665.5121, Val Loss: 16472.2158
# Epoch [180/400], Train Loss: 3667.0319, Val Loss: 15094.0201
# Epoch [181/400], Train Loss: 3690.3884, Val Loss: 15435.5348
# Epoch [182/400], Train Loss: 3645.6293, Val Loss: 15661.2370
# Epoch [183/400], Train Loss: 3668.0632, Val Loss: 16312.7616
# Epoch [184/400], Train Loss: 3669.9330, Val Loss: 15923.8450
# Epoch [185/400], Train Loss: 3647.4966, Val Loss: 16177.7038
# Epoch [186/400], Train Loss: 3652.9434, Val Loss: 15692.9001
# Epoch [187/400], Train Loss: 3617.6422, Val Loss: 14974.6596
# Epoch [188/400], Train Loss: 3657.7979, Val Loss: 16208.9158
# Epoch [189/400], Train Loss: 3629.3026, Val Loss: 16056.8203
# Epoch [190/400], Train Loss: 3651.7132, Val Loss: 15742.1421
# Epoch [191/400], Train Loss: 3642.2437, Val Loss: 17226.8003
# Epoch [192/400], Train Loss: 3666.3049, Val Loss: 15931.4082
# Epoch [193/400], Train Loss: 3633.6307, Val Loss: 15893.7430
# Epoch [194/400], Train Loss: 3630.6632, Val Loss: 15817.0642
# Epoch [195/400], Train Loss: 3613.8999, Val Loss: 15274.3455
# Epoch [196/400], Train Loss: 3589.2405, Val Loss: 16733.6566
# Epoch [197/400], Train Loss: 3626.8270, Val Loss: 17963.7040
# Epoch [198/400], Train Loss: 3629.9870, Val Loss: 15362.1982
# Epoch [199/400], Train Loss: 3609.8431, Val Loss: 16906.7508
# Epoch [200/400], Train Loss: 3590.7875, Val Loss: 15498.7804
# Epoch [201/400], Train Loss: 3601.9294, Val Loss: 16462.9451
# Epoch [202/400], Train Loss: 3607.5299, Val Loss: 15300.1057
# Epoch [203/400], Train Loss: 3614.4191, Val Loss: 17188.4576
# Epoch [204/400], Train Loss: 3588.4817, Val Loss: 15953.5776
# Epoch [205/400], Train Loss: 3591.7197, Val Loss: 15300.1199
# Epoch [206/400], Train Loss: 3605.0734, Val Loss: 15997.4864
# Epoch [207/400], Train Loss: 3588.4015, Val Loss: 19056.8380
# Epoch [208/400], Train Loss: 3574.9143, Val Loss: 15325.0513
# Epoch [209/400], Train Loss: 3570.1682, Val Loss: 15944.8777
# Epoch [210/400], Train Loss: 3589.1925, Val Loss: 16611.8158
# Epoch [211/400], Train Loss: 3602.7702, Val Loss: 16214.6331
# Epoch [212/400], Train Loss: 3579.1943, Val Loss: 16068.2526
# Epoch [213/400], Train Loss: 3575.1225, Val Loss: 16493.9890
# Epoch [214/400], Train Loss: 3598.0625, Val Loss: 15650.6430
# Epoch [215/400], Train Loss: 3565.9158, Val Loss: 16055.2930
# Epoch [216/400], Train Loss: 3528.4250, Val Loss: 17019.2734
# Epoch [217/400], Train Loss: 3573.9780, Val Loss: 15536.2253
# Epoch [218/400], Train Loss: 3564.7539, Val Loss: 15545.2310
# Epoch [219/400], Train Loss: 3591.4291, Val Loss: 15698.3805
# Epoch [220/400], Train Loss: 3549.7240, Val Loss: 16308.4405
# Epoch [221/400], Train Loss: 3555.5198, Val Loss: 15398.1896
# Epoch [222/400], Train Loss: 3551.6543, Val Loss: 16802.0187
# Epoch [223/400], Train Loss: 3545.0671, Val Loss: 16214.8293
# Epoch [224/400], Train Loss: 3552.5678, Val Loss: 15542.0261
# Epoch [225/400], Train Loss: 3534.5751, Val Loss: 15873.7213
# Epoch [226/400], Train Loss: 3537.9719, Val Loss: 15887.8940
# Epoch [227/400], Train Loss: 3551.0039, Val Loss: 16793.2108
# Epoch [228/400], Train Loss: 3524.8309, Val Loss: 15832.0513
# Epoch [229/400], Train Loss: 3531.7897, Val Loss: 17465.6630
# Epoch [230/400], Train Loss: 3539.5086, Val Loss: 17015.7037
# Epoch [231/400], Train Loss: 3521.1516, Val Loss: 16987.4251
# Epoch [232/400], Train Loss: 3537.8288, Val Loss: 16888.6823
# Epoch [233/400], Train Loss: 3491.5992, Val Loss: 15491.5958
# Epoch [234/400], Train Loss: 3473.9193, Val Loss: 16244.1927
# Epoch [235/400], Train Loss: 3511.5924, Val Loss: 16538.4059
# Epoch [236/400], Train Loss: 3517.0992, Val Loss: 15909.2353
# Epoch [237/400], Train Loss: 3452.7581, Val Loss: 15899.7946
# Epoch [238/400], Train Loss: 3461.2163, Val Loss: 15941.3623
# Epoch [239/400], Train Loss: 3458.7969, Val Loss: 16008.8826
# Epoch [240/400], Train Loss: 3455.1512, Val Loss: 15735.2510
# Epoch [241/400], Train Loss: 3492.2119, Val Loss: 15370.6307
# Epoch [242/400], Train Loss: 3428.5764, Val Loss: 16306.2531
# Epoch [243/400], Train Loss: 3449.8383, Val Loss: 16712.7274
# Epoch [244/400], Train Loss: 3419.6012, Val Loss: 15301.8261
# Epoch [245/400], Train Loss: 3410.0433, Val Loss: 15375.7322
# Epoch [246/400], Train Loss: 3430.0697, Val Loss: 14628.0092
# Epoch [247/400], Train Loss: 3398.0943, Val Loss: 14929.9174
# Epoch [248/400], Train Loss: 3423.6818, Val Loss: 15837.7008
# Epoch [249/400], Train Loss: 3409.7206, Val Loss: 15563.8549
# Epoch [250/400], Train Loss: 3406.1861, Val Loss: 16576.4246
# Epoch [251/400], Train Loss: 3427.2371, Val Loss: 14536.4402
# Epoch [252/400], Train Loss: 3392.0755, Val Loss: 16490.7472
# Epoch [253/400], Train Loss: 3401.4613, Val Loss: 16828.8413
# Epoch [254/400], Train Loss: 3405.7594, Val Loss: 15727.8854
# Epoch [255/400], Train Loss: 3384.9644, Val Loss: 14819.8689
# Epoch [256/400], Train Loss: 3398.6740, Val Loss: 14913.6006
# Epoch [257/400], Train Loss: 3409.0388, Val Loss: 14612.4407
# Epoch [258/400], Train Loss: 3408.1480, Val Loss: 16280.6865
# Epoch [259/400], Train Loss: 3381.3271, Val Loss: 14543.8364
# Epoch [260/400], Train Loss: 3410.0921, Val Loss: 15841.4134
# Epoch [261/400], Train Loss: 3366.1757, Val Loss: 16107.3362
# Epoch [262/400], Train Loss: 3425.2868, Val Loss: 16706.9170
# Epoch [263/400], Train Loss: 3366.9296, Val Loss: 15060.9464
# Epoch [264/400], Train Loss: 3370.3765, Val Loss: 14323.6708
# Epoch [265/400], Train Loss: 3356.3292, Val Loss: 15215.2368
# Epoch [266/400], Train Loss: 3382.0571, Val Loss: 15446.8327
# Epoch [267/400], Train Loss: 3393.6685, Val Loss: 15254.6657
# Epoch [268/400], Train Loss: 3386.4889, Val Loss: 15912.8443
# Epoch [269/400], Train Loss: 3396.8386, Val Loss: 15879.1735
# Epoch [270/400], Train Loss: 3380.2559, Val Loss: 15754.8146
# Epoch [271/400], Train Loss: 3372.6314, Val Loss: 14839.5697
# Epoch [272/400], Train Loss: 3385.2814, Val Loss: 15951.2221
# Epoch [273/400], Train Loss: 3398.9243, Val Loss: 15823.9391
# Epoch [274/400], Train Loss: 3387.5642, Val Loss: 15459.9147
# Epoch [275/400], Train Loss: 3364.7655, Val Loss: 14546.6660
# Epoch [276/400], Train Loss: 3356.3235, Val Loss: 16053.5079
# Epoch [277/400], Train Loss: 3370.8934, Val Loss: 17485.4068
# Epoch [278/400], Train Loss: 3358.8467, Val Loss: 15961.0764
# Epoch [279/400], Train Loss: 3394.2317, Val Loss: 15297.1301
# Epoch [280/400], Train Loss: 3362.0791, Val Loss: 15145.2094
# Epoch [281/400], Train Loss: 3370.6407, Val Loss: 15397.8275
# Epoch [282/400], Train Loss: 3329.6661, Val Loss: 15447.5409
# Epoch [283/400], Train Loss: 3380.4893, Val Loss: 15645.9852
# Epoch [284/400], Train Loss: 3376.6608, Val Loss: 16355.0843
# Epoch [285/400], Train Loss: 3361.3233, Val Loss: 15288.1587
# Epoch [286/400], Train Loss: 3363.4915, Val Loss: 16295.1102
# Epoch [287/400], Train Loss: 3408.2747, Val Loss: 15358.5655
# Epoch [288/400], Train Loss: 3348.2612, Val Loss: 15027.7052
# Epoch [289/400], Train Loss: 3327.6669, Val Loss: 15107.0310
# Epoch [290/400], Train Loss: 3361.0751, Val Loss: 16096.2619
# Epoch [291/400], Train Loss: 3362.9240, Val Loss: 14843.5272
# Epoch [292/400], Train Loss: 3338.4649, Val Loss: 15159.1453
# Epoch [293/400], Train Loss: 3356.4443, Val Loss: 14651.9347
# Epoch [294/400], Train Loss: 3346.3346, Val Loss: 15769.4078
# Epoch [295/400], Train Loss: 3356.7352, Val Loss: 15739.1128
# Epoch [296/400], Train Loss: 3387.1122, Val Loss: 16838.1950
# Epoch [297/400], Train Loss: 3345.7444, Val Loss: 16255.0292
# Epoch [298/400], Train Loss: 3358.3067, Val Loss: 16070.3772
# Epoch [299/400], Train Loss: 3375.7553, Val Loss: 14788.9633
# Epoch [300/400], Train Loss: 3355.4367, Val Loss: 15241.2298
# Epoch [301/400], Train Loss: 3328.3553, Val Loss: 15045.4997
# Epoch [302/400], Train Loss: 3335.5858, Val Loss: 16401.2586
# Epoch [303/400], Train Loss: 3375.9326, Val Loss: 14902.9906
# Epoch [304/400], Train Loss: 3344.6909, Val Loss: 14554.6530
# Epoch [305/400], Train Loss: 3362.4177, Val Loss: 14920.0687
# Epoch [306/400], Train Loss: 3338.1250, Val Loss: 15735.8562
# Epoch [307/400], Train Loss: 3353.5040, Val Loss: 16063.6196
# Epoch [308/400], Train Loss: 3331.9683, Val Loss: 16382.8409
# Epoch [309/400], Train Loss: 3310.4242, Val Loss: 15782.9580
# Epoch [310/400], Train Loss: 3354.4429, Val Loss: 15175.7850
# Epoch [311/400], Train Loss: 3350.2456, Val Loss: 15876.7757
# Epoch [312/400], Train Loss: 3371.3010, Val Loss: 16071.3015
# Epoch [313/400], Train Loss: 3323.6407, Val Loss: 15222.5748
# Epoch [314/400], Train Loss: 3329.1870, Val Loss: 15777.1073
# Epoch [315/400], Train Loss: 3346.7704, Val Loss: 16077.2619
# Epoch [316/400], Train Loss: 3315.8902, Val Loss: 16271.0675
# Epoch [317/400], Train Loss: 3356.9098, Val Loss: 14976.5635
# Epoch [318/400], Train Loss: 3342.9770, Val Loss: 16083.2687
# Epoch [319/400], Train Loss: 3378.8156, Val Loss: 15531.4128
# Epoch [320/400], Train Loss: 3317.3766, Val Loss: 16142.9823
# Epoch [321/400], Train Loss: 3344.2499, Val Loss: 15686.6760
# Epoch [322/400], Train Loss: 3345.5275, Val Loss: 14653.4286
# Epoch [323/400], Train Loss: 3335.7799, Val Loss: 15953.6170
# Epoch [324/400], Train Loss: 3313.8149, Val Loss: 14988.3186
# Epoch [325/400], Train Loss: 3342.0813, Val Loss: 15123.0234
# Epoch [326/400], Train Loss: 3324.2552, Val Loss: 15148.3649
# Epoch [327/400], Train Loss: 3303.4406, Val Loss: 16081.2313
# Epoch [328/400], Train Loss: 3343.1576, Val Loss: 14139.5415
# Epoch [329/400], Train Loss: 3343.5541, Val Loss: 16271.4994
# Epoch [330/400], Train Loss: 3309.8993, Val Loss: 16220.7848
# Epoch [331/400], Train Loss: 3326.8298, Val Loss: 15293.9620
# Epoch [332/400], Train Loss: 3334.8608, Val Loss: 15183.8728
# Epoch [333/400], Train Loss: 3294.7321, Val Loss: 15173.2631
# Epoch [334/400], Train Loss: 3319.8227, Val Loss: 14922.7900
# Epoch [335/400], Train Loss: 3347.2078, Val Loss: 14129.8477
# Epoch [336/400], Train Loss: 3298.4544, Val Loss: 16170.0581
# Epoch [337/400], Train Loss: 3293.5406, Val Loss: 15351.7833
# Epoch [338/400], Train Loss: 3321.1963, Val Loss: 16663.6016
# Epoch [339/400], Train Loss: 3354.0756, Val Loss: 15542.1284
# Epoch [340/400], Train Loss: 3317.1356, Val Loss: 15289.5882
# Epoch [341/400], Train Loss: 3322.1687, Val Loss: 14409.7015
# Epoch [342/400], Train Loss: 3309.0664, Val Loss: 16016.9720
# Epoch [343/400], Train Loss: 3299.3455, Val Loss: 15333.1906
# Epoch [344/400], Train Loss: 3285.6583, Val Loss: 13880.8091
# Epoch [345/400], Train Loss: 3321.9422, Val Loss: 15052.5681
# Epoch [346/400], Train Loss: 3312.9131, Val Loss: 15626.7159
# Epoch [347/400], Train Loss: 3306.7139, Val Loss: 15014.8004
# Epoch [348/400], Train Loss: 3323.5806, Val Loss: 15825.6824
# Epoch [349/400], Train Loss: 3309.3522, Val Loss: 15788.4012
# Epoch [350/400], Train Loss: 3288.3332, Val Loss: 15731.7960
# Epoch [351/400], Train Loss: 3286.5654, Val Loss: 16301.9259
# Epoch [352/400], Train Loss: 3286.8233, Val Loss: 15370.0431
# Epoch [353/400], Train Loss: 3324.5447, Val Loss: 15187.6078
# Epoch [354/400], Train Loss: 3295.9759, Val Loss: 15852.6623
# Epoch [355/400], Train Loss: 3283.6600, Val Loss: 14681.8374
# Epoch [356/400], Train Loss: 3340.8588, Val Loss: 15262.4610
# Epoch [357/400], Train Loss: 3295.3236, Val Loss: 15936.5182
# Epoch [358/400], Train Loss: 3316.5860, Val Loss: 14360.2450
# Epoch [359/400], Train Loss: 3331.0740, Val Loss: 16828.3137
# Epoch [360/400], Train Loss: 3295.7361, Val Loss: 15094.7905
# Epoch [361/400], Train Loss: 3287.4395, Val Loss: 15392.7047
# Epoch [362/400], Train Loss: 3303.9559, Val Loss: 15091.8764
# Epoch [363/400], Train Loss: 3293.5169, Val Loss: 15709.5524
# Epoch [364/400], Train Loss: 3309.9035, Val Loss: 16178.7055
# Epoch [365/400], Train Loss: 3258.0980, Val Loss: 15892.0220
# Epoch [366/400], Train Loss: 3295.2452, Val Loss: 15950.5755
# Epoch [367/400], Train Loss: 3273.2858, Val Loss: 16027.6132
# Epoch [368/400], Train Loss: 3310.9354, Val Loss: 15862.4066
# Epoch [369/400], Train Loss: 3307.0410, Val Loss: 16306.6779
# Epoch [370/400], Train Loss: 3311.6223, Val Loss: 15809.6968
# Epoch [371/400], Train Loss: 3281.2755, Val Loss: 15045.7883
# Epoch [372/400], Train Loss: 3284.2059, Val Loss: 15481.0595
# Epoch [373/400], Train Loss: 3270.4117, Val Loss: 14796.5795
# Epoch [374/400], Train Loss: 3275.9191, Val Loss: 14849.7772
# Epoch [375/400], Train Loss: 3262.3483, Val Loss: 13882.2384
# Epoch [376/400], Train Loss: 3271.3778, Val Loss: 15177.7338
# Epoch [377/400], Train Loss: 3280.5604, Val Loss: 15742.0357
# Epoch [378/400], Train Loss: 3267.6916, Val Loss: 15490.7468
# Epoch [379/400], Train Loss: 3256.6870, Val Loss: 16246.5464
# Epoch [380/400], Train Loss: 3266.2594, Val Loss: 14728.5420
# Epoch [381/400], Train Loss: 3310.1517, Val Loss: 15543.5877
# Epoch [382/400], Train Loss: 3261.7490, Val Loss: 14283.6075
# Epoch [383/400], Train Loss: 3285.8043, Val Loss: 14968.7321
# Epoch [384/400], Train Loss: 3263.4725, Val Loss: 16064.2811
# Epoch [385/400], Train Loss: 3256.7405, Val Loss: 15912.8101
# Epoch [386/400], Train Loss: 3245.5810, Val Loss: 16228.0912
# Epoch [387/400], Train Loss: 3233.6691, Val Loss: 15353.3115
# Epoch [388/400], Train Loss: 3271.9726, Val Loss: 16568.6383
# Epoch [389/400], Train Loss: 3241.0382, Val Loss: 15984.4748
# Epoch [390/400], Train Loss: 3238.2783, Val Loss: 15771.9001
# Epoch [391/400], Train Loss: 3262.0521, Val Loss: 14312.8758
# Epoch [392/400], Train Loss: 3220.5889, Val Loss: 15858.8379
# Epoch [393/400], Train Loss: 3231.0606, Val Loss: 15360.5876
# Epoch [394/400], Train Loss: 3261.6450, Val Loss: 15389.0767
# Epoch [395/400], Train Loss: 3255.8342, Val Loss: 15345.4959
# Epoch [396/400], Train Loss: 3234.9110, Val Loss: 16085.4955
# Epoch [397/400], Train Loss: 3229.6503, Val Loss: 15560.8113
# Epoch [398/400], Train Loss: 3236.6184, Val Loss: 15348.8905
# Epoch [399/400], Train Loss: 3264.6031, Val Loss: 14892.8264
# Epoch [400/400], Train Loss: 3223.7799, Val Loss: 15753.0979

# %%
def plot_losses(train_losses, val_losses, title):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='训练损失')
    plt.plot(val_losses, label='验证损失')
    plt.title(f'{title} 损失曲线')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.show()

# 读取损失
train_losses = pd.read_csv('./short_model/train_losses.csv').values
val_losses = pd.read_csv('./short_model/val_losses.csv').values
# 绘制短期预测模型的损失曲线
plot_losses(train_losses, val_losses, '短期预测模型')

# %%
def evaluate_model(model, val_loader, device):
    model.eval()
    predictions = []
    actuals = []
    inputs = []  # 用于存储输入序列
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val = X_val.to(device)
            y_val = y_val.to(device)
            outputs = model(X_val)
            predictions.append(outputs.cpu().numpy())
            actuals.append(y_val.cpu().numpy())
            inputs.append(X_val.cpu().numpy())  # 收集输入序列
    
    predictions = np.concatenate(predictions, axis=0)
    actuals = np.concatenate(actuals, axis=0)
    inputs = np.concatenate(inputs, axis=0)  # 合并所有输入序列
    
    mse = mean_squared_error(actuals, predictions)
    mae = mean_absolute_error(actuals, predictions)
    
    return mse, mae, inputs, actuals, predictions

# 设置训练参数
num_epochs = 400
learning_rate = 0.005
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_experiments = 5

# 获取输入特征数量
input_size = len(features)

# 短期预测模型参数
hidden_size_short = 64
num_layers_short = 3
output_steps_short = 96
mse_list = []
mae_list = []

for exp in range(num_experiments):
    model_short = LSTMModel(input_size, hidden_size_short, num_layers_short, output_steps_short)
    model_short = model_short.to('cuda' if torch.cuda.is_available() else 'cpu')
    model_short.load_state_dict(torch.load(f'./short_model/model_short_{exp+1}.pth', weights_only=False))
    mse, mae, inputs_short, actuals_short, predictions_short = evaluate_model(model_short, test_loader_short, device)
    mse_list.append(mse)
    mae_list.append(mae)

std_mse = np.std(mse_list)
std_mae = np.std(mae_list)
print(f'短期预测模型 - 平均 MSE: {np.mean(mse_list):.4f}, 平均 MAE: {np.mean(mae_list):.4f}')
print(f'短期预测模型 - MSE 标准差: {std_mse:.4f}, MAE 标准差: {std_mae:.4f}')

# 最佳模型
best_model_idx = np.argmin(mse_list)
model_short = LSTMModel(input_size, hidden_size_short, num_layers_short, output_steps_short)
model_short = model_short.to('cuda' if torch.cuda.is_available() else 'cpu')
model_short.load_state_dict(torch.load(f'./short_model/model_short_{best_model_idx+1}.pth', weights_only=False))
mse, mae, inputs_short, actuals_short, predictions_short = evaluate_model(model_short, test_loader_short, device)

def plot_predictions_with_input(inputs, actual, predicted, sample_idx, title):
    plt.figure(figsize=(15, 5))
    
    input_steps = inputs.shape[1]
    output_steps = actual.shape[1]
    total_steps = input_steps + output_steps
    
    # 提取特定样本的输入、实际和预测数据
    actual_seq = actual[sample_idx]
    predicted_seq = predicted[sample_idx]
    
    last_input_cnt = list(actual[sample_idx - 1][-input_steps:])
    last_input_cnt.append(actual[sample_idx][0])
    
    # 绘制输入序列
    plt.plot(range(input_steps+1), last_input_cnt, label='Input (前一个时间步 cnt)', color='gray')
    
    # 绘制实际值
    plt.plot(range(input_steps, total_steps), actual_seq, label='True', color='blue')
    
    # 绘制预测值
    plt.plot(range(input_steps, total_steps), predicted_seq, label='Predicted', color='red')
    
    plt.title(f'{title} - 预测结果')
    plt.xlabel('时间步')
    plt.ylabel('租赁数量')
    plt.legend()
    plt.show()


plot_predictions_with_input(inputs_short, actuals_short, predictions_short, 1, '短期预测')
# Out:
# 短期预测模型 - 平均 MSE: 22436.8875, 平均 MAE: 101.2068
# 短期预测模型 - MSE 标准差: 2481.3817, MAE 标准差: 6.7316
